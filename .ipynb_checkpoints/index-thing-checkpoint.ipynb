# %%
import os
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.ingestion import IngestionPipeline
from llama_index.core.node_parser import MarkdownNodeParser, SemanticSplitterNodeParser

from llama_index.llms.cohere import Cohere
from llama_index.embeddings.cohere import CohereEmbedding

embed_model = CohereEmbedding(model_name="embed-english-v3.0")

# load markdown nodes
# group together semantically similar nodes
# TODO: make sure there are enough nodes per PDF
reader = SimpleDirectoryReader(
    input_files=[
        "datasets/cds/md/bama.md",
        "datasets/cds/md/mississippi-state.md",
        "datasets/cds/md/nyu.md",
        "datasets/cds/md/uw-madison.md",
        "datasets/cds/md/penn-state.md",
    ],
)

documents = reader.load_data()

pipeline = IngestionPipeline(
    transformations=[MarkdownNodeParser()],
)

nodes = pipeline.run(documents=documents)

# %%
from sklearn.metrics.pairwise import cosine_similarity

import nest_asyncio; nest_asyncio.apply();

# group together nodes by file
nodes_by_file = {}

for node in nodes:
    file_name = node.metadata['file_name']

    if file_name not in nodes_by_file:
        nodes_by_file[file_name] = [node]
    else:
        nodes_by_file[file_name].append(node)

for file in nodes_by_file:
    print(f"{file}: {len(nodes_by_file[file])}")

embeddings_by_file = {
    filename: [await embed_model.aget_text_embedding(node.text) for node in nodes_by_file[filename]]
    for filename in nodes_by_file
}
        
# add first file nodes to groups
# for each node in next file, compare to nodes in group
# node_groups = []

# for node in nodes_by_file['bama.md']:
#     node_groups.append(node)

# for node in
# Out:
# bama.md: 198
# mississippi-state.md: 5
# nyu.md: 74
# uw-madison.md: 262
# penn-state.md: 93

# %%
node_groupings = []

for file_name in embeddings_by_file:
    incoming_dataset_embeddings = embeddings_by_file[file_name]
    # TODO: take vector average instead of first node
    # TODO: may need to include relevant preceeding context to build summary node
    existing_dataset_embeddings = [group[0]["embedding"] for group in node_groupings]

    if existing_dataset_embeddings == []:
        for i, embedding in enumerate(incoming_dataset_embeddings):
            node_groupings.append([{"node": nodes_by_file[file_name][i], "embedding": embedding}])
    else:
        similarities = cosine_similarity(incoming_dataset_embeddings, existing_dataset_embeddings)
        # print(similarities)

        for i, incoming_node_sims in enumerate(similarities):
            current_node = nodes_by_file[file_name][i]
            max_score = 0
            max_index = -1

            for j, existing_node_score in enumerate(incoming_node_sims):
                if existing_node_score > 0.5 and existing_node_score > max_score:
                    max_score = existing_node_score
                    max_index = j
    
            if max_index > -1:
                node_groupings[max_index].append({"node": current_node, "embedding": incoming_dataset_embeddings[i]})
                # print("score:", existing_node_score)
                # print("incoming node:", nodes_by_file[file_name][i])
                # print("existing node:", node_groupings[max_index][0]["node"])
                # print("\n")
            else:
                node_groupings.append([{"node": current_node, "embedding": incoming_dataset_embeddings[i]}])

# print("node groups collected:", len(node_groupings))
# print("non singular groups collected:", len([ng for ng in node_groupings if len(ng) > 1]))

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.schema import TextNode

index = VectorStoreIndex(nodes=[], embed_model=embed_model)
# upsert title node for each document
index.insert_nodes([TextNode(text=filename) for filename in embeddings_by_file])
index.insert_nodes([TextNode(text=f"# {ng[0]['node'].metadata['file_name']}:\n{ng[0]['node'].text}") for ng in node_groupings])

# %%
retriever = index.as_retriever(similarity_top_k=8)
nodes = retriever.retrieve("which schools have more men than women?")

for node in nodes:
    print(node.text + "\n")
# Out:
# # bama.md: TOTAL
#
# |                          | Men    | Women  | Another Gender | Total  |
# | ------------------------ | ------ | ------ | -------------- | ------ |
# | Total all undergraduates | 15,105 | 18,530 | 1,428          | 35,063 |
# | Total all graduate       | 3,483  | 4,060  | 814            | 8,357  |
# | GRAND TOTAL ALL STUDENTS | 18,588 | 22,590 | 2,242          | 43,420 |
#
# # bama.md: B1 Institutional Enrollment - Men and Women
#
# Provide numbers of students for each of the following categories as of the institution's official fall reporting date or as of October 19, 2023.
#
# - Note: Report students formerly designated as "first professional" in the graduate cells.
# - For information on reporting study abroad students please see: This Document at NCES.GOV
# - If your institution collects and reports non-binary gender data, please use the "Another Gender" category.
#   - In cases where gender information is not provided, please distribute across the two-binary categories.
#
# # bama.md: C1 First-time, first-year students:
#
# Provide the number of degree-seeking, first-time, first-year students who applied, were admitted, and enrolled (full- or part-time) in Fall 2023.
#
# - Include early decision, early action, and students who began studies during summer in this cohort.
# - Applicants should include only those students who fulfilled the requirements for consideration for admission (i.e., who completed actionable applications) and who have been notified of one of the following actions: admission, non-admission, placement on waiting list, or application withdrawn (by applicant or institution).
# - Admitted applicants should include wait-listed students who were subsequently offered admission.
# - Since the total may include students who did not provide gender data, the detail need not sum to the total.
# - If your institution collects and reports non-binary gender data, please use the "Another Gender" category.
# - Note that recent high school graduates and other students without prior postsecondary experience will still be considered "first-time students" for fall enrollment reporting purposes even if they enrolled in the summer prior to fall enrollment.
# - Provide numbers of students for each of the following categories as of the institution's official fall reporting date or as of October 15th.
#
# | Category                                                               | Number     |
# | ---------------------------------------------------------------------- | ---------- |
# | Total first-time, first-year men who applied                           | 23,331     |
# | Total first-time, first-year women who applied                         | 35,087     |
# | Total first-time, first-year of another gender who applied             | 0          |
# | **Total**                                                              | **58,418** |
# | Total first-time, first-year men who were admitted                     | 17,444     |
# | Total first-time, first-year women who were admitted                   | 26,851     |
# | Total first-time, first-year of another gender who were admitted       | 0          |
# | **Total**                                                              | **44,295** |
# | Total full-time, first-time, first-year men who enrolled               | 3,520      |
# | Total full-time, first-time, first-year women who enrolled             | 4,732      |
# | Total part-time, first-time, first-year men who enrolled               | 27         |
# | Total full-time, first-time, first-year of another gender who enrolled | 0          |
# | Total part-time, first-time, first-year of another gender who enrolled | 0          |
# | **Total**                                                              | **8,279**  |
# | Total first-time, first-year (degree-seeking) who applied              | 58,418     |
# | Total first-time, first-year (degree-seeking) who were admitted        | 44,295     |
# | Total first-time, first-year (degree-seeking) who enrolled             | 8,279      |
#
# # bama.md: FULL-TIME
#
# |                                                     | Men    | Women  | Another Gender | Total  |
# | --------------------------------------------------- | ------ | ------ | -------------- | ------ |
# | Undergraduates                                      |        |        |                |        |
# | Degree-seeking, first-time, first-year              | 3,483  | 4,732  | 37             | 8,279  |
# | Other first-year, degree-seeking                    | 1,225  | 1,338  | 86             | 2,649  |
# | All other degree-seeking                            | 8,421  | 10,787 | 955            | 21,286 |
# | Total degree-seeking                                | 13,129 | 16,827 | 1,078          | 31,034 |
# | All other undergraduates enrolled in credit courses | 39     | 17     | 350            | 406    |
# | Total undergraduates                                | 13,168 | 16,844 | 1,428          | 31,440 |
# | Graduate                                            |        |        |                |        |
# | Degree-seeking, first-time                          | 1,049  | 628    | 26             | 1,703  |
# | All other degree-seeking                            | 1,039  | 2,140  | 174            | 3,353  |
# | All other graduates enrolled in credit courses      | 5      | 6      | 614            | 625    |
# | Total graduate                                      | 2,093  | 2,774  | 814            | 5,681  |
# | Total all students                                  | 15,261 | 19,618 | 2,242          | 37,121 |
#
# # bama.md: D2. Provide the number of students who applied, were admitted, and enrolled as degree-seeking transfer students in Fall 2023.
#
# If your institution collects and reports non-binary gender data, please use the "Another Gender" category.
#
# | Gender         | Applicants | Admitted Applicants | Enrolled Applicants |
# | -------------- | ---------- | ------------------- | ------------------- |
# | Men            | 2,215      | 1,194               | 530                 |
# | Women          | 2,831      | 1,386               | 621                 |
# | Another Gender | 0          | 0                   | 0                   |
# | **Total**      | **5,046**  | **2,580**           | **1,151**           |
#
# # bama.md: PART-TIME
#
# |                                                     | Men   | Women | Another Gender | Total |
# | --------------------------------------------------- | ----- | ----- | -------------- | ----- |
# | Undergraduates                                      |       |       |                |       |
# | Degree-seeking, first-time, first-year              | 7     | 7     | 0              | 14    |
# | Other first-year, degree-seeking                    | 37    | 30    | 0              | 67    |
# | All other degree-seeking                            | 1,178 | 1,299 | 0              | 2,477 |
# | Total degree-seeking                                | 1,222 | 1,336 | 0              | 2,558 |
# | All other undergraduates enrolled in credit courses | 715   | 350   | 0              | 1,112 |
# | Total undergraduates                                | 1,937 | 1,686 | 0              | 3,623 |
# | Graduate                                            |       |       |                |       |
# | Degree-seeking, first-time                          | 226   | 122   | 0              | 348   |
# | All other degree-seeking                            | 1,164 | 1,164 | 0              | 2,328 |
# | All other graduates enrolled in credit courses      | 0     | 0     | 0              | 0     |
# | Total graduate                                      | 1,390 | 1,286 | 0              | 2,676 |
# | Total all students                                  | 3,327 | 2,972 | 0              | 6,299 |
#
# # bama.md: I-1
#
# | Description | Full-Time                                                                                                                | Part-Time | Total |
# | ----------- | ------------------------------------------------------------------------------------------------------------------------ | --------- | ----- | ----- |
# | A           | Total number of instructional faculty                                                                                    | 1,579     | 457   | 2,036 |
# | B           | Total number who are members of minority groups                                                                          | 325       | 110   | 435   |
# | C           | Total number who are women                                                                                               | 756       | 299   | 1,055 |
# | D           | Total number who are men                                                                                                 | 823       | 158   | 981   |
# | E           | Total number who are nonresidents (international)                                                                        | 72        | 2     | 74    |
# | F           | Total number with doctorate, or other terminal degree                                                                    | 1,299     | 272   | 1,571 |
# | G           | Total number whose highest degree is a master's but not a terminal master's                                              | 260       | 171   | 431   |
# | H           | Total number whose highest degree is a bachelor's                                                                        | 17        | 14    | 31    |
# | I           | Total number whose highest degree is a doctorate                                                                         | 1,182     | 185   | 1,367 |
# | J           | Total number whose highest degree is unknown or other (Note: Items f, g, h, and i must sum up to item a.)                | 3         | 3     | 6     |
# | K           | Total number in stand-alone graduate/professional programs in which faculty teach virtually only graduate-level students | 39        | 34    | 73    |
#
# # bama.md: A3 Classify your undergraduate institution:
#
# - [x] Coeducational college
# - [ ] Men's college
# - [ ] Women's college

# %%
from llama_index.core import PromptTemplate
from llama_index.core.indices.property_graph import SchemaLLMPathExtractor
from llama_index.core.program import LLMTextCompletionProgram

from llama_index.llms.cohere import Cohere

from typing import List, Literal, Union, Optional, Dict, Any
from pydantic import BaseModel

# TODO: try with more obedient model
llm = Cohere(model="command-r")

class GroupInfo(BaseModel):
    subject: str
    fields: List[str]
    
    # possible_values: List[str]

def generate_fields(node_group):
    prompt = """
Given these nodes, determine a common subject.
Next, determine up to {num_fields} fields that can be extracted from the nodes and a datatype for each field.
If the subject represent categorical data with a finite amount of possible values, express each value as a separate field.
Use snake_case for the subject and field names.
Each field should be in the form `field_name (field_datatype)`.
field_datatype should be one of the following: STRING, BOOLEAN, NUMBER.
Categorical data should be boolean datatype.
Avoid creating different fields for similar information, such as "phone" and "phone_number".
Do not make up fields if they are not present in any of the nodes.
Avoid stopwords.

Nodes:
{nodes}
"""

    # for i, node in enumerate(node_group):
    #     prompt += f"Node {i+1}:\n"
    #     prompt += node["node"].text
    #     prompt += "\n"

    program = LLMTextCompletionProgram.from_defaults(
        output_cls=GroupInfo,
        prompt=PromptTemplate(prompt),
        verbose=True,
    )

    output = program(num_fields=20, nodes=[f"Node {i+1}:\n {n['node'].text}\n" for i, n in enumerate(node_group)])
    print(output)
    return output

class NodeAnswer(BaseModel):
    question: str
    value: Union[str, bool, int, float, None]

class NodeAnswers(BaseModel):
    answers: List[NodeAnswer]

def extract_single_answers(node, fields):
    answers = []

    for f in fields:
        prompt = """
Given this node, attempt to fill in the following field:
{question}
Node:
{node}
"""

        program = LLMTextCompletionProgram.from_defaults(
            prompt=PromptTemplate(prompt),
            output_cls=NodeAnswer,
            verbose=True,
        )

        try:
            output = program(question=f, node=node.text)
            print(output)
            answers.append(output)
        except Exception as e:
            print(e)

    return NodeAnswers(answers=answers)

def extract_answers(node, subject, fields):
    prompt = """
Given this node, which is about {subject}, attempt to answer the following questions:
{fields}
Node:
{node}
"""
    
    program = LLMTextCompletionProgram.from_defaults(
        prompt=PromptTemplate(prompt),
        output_cls=NodeAnswers,
        verbose=True,
    )

    try:
        answers = program(
            subject=subject,
            fields="\n".join([f"Question {i+1}. {f}" for i, f in enumerate(fields)]),
            node=node.text,
        )
        print(answers)
        return answers
        # TODO: try individual field extraction
    except Exception as e:
        answers = extract_single_answers(node, fields)
        print(answers)
        return answers

def get_group_kg_extractor(group):
    info = generate_fields(group)

    # entity = triples.subject.upper()
    fields = [f.upper() for f in info.fields]

    for node in ng:
        node_answers = extract_answers(node["node"], info.subject, fields)
        # TODO: add entity relations

# for ng in node_groupings[:10]:
#     if len(ng) > 0:
#         get_group_kg_extractor(ng)

# %%
# setup duckdb
# import schema
# index, index keys, values, m2m index relationship, m2m value relationship to index keys
# chunk storage, link index keys and values to chunks, delete values if chunks change or deleted
cursor.sql('create table "indexes" ("id" TEXT NOT NULL, "name" TEXT NOT NULL), CONSTRAINT "indexes_pkey" PRIMARY KEY ("id")')
cursor.sql('create table "index_keys" ("id" TEXT NOT NULL, "index_id" TEXT NOT NULL, "key" TEXT, "key_embedding" FLOAT[1024], CONSTRAINT "index_keys_pkey" PRIMARY KEY ("id"))')
cursor.sql('create table "values" ("id" TEXT NOT NULL, "value" TEXT NOT NULL, CONSTRAINT "values_pkey" PRIMARY KEY ("id"))')
# add vector extension
cursor.sql('select * from index_keys order by array_distance(key_embedding, [1,2,3]::FLOAT[1024])')

# Document API:

# insert generic chunk
# create collection
# add document w/ document name, document hash, document text
# add chunks for document with hash, name, text, parent doc
# add queryable embedding node with link to parent chunk
# add non-queryable embedding group node for each chunk

# when adding a new document, get possible groups with existing document nodes w/threshold
# create node group should un-index original embedding nodes in group, create embedded primary field nodes and secondary title nodes for each document
# all nodes in group need to be added back as value nodes with primary and secondary filters with a link to the originally embedded node
# adding a new document to an existing group should add the 
# if the group changes and originally grouped nodes are removed, put the node back on the index
# deleting an index node should delete all values under the index

# re-indexing document -> diff check chunks, return existing nodes that are outdated, new chunks from updated document

# delete document should delete all child documents, all embeddings for document


# insert grouped semi-structured document
# insert document + chunk like normal in grouping index -> do not return individual nodes from grouping index
# get document groupings from grouping index

# %%
from llama_index.core.graph_stores.types import Relation, EntityNode, KG_NODES_KEY, KG_RELATIONS_KEY
from llama_index.core import VectorStoreIndex
from llama_index.core.schema import TextNode

def insert_node_answers(node, answers):
    existing_relations = node.metadata.pop(KG_RELATIONS_KEY, [])
    existing_nodes = node.metadata.pop(KG_NODES_KEY, [])

    edges = []
    metadata = node.metadata.copy()

    for answer in answers:
        if answer.value is not None:
            answer_node = EntityNode(name=answer.value, properties=metadata)
            edges.append(
                Relation(
                    source_id=node.node_id,
                    target_id=answer_node.id,
                    label=answer.question,
                    properties=metadata,
                )
            )
    
    existing_relations.extend(edges)
    node.metadata[KG_RELATIONS_KEY] = existing_relations
    node.metadata[KG_NODES_KEY] = existing_nodes

index = VectorStoreIndex(nodes=[], embed_model=embed_model)
title_index = VectorStoreIndex(nodes=[], embed_model=embed_model)
# upsert title node for each document
index.insert_nodes([TextNode(text=filename) for filename in embeddings_by_file])
title_index.insert_nodes([TextNode(text=filename) for filename in embeddings_by_file])

for ng in node_groupings[:20]:
    if len(ng) > 1:
        info = generate_fields(ng)
        # insert node for fields in node group -> if this is hit + fields in this subject just return all fields under subject
        info_node_text = f"{info.subject}\n"
        for field in info.fields:
            info_node_text += f"* {field}\n"

        index.insert_nodes([TextNode(text=info_node_text)])

        # entity = triples.subject.upper()
        fields = [f.upper() for f in info.fields]
        # Insert nodes for each key (with aggregate info for all keys under it)
        index.insert_nodes([TextNode(text=field) for field in fields])
    
        for node in ng:
            node_answers = extract_answers(node["node"], info.subject, fields)
            # insert value node with node metadata for key and title
            # index.insert_nodes([TextNode(text=f"{node['node'].metadata['file_name']} {answer.question}: {answer.value}") for answer in node_answers.answers])
            # if node_answers is not None:
            #     insert_node_answers(node["node"], node_answers.answers)


# TODO: save schemas
# save answer chunks
# title nodes
# key nodes
# cross reference key and title nodes
# if key and title node both hit, generate custom aggregate value node and return
# if key node(s) hit (and some value nodes in column), return synthetic node with all values in columns
# Out:
# subject='general_information' fields=['annual_expenses (boolean)']
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# answers=[NodeAnswer(question='ANNUAL_EXPENSES', value=True)]
# subject='respondent_information' fields=['name (string)', 'title (string)', 'office (string)', 'mailing_address (string)', 'city (string)', 'state (string)', 'zip (string)', 'country (string)', 'phone (string)', 'email_address (string)', 'responses_posted_on_website (boolean)', 'url_of_web_page (string)', 'first_name (string)', 'last_name (string)', 'address (string)', 'phone_number (string)', 'extension (string)', 'url_of_cds_responses (string)']
# answers=[NodeAnswer(question='NAME', value='Lorne Kuffel'), NodeAnswer(question='TITLE', value='Executive Director, OIRA'), NodeAnswer(question='OFFICE', value='Institutional Research and Assessment'), NodeAnswer(question='MAILING_ADDRESS', value='University of Alabama, Box 870166'), NodeAnswer(question='CITY', value='Tuscaloosa'), NodeAnswer(question='STATE', value='Alabama'), NodeAnswer(question='ZIP', value='35487-0166'), NodeAnswer(question='COUNTRY', value='USA'), NodeAnswer(question='PHONE', value='(205) 348-7200'), NodeAnswer(question='EMAIL_ADDRESS', value='lkuffel@ua.edu'), NodeAnswer(question='RESPONSES_POSTED_ON_WEBSITE', value=True), NodeAnswer(question='URL_OF_WEB_PAGE', value='http://oira.ua.edu/new/reports/?Report%20Type[0][0]=Common%20Data%20Set')]
# answers=[NodeAnswer(question='NAME', value=None), NodeAnswer(question='TITLE', value=None), NodeAnswer(question='OFFICE', value='Office of Institutional Research and Effectiveness'), NodeAnswer(question='MAILING_ADDRESS', value='P.O. Drawer EY'), NodeAnswer(question='CITY', value='Mississippi State'), NodeAnswer(question='STATE', value='Mississippi'), NodeAnswer(question='ZIP', value=39762), NodeAnswer(question='COUNTRY', value='United States'), NodeAnswer(question='PHONE', value='662-325-3920'), NodeAnswer(question='EMAIL_ADDRESS', value='oire@ir.msstate.edu'), NodeAnswer(question='RESPONSES_POSTED_ON_WEBSITE', value=True), NodeAnswer(question='URL_OF_WEB_PAGE', value='https://ir.msstate.edu/cdsets.php'), NodeAnswer(question='FIRST_NAME', value=None), NodeAnswer(question='LAST_NAME', value=None), NodeAnswer(question='ADDRESS', value=None), NodeAnswer(question='PHONE_NUMBER', value=None), NodeAnswer(question='EXTENSION', value=None), NodeAnswer(question='URL_OF_CDS_RESPONSES', value=None)]
# answers=[NodeAnswer(question='NAME', value=None), NodeAnswer(question='TITLE', value=''), NodeAnswer(question='OFFICE', value='Office of Institutional Research'), NodeAnswer(question='MAILING_ADDRESS', value='3 Washington Square Village, 1M'), NodeAnswer(question='CITY', value='New York'), NodeAnswer(question='STATE', value='New York'), NodeAnswer(question='ZIP', value='10012'), NodeAnswer(question='COUNTRY', value='United States'), NodeAnswer(question='PHONE', value=''), NodeAnswer(question='EMAIL_ADDRESS', value='external.reporting@nyu.edu'), NodeAnswer(question='RESPONSES_POSTED_ON_WEBSITE', value=True), NodeAnswer(question='URL_OF_WEB_PAGE', value='https://www.nyu.edu/employees/resources-and-services/administrative-services/institutional-research/factbook.html'), NodeAnswer(question='FIRST_NAME', value=''), NodeAnswer(question='LAST_NAME', value=''), NodeAnswer(question='ADDRESS', value=''), NodeAnswer(question='PHONE_NUMBER', value=''), NodeAnswer(question='EXTENSION', value=''), NodeAnswer(question='URL_OF_CDS_RESPONSES', value='')]
# answers=[NodeAnswer(question='NAME', value='Sara Lazenby'), NodeAnswer(question='TITLE', value='Institutional Policy Analyst'), NodeAnswer(question='OFFICE', value='Data, Academic Planning, and Institutional Research'), NodeAnswer(question='MAILING_ADDRESS', value='170 Bascom Hall 500 Lincoln Drive'), NodeAnswer(question='CITY', value='Madison'), NodeAnswer(question='STATE', value='Wisconsin'), NodeAnswer(question='ZIP', value='53706'), NodeAnswer(question='COUNTRY', value='United States'), NodeAnswer(question='PHONE', value='608-263-5945'), NodeAnswer(question='EMAIL_ADDRESS', value='sara.lazenby@wisc.edu'), NodeAnswer(question='RESPONSES_POSTED_ON_WEBSITE', value=True), NodeAnswer(question='URL_OF_WEB_PAGE', value='https://data.wisc.edu/common-data-set-and-rankings/'), NodeAnswer(question='FIRST_NAME', value='Sara'), NodeAnswer(question='LAST_NAME', value='Lazenby'), NodeAnswer(question='ADDRESS', value='170 Bascom Hall 500 Lincoln Drive'), NodeAnswer(question='PHONE_NUMBER', value='608-263-5945'), NodeAnswer(question='EXTENSION', value=None), NodeAnswer(question='URL_OF_CDS_RESPONSES', value='https://data.wisc.edu/common-data-set-and-rankings/')]
# subject='cds_comments' fields=['comments_about_cds (string)']
# answers=[NodeAnswer(question='COMMENTS_ABOUT_CDS', value='There are no items on the CDS for which I cannot use the requested analytic convention.')]
# answers=[NodeAnswer(question='COMMENTS_ABOUT_CDS', value='I am unable to use the requested analytic convention for some items on the CDS.')]
# answers=[NodeAnswer(question='COMMENTS_ABOUT_CDS', value='A0A. Comments About CDS (not for publication)')]
# answers=[NodeAnswer(question='COMMENTS_ABOUT_CDS', value='There are items on the CDS for which we cannot use the requested analytic convention.')]
# subject='address_information' fields=['name_of_college_university (string)', 'mailing_address (string)', 'city_state_zip_country (string)', 'street_address (string)', 'main_phone_number (string)', 'www_home_page_address (string)', 'admissions_phone_number (string)', 'admissions_toll_free_phone_number (string)', 'admissions_office_mailing_address (string)', 'admissions_fax_number (string)', 'admissions_e_mail_address (string)', 'separate_url_for_schools_online_application (string)', 'applications_mailing_address (string)', 'institution_website (string)', 'admissions_website (string)', 'admissions_email_address (string)', 'admissions_toll_free_number (string)', 'updated (string)', 'general_information_common_data_set_2023_24 (string)']
# answers=[NodeAnswer(question='NAME_OF_COLLEGE_UNIVERSITY', value='The University of Alabama'), NodeAnswer(question='MAILING_ADDRESS', value='Box 870100'), NodeAnswer(question='CITY_STATE_ZIP_COUNTRY', value='Tuscaloosa, AL 35487-0100 USA'), NodeAnswer(question='STREET_ADDRESS', value='801 University Blvd'), NodeAnswer(question='MAIN_PHONE_NUMBER', value='(205) 348-6010'), NodeAnswer(question='WWW_HOME_PAGE_ADDRESS', value='www.ua.edu'), NodeAnswer(question='ADMISSIONS_PHONE_NUMBER', value='(205) 348-5666'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_PHONE_NUMBER', value='(800) 933-2262'), NodeAnswer(question='ADMISSIONS_OFFICE_MAILING_ADDRESS', value='The University of Alabama, Box 870132'), NodeAnswer(question='ADMISSIONS_FAX_NUMBER', value='(205) 348-9046'), NodeAnswer(question='ADMISSIONS_E_MAIL_ADDRESS', value='admissions@ua.edu'), NodeAnswer(question='SEPARATE_URL_FOR_SCHOOLS_ONLINE_APPLICATION', value='www.apply.ua.edu'), NodeAnswer(question='APPLICATIONS_MAILING_ADDRESS', value=None), NodeAnswer(question='INSTITUTION_WEBSITE', value=None), NodeAnswer(question='ADMISSIONS_WEBSITE', value=None), NodeAnswer(question='ADMISSIONS_EMAIL_ADDRESS', value=None), NodeAnswer(question='ADMISSIONS_TOLL_FREE_NUMBER', value=None), NodeAnswer(question='UPDATED', value=None), NodeAnswer(question='GENERAL_INFORMATION_COMMON_DATA_SET_2023_24', value=None)]
# answers=[NodeAnswer(question='NAME_OF_COLLEGE_UNIVERSITY', value='Mississippi State University'), NodeAnswer(question='MAILING_ADDRESS', value='75 B.S. Hood Road, Mississippi State, Mississippi, 39762, United States'), NodeAnswer(question='CITY_STATE_ZIP_COUNTRY', value='Mississippi State, Mississippi, 39762, United States'), NodeAnswer(question='STREET_ADDRESS', value='75 B.S. Hood Road'), NodeAnswer(question='MAIN_PHONE_NUMBER', value='662-325-2323'), NodeAnswer(question='WWW_HOME_PAGE_ADDRESS', value='https://www.msstate.edu/'), NodeAnswer(question='ADMISSIONS_PHONE_NUMBER', value='662-325-2224'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_PHONE_NUMBER', value=None), NodeAnswer(question='ADMISSIONS_OFFICE_MAILING_ADDRESS', value='25 Old Main, Mississippi State, Mississippi, 39762, United States'), NodeAnswer(question='ADMISSIONS_FAX_NUMBER', value=None), NodeAnswer(question='ADMISSIONS_E_MAIL_ADDRESS', value='admit@msstate.edu'), NodeAnswer(question='SEPARATE_URL_FOR_SCHOOLS_ONLINE_APPLICATION', value='https://apply.msstate.edu'), NodeAnswer(question='APPLICATIONS_MAILING_ADDRESS', value='P.O. Box 6334, Mississippi State, Mississippi, 39762'), NodeAnswer(question='INSTITUTION_WEBSITE', value='https://www.msstate.edu/'), NodeAnswer(question='ADMISSIONS_WEBSITE', value='https://www.admissions.msstate.edu/'), NodeAnswer(question='ADMISSIONS_EMAIL_ADDRESS', value='admit@msstate.edu'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_NUMBER', value=None), NodeAnswer(question='UPDATED', value='2/13/2024'), NodeAnswer(question='GENERAL_INFORMATION_COMMON_DATA_SET_2023_24', value='A. General Information Common Data Set 2023-24')]
# answers=[NodeAnswer(question='NAME_OF_COLLEGE_UNIVERSITY', value='New York University'), NodeAnswer(question='MAILING_ADDRESS', value='70 Washington Square South'), NodeAnswer(question='CITY_STATE_ZIP_COUNTRY', value='New York, New York, 10003, United States'), NodeAnswer(question='STREET_ADDRESS', value='383 Lafayette Street'), NodeAnswer(question='MAIN_PHONE_NUMBER', value='(212) 998-1212'), NodeAnswer(question='WWW_HOME_PAGE_ADDRESS', value='www.nyu.edu'), NodeAnswer(question='ADMISSIONS_PHONE_NUMBER', value='(212) 998-4500'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_PHONE_NUMBER', value=''), NodeAnswer(question='ADMISSIONS_OFFICE_MAILING_ADDRESS', value='383 Lafayette Street, New York, New York, 10003, United States'), NodeAnswer(question='ADMISSIONS_FAX_NUMBER', value=''), NodeAnswer(question='ADMISSIONS_E_MAIL_ADDRESS', value='admissions@nyu.edu'), NodeAnswer(question='SEPARATE_URL_FOR_SCHOOLS_ONLINE_APPLICATION', value='https://www.nyu.edu/admissions/undergraduate-admissions/how-to-apply.html'), NodeAnswer(question='APPLICATIONS_MAILING_ADDRESS', value='(No additional mailing address provided)'), NodeAnswer(question='INSTITUTION_WEBSITE', value=''), NodeAnswer(question='ADMISSIONS_WEBSITE', value='https://www.nyu.edu/admissions/undergraduate-admissions.html'), NodeAnswer(question='ADMISSIONS_EMAIL_ADDRESS', value='admissions@nyu.edu'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_NUMBER', value=''), NodeAnswer(question='UPDATED', value=''), NodeAnswer(question='GENERAL_INFORMATION_COMMON_DATA_SET_2023_24', value='')]
# answers=[NodeAnswer(question='NAME_OF_COLLEGE_UNIVERSITY', value='University of Wisconsin-Madison'), NodeAnswer(question='MAILING_ADDRESS', value='500 Lincoln Drive, Madison, Wisconsin, 53706, United States'), NodeAnswer(question='CITY_STATE_ZIP_COUNTRY', value='Madison, Wisconsin, 53706, United States'), NodeAnswer(question='STREET_ADDRESS', value='500 Lincoln Drive'), NodeAnswer(question='MAIN_PHONE_NUMBER', value='(608) 263-2400'), NodeAnswer(question='WWW_HOME_PAGE_ADDRESS', value='https://www.wisc.edu'), NodeAnswer(question='ADMISSIONS_PHONE_NUMBER', value='(608) 262-3691'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_PHONE_NUMBER', value=''), NodeAnswer(question='ADMISSIONS_OFFICE_MAILING_ADDRESS', value='702 West Johnson Street, Suite 1101, Madison, Wisconsin, 53715, United States'), NodeAnswer(question='ADMISSIONS_FAX_NUMBER', value=''), NodeAnswer(question='ADMISSIONS_E_MAIL_ADDRESS', value='onwisconsin@admissions.wisc.edu'), NodeAnswer(question='SEPARATE_URL_FOR_SCHOOLS_ONLINE_APPLICATION', value=''), NodeAnswer(question='APPLICATIONS_MAILING_ADDRESS', value=''), NodeAnswer(question='INSTITUTION_WEBSITE', value='https://www.wisc.edu'), NodeAnswer(question='ADMISSIONS_WEBSITE', value='https://admissions.wisc.edu'), NodeAnswer(question='ADMISSIONS_EMAIL_ADDRESS', value='onwisconsin@admissions.wisc.edu'), NodeAnswer(question='ADMISSIONS_TOLL_FREE_NUMBER', value=''), NodeAnswer(question='UPDATED', value=''), NodeAnswer(question='GENERAL_INFORMATION_COMMON_DATA_SET_2023_24', value='')]
# subject='institutional_control' fields=['public (boolean)', 'private_nonprofit (boolean)', 'proprietary (boolean)', 'private_institution (boolean)', 'private_for_profit_institution (boolean)', 'private_nonprofit_institution (boolean)', 'proprietary_institution (boolean)']
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=True), NodeAnswer(question='PROPRIETARY', value=False), NodeAnswer(question='PRIVATE_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=True), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=False)]
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=True), NodeAnswer(question='PROPRIETARY', value=False), NodeAnswer(question='PRIVATE_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=True), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=False)]
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=False), NodeAnswer(question='PROPRIETARY', value=False), NodeAnswer(question='PRIVATE_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=True), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=True)]
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=False), NodeAnswer(question='PROPRIETARY', value=True), NodeAnswer(question='PRIVATE_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=False), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=False)]
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=True), NodeAnswer(question='PROPRIETARY', value=False), NodeAnswer(question='PRIVATE_INSTITUTION', value=True), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=True), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=False)]
# answers=[NodeAnswer(question='PUBLIC', value=False), NodeAnswer(question='PRIVATE_NONPROFIT', value=False), NodeAnswer(question='PROPRIETARY', value=True), NodeAnswer(question='PRIVATE_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_FOR_PROFIT_INSTITUTION', value=False), NodeAnswer(question='PRIVATE_NONPROFIT_INSTITUTION', value=False), NodeAnswer(question='PROPRIETARY_INSTITUTION', value=False)]
# subject='undergraduate_institution' fields=['coeducational_college (boolean)', 'mens_college (boolean)', 'womens_college (boolean)', 'coeducational (boolean)', 'womens_center (boolean)']
# answers=[NodeAnswer(question='COEDUCATIONAL_COLLEGE', value=True), NodeAnswer(question='MENS_COLLEGE', value=False), NodeAnswer(question='WOMENS_COLLEGE', value=False), NodeAnswer(question='COEDUCATIONAL', value=True), NodeAnswer(question='WOMENS_CENTER', value=False)]
# answers=[NodeAnswer(question='COEDUCATIONAL_COLLEGE', value=True), NodeAnswer(question='MENS_COLLEGE', value=False), NodeAnswer(question='WOMENS_COLLEGE', value=False), NodeAnswer(question='COEDUCATIONAL', value=True), NodeAnswer(question='WOMENS_CENTER', value=False)]
# answers=[NodeAnswer(question='COEDUCATIONAL_COLLEGE', value=False), NodeAnswer(question='MENS_COLLEGE', value=False), NodeAnswer(question='WOMENS_COLLEGE', value=False), NodeAnswer(question='COEDUCATIONAL', value=True), NodeAnswer(question='WOMENS_CENTER', value=True)]
# subject='academic_year_calendar' fields=['semester (boolean)', 'quarter (boolean)', 'trimester (boolean)', '4_1_4 (boolean)', 'continuous (boolean)', 'differs_by_program (boolean)', 'other_describe (boolean)']
# answers=[NodeAnswer(question='SEMESTER', value=True), NodeAnswer(question='QUARTER', value=False), NodeAnswer(question='TRIMESTER', value=False), NodeAnswer(question='4_1_4', value=False), NodeAnswer(question='CONTINUOUS', value=False), NodeAnswer(question='DIFFERS_BY_PROGRAM', value=False), NodeAnswer(question='OTHER_DESCRIBE', value=False)]
# answers=[NodeAnswer(question='SEMESTER', value=True), NodeAnswer(question='QUARTER', value=False), NodeAnswer(question='TRIMESTER', value=False), NodeAnswer(question='4_1_4', value=False), NodeAnswer(question='CONTINUOUS', value=False), NodeAnswer(question='DIFFERS_BY_PROGRAM', value=False), NodeAnswer(question='OTHER_DESCRIBE', value=False)]
# answers=[NodeAnswer(question='SEMESTER', value=False), NodeAnswer(question='QUARTER', value=False), NodeAnswer(question='TRIMESTER', value=False), NodeAnswer(question='4_1_4', value=False), NodeAnswer(question='CONTINUOUS', value=False), NodeAnswer(question='DIFFERS_BY_PROGRAM', value=False), NodeAnswer(question='OTHER_DESCRIBE', value=False)]
# answers=[NodeAnswer(question='SEMESTER', value=True), NodeAnswer(question='QUARTER', value=False), NodeAnswer(question='TRIMESTER', value=False), NodeAnswer(question='4_1_4', value=False), NodeAnswer(question='CONTINUOUS', value=False), NodeAnswer(question='DIFFERS_BY_PROGRAM', value=False), NodeAnswer(question='OTHER_DESCRIBE', value=False)]
# subject='degrees_offered' fields=['certificate (boolean)', 'diploma (boolean)', 'associate (boolean)', 'transfer_associate (boolean)', 'terminal_associate (boolean)', "bachelor's (boolean)", "postbachelor's_certificate (boolean)", "master's (boolean)", "post-master's_certificate (boolean)", 'doctoral_degree_research_scholarship (boolean)', 'doctoral_degree_professional_practice (boolean)', 'doctoral_degree_other (boolean)']
# answers=[NodeAnswer(question='CERTIFICATE', value=False), NodeAnswer(question='DIPLOMA', value=False), NodeAnswer(question='ASSOCIATE', value=False), NodeAnswer(question='TRANSFER_ASSOCIATE', value=False), NodeAnswer(question='TERMINAL_ASSOCIATE', value=False), NodeAnswer(question="BACHELOR'S", value=True), NodeAnswer(question="POSTBACHELOR'S_CERTIFICATE", value=False), NodeAnswer(question="MASTER'S", value=True), NodeAnswer(question="POST-MASTER'S_CERTIFICATE", value=False), NodeAnswer(question='DOCTORAL_DEGREE_RESEARCH_SCHOLARSHIP', value=True), NodeAnswer(question='DOCTORAL_DEGREE_PROFESSIONAL_PRACTICE', value=True), NodeAnswer(question='DOCTORAL_DEGREE_OTHER', value=False)]
# answers=[NodeAnswer(question='CERTIFICATE', value=True), NodeAnswer(question='DIPLOMA', value=True), NodeAnswer(question='ASSOCIATE', value=True), NodeAnswer(question='TRANSFER_ASSOCIATE', value=True), NodeAnswer(question='TERMINAL_ASSOCIATE', value=True), NodeAnswer(question="BACHELOR'S", value=True), NodeAnswer(question="POSTBACHELOR'S_CERTIFICATE", value=True), NodeAnswer(question="MASTER'S", value=True), NodeAnswer(question="POST-MASTER'S_CERTIFICATE", value=True), NodeAnswer(question='DOCTORAL_DEGREE_RESEARCH_SCHOLARSHIP', value=True), NodeAnswer(question='DOCTORAL_DEGREE_PROFESSIONAL_PRACTICE', value=True), NodeAnswer(question='DOCTORAL_DEGREE_OTHER', value=True)]
# answers=[NodeAnswer(question='CERTIFICATE', value=False), NodeAnswer(question='DIPLOMA', value=False), NodeAnswer(question='ASSOCIATE', value=False), NodeAnswer(question='TRANSFER_ASSOCIATE', value=False), NodeAnswer(question='TERMINAL_ASSOCIATE', value=False), NodeAnswer(question="BACHELOR'S", value=True), NodeAnswer(question="POSTBACHELOR'S_CERTIFICATE", value=True), NodeAnswer(question="MASTER'S", value=True), NodeAnswer(question="POST-MASTER'S_CERTIFICATE", value=False), NodeAnswer(question='DOCTORAL_DEGREE_RESEARCH_SCHOLARSHIP', value=False), NodeAnswer(question='DOCTORAL_DEGREE_PROFESSIONAL_PRACTICE', value=False), NodeAnswer(question='DOCTORAL_DEGREE_OTHER', value=False)]
# answers=[NodeAnswer(question='CERTIFICATE', value=False), NodeAnswer(question='DIPLOMA', value=False), NodeAnswer(question='ASSOCIATE', value=False), NodeAnswer(question='TRANSFER_ASSOCIATE', value=False), NodeAnswer(question='TERMINAL_ASSOCIATE', value=False), NodeAnswer(question="BACHELOR'S", value=False), NodeAnswer(question="POSTBACHELOR'S_CERTIFICATE", value=False), NodeAnswer(question="MASTER'S", value=False), NodeAnswer(question="POST-MASTER'S_CERTIFICATE", value=False), NodeAnswer(question='DOCTORAL_DEGREE_RESEARCH_SCHOLARSHIP', value=True), NodeAnswer(question='DOCTORAL_DEGREE_PROFESSIONAL_PRACTICE', value=False), NodeAnswer(question='DOCTORAL_DEGREE_OTHER', value=False)]
# subject='diversity_equity_inclusion' fields=['url (string)', 'has_diversity_office (boolean)']
# answers=[NodeAnswer(question='URL', value='https://diversity.ua.edu/'), NodeAnswer(question='HAS_DIVERSITY_OFFICE', value=True)]
# answers=[NodeAnswer(question='URL', value='https://www.nyu.edu/life/global-inclusion-and-diversity.html'), NodeAnswer(question='HAS_DIVERSITY_OFFICE', value=True)]
# answers=[NodeAnswer(question='URL', value='https://diversity.wisc.edu'), NodeAnswer(question='HAS_DIVERSITY_OFFICE', value=True)]
# subject='enrollment_and_persistence' fields=['b_enrollment_and_persistence (boolean)']
# answers=[NodeAnswer(question='Question 1', value=True)]
# answers=[NodeAnswer(question='Question 1', value=True)]
# subject='institutional_enrollment' fields=['men_full_time_enrollment (number)', 'men_part_time_enrollment (number)', 'women_full_time_enrollment (number)', 'women_part_time_enrollment (number)', 'another_gender_full_time_enrollment (number)', 'another_gender_part_time_enrollment (number)', 'undergraduate_students_total (number)', 'undergraduate_students_part_time_total (number)', 'undergraduate_students_full_time_total (number)', 'undergraduate_degree_seeking_students_total (number)', 'undergraduate_degree_seeking_students_part_time_total (number)', 'undergraduate_degree_seeking_students_full_time_total (number)', 'graduate_students_total (number)', 'graduate_students_part_time_total (number)', 'graduate_students_full_time_total (number)', 'graduate_degree_seeking_students_total (number)', 'graduate_degree_seeking_students_part_time_total (number)', 'graduate_degree_seeking_students_full_time_total (number)']
# answers=[NodeAnswer(question='MEN_FULL_TIME_ENROLLMENT', value=None), NodeAnswer(question='MEN_PART_TIME_ENROLLMENT', value=None), NodeAnswer(question='WOMEN_FULL_TIME_ENROLLMENT', value=None), NodeAnswer(question='WOMEN_PART_TIME_ENROLLMENT', value=None), NodeAnswer(question='ANOTHER_GENDER_FULL_TIME_ENROLLMENT', value=None), NodeAnswer(question='ANOTHER_GENDER_PART_TIME_ENROLLMENT', value=None), NodeAnswer(question='UNDERGRADUATE_STUDENTS_TOTAL', value=None), NodeAnswer(question='UNDERGRADUATE_STUDENTS_PART_TIME_TOTAL', value=None), NodeAnswer(question='UNDERGRADUATE_STUDENTS_FULL_TIME_TOTAL', value=None), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_TOTAL', value=None), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_PART_TIME_TOTAL', value=None), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_FULL_TIME_TOTAL', value=None), NodeAnswer(question='GRADUATE_STUDENTS_TOTAL', value=None), NodeAnswer(question='GRADUATE_STUDENTS_PART_TIME_TOTAL', value=None), NodeAnswer(question='GRADUATE_STUDENTS_FULL_TIME_TOTAL', value=None), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_TOTAL', value=None), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_PART_TIME_TOTAL', value=None), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_FULL_TIME_TOTAL', value=None)]
# answers=[NodeAnswer(question='MEN_FULL_TIME_ENROLLMENT', value=20092), NodeAnswer(question='MEN_PART_TIME_ENROLLMENT', value=8), NodeAnswer(question='WOMEN_FULL_TIME_ENROLLMENT', value=23437), NodeAnswer(question='WOMEN_PART_TIME_ENROLLMENT', value=1913), NodeAnswer(question='ANOTHER_GENDER_FULL_TIME_ENROLLMENT', value=0), NodeAnswer(question='ANOTHER_GENDER_PART_TIME_ENROLLMENT', value=0), NodeAnswer(question='UNDERGRADUATE_STUDENTS_TOTAL', value=37817), NodeAnswer(question='UNDERGRADUATE_STUDENTS_PART_TIME_TOTAL', value=1691), NodeAnswer(question='UNDERGRADUATE_STUDENTS_FULL_TIME_TOTAL', value=36000), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_TOTAL', value=35665), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_PART_TIME_TOTAL', value=1664), NodeAnswer(question='UNDERGRADUATE_DEGREE_SEEKING_STUDENTS_FULL_TIME_TOTAL', value=34001), NodeAnswer(question='GRADUATE_STUDENTS_TOTAL', value=5670), NodeAnswer(question='GRADUATE_STUDENTS_PART_TIME_TOTAL', value=1171), NodeAnswer(question='GRADUATE_STUDENTS_FULL_TIME_TOTAL', value=10001), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_TOTAL', value=4974), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_PART_TIME_TOTAL', value=2172), NodeAnswer(question='GRADUATE_DEGREE_SEEKING_STUDENTS_FULL_TIME_TOTAL', value=10644)]
# subject='enrollment_data' fields=['part_time_enrollment_men (NUMBER)', 'part_time_enrollment_women (NUMBER)', 'part_time_enrollment_another_gender (NUMBER)', 'full_time_enrollment_men (NUMBER)', 'full_time_enrollment_women (NUMBER)', 'full_time_enrollment_another_gender (NUMBER)', 'total_part_time_enrollment_graduate_students (NUMBER)', 'total_full_time_enrollment_graduate_students (NUMBER)', 'total_all_graduate_students (NUMBER)', 'total_all_graduate_students_enrolled (NUMBER)']
# answers=[NodeAnswer(question='PART_TIME_ENROLLMENT_MEN', value=1222), NodeAnswer(question='PART_TIME_ENROLLMENT_WOMEN', value=1336), NodeAnswer(question='PART_TIME_ENROLLMENT_ANOTHER_GENDER', value=0), NodeAnswer(question='FULL_TIME_ENROLLMENT_MEN', value=2005), NodeAnswer(question='FULL_TIME_ENROLLMENT_WOMEN', value=1686), NodeAnswer(question='FULL_TIME_ENROLLMENT_ANOTHER_GENDER', value=0), NodeAnswer(question='TOTAL_PART_TIME_ENROLLMENT_GRADUATE_STUDENTS', value=348), NodeAnswer(question='TOTAL_FULL_TIME_ENROLLMENT_GRADUATE_STUDENTS', value=2005), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS', value=2676), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS_ENROLLED', value=2676)]
# answers=[NodeAnswer(question='PART_TIME_ENROLLMENT_MEN', value=225), NodeAnswer(question='PART_TIME_ENROLLMENT_WOMEN', value=205), NodeAnswer(question='PART_TIME_ENROLLMENT_ANOTHER_GENDER', value=0), NodeAnswer(question='FULL_TIME_ENROLLMENT_MEN', value=3418), NodeAnswer(question='FULL_TIME_ENROLLMENT_WOMEN', value=2970), NodeAnswer(question='FULL_TIME_ENROLLMENT_ANOTHER_GENDER', value=94), NodeAnswer(question='TOTAL_PART_TIME_ENROLLMENT_GRADUATE_STUDENTS', value=396), NodeAnswer(question='TOTAL_FULL_TIME_ENROLLMENT_GRADUATE_STUDENTS', value=6478), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS', value=6874), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS_ENROLLED', value=6912)]
# subject='total' fields=['total_all_undergraduates_men (number)', 'total_all_undergraduates_women (number)', 'total_all_undergraduates_another_gender (number)', 'total_all_undergraduates_total (number)', 'total_all_graduate_men (number)', 'total_all_graduate_women (number)', 'total_all_graduate_another_gender (number)', 'total_all_graduate_total (number)', 'grand_total_all_students_men (number)', 'grand_total_all_students_women (number)', 'grand_total_all_students_another_gender (number)', 'grand_total_all_students_total (number)', 'total_all_graduate_degree_seeking_students (number)', 'total_all_graduate_students_enrolled (number)']
# answers=[NodeAnswer(question='TOTAL_ALL_UNDERGRADUATES_MEN', value=15105), NodeAnswer(question='TOTAL_ALL_UNDERGRADUATES_WOMEN', value=18530), NodeAnswer(question='TOTAL_ALL_UNDERGRADUATES_ANOTHER_GENDER', value=1428), NodeAnswer(question='TOTAL_ALL_UNDERGRADUATES_TOTAL', value=35063), NodeAnswer(question='TOTAL_ALL_GRADUATE_MEN', value=3483), NodeAnswer(question='TOTAL_ALL_GRADUATE_WOMEN', value=4060), NodeAnswer(question='TOTAL_ALL_GRADUATE_ANOTHER_GENDER', value=814), NodeAnswer(question='TOTAL_ALL_GRADUATE_TOTAL', value=8357), NodeAnswer(question='GRAND_TOTAL_ALL_STUDENTS_MEN', value=18588), NodeAnswer(question='GRAND_TOTAL_ALL_STUDENTS_WOMEN', value=22590), NodeAnswer(question='GRAND_TOTAL_ALL_STUDENTS_ANOTHER_GENDER', value=2242), NodeAnswer(question='GRAND_TOTAL_ALL_STUDENTS_TOTAL', value=43420), NodeAnswer(question='TOTAL_ALL_GRADUATE_DEGREE_SEEKING_STUDENTS', value=None), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS_ENROLLED', value=None)]
# answers=[NodeAnswer(question='TOTAL_ALL_GRADUATE_DEGREE_SEEKING_STUDENTS', value=12816.0), NodeAnswer(question='TOTAL_ALL_GRADUATE_STUDENTS_ENROLLED', value=12816.0)]
# subject='enrollment_by_racial_ethnic_category' fields=['nonresident_aliens (number)', 'hispanic_latino (number)', 'black_or_african_american_non_hispanic (number)', 'white_non_hispanic (number)', 'american_indian_or_alaska_native_non_hispanic (number)', 'asian_non_hispanic (number)', 'native_hawaiian_or_other_pacific_islander_non_hispanic (number)', 'two_or_more_races_non_hispanic (number)', 'race_and_or_ethnicity_unknown (number)']
# answers=[NodeAnswer(question='Question 1. NONRESIDENT_ALIENS (NUMBER)', value=2825), NodeAnswer(question='Question 2. HISPANIC_LATINO (NUMBER)', value=2301), NodeAnswer(question='Question 3. BLACK_OR_AFRICAN_AMERICAN_NON_HISPANIC (NUMBER)', value=3779), NodeAnswer(question='Question 4. WHITE_NON_HISPANIC (NUMBER)', value=24623), NodeAnswer(question='Question 5. AMERICAN_INDIAN_OR_ALASKA_NATIVE_NON_HISPANIC (NUMBER)', value=87), NodeAnswer(question='Question 6. ASIAN_NON_HISPANIC (NUMBER)', value=489), NodeAnswer(question='Question 7. NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER_NON_HISPANIC (NUMBER)', value=32), NodeAnswer(question='Question 8. TWO_OR_MORE_RACES_NON_HISPANIC (NUMBER)', value=1520), NodeAnswer(question='Question 9. RACE_AND_OR_ETHNICITY_UNKNOWN (NUMBER)', value=1305)]
# answers=[NodeAnswer(question='NONRESIDENT_ALIENS (NUMBER)', value=661.0), NodeAnswer(question='HISPANIC_LATINO (NUMBER)', value=796.0), NodeAnswer(question='BLACK_OR_AFRICAN_AMERICAN_NON_HISPANIC (NUMBER)', value=235.0), NodeAnswer(question='WHITE_NON_HISPANIC (NUMBER)', value=4619.0), NodeAnswer(question='AMERICAN_INDIAN_OR_ALASKA_NATIVE_NON_HISPANIC (NUMBER)', value=22.0), NodeAnswer(question='ASIAN_NON_HISPANIC (NUMBER)', value=956.0), NodeAnswer(question='NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER_NON_HISPANIC (NUMBER)', value=3.0), NodeAnswer(question='TWO_OR_MORE_RACES_NON_HISPANIC (NUMBER)', value=417.0), NodeAnswer(question='RACE_AND_OR_ETHNICITY_UNKNOWN (NUMBER)', value=255.0)]

# %%
retriever = index.as_retriever(similarity_top_k=8)
retriever.retrieve("are there more women at nyu or penn state?")
# retriever.retrieve("which schools are in the south?")
# retriever = title_index.as_retriever(similarity_top_k=8)
# retriever.retrieve("how many women are at alabama, mississippi, nyu, penn, and madison?")
# Out:
# [NodeWithScore(node=TextNode(id_='57024bb0-11af-4ead-b9c4-daf33ef47835', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='penn-state.md FULL_TIME_ENROLLMENT_WOMEN: 2970', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.4362364717190708),
#  NodeWithScore(node=TextNode(id_='66249e2b-5c17-4790-9e7a-11e4d2c8c9b0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='penn-state.md PART_TIME_ENROLLMENT_WOMEN: 205', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.4178824872177374),
#  NodeWithScore(node=TextNode(id_='d1f9b713-c2a9-4ab0-8e84-6ea0c533e123', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md STATE: New York', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.4079935414592395),
#  NodeWithScore(node=TextNode(id_='67f8c339-b27c-442e-adbc-c66559e0cf4c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.3888216058208516),
#  NodeWithScore(node=TextNode(id_='df2b12ec-90b6-43a0-b2c2-2e5a27a7ccc9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md CITY: New York', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.37156402340898514),
#  NodeWithScore(node=TextNode(id_='9356bf4b-aece-477f-ba28-2719c21605e1', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md WOMENS_COLLEGE: False', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.36942785450178794),
#  NodeWithScore(node=TextNode(id_='6a432635-9345-47ef-94fb-26f07428fec0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md ADMISSIONS_OFFICE_MAILING_ADDRESS: 383 Lafayette Street, New York, New York, 10003, United States', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.36860566048771237),
#  NodeWithScore(node=TextNode(id_='49a5a2a3-150e-4aae-ad39-ba40d61c7d7d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='nyu.md FIRST_NAME: ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.35618682268879404)]
