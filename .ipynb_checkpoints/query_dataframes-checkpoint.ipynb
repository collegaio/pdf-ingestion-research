# %%
# load dataframes
import polars as pl

df_1 = pl.read_parquet("./datasets/cds/parquet/cu-boulder.parquet")
df_2 = pl.read_parquet("./datasets/cds/parquet/purdue.parquet")

print(df_1)
print(df_2)
# Out:
# shape: (1, 326)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ instituti ┆ are_first ┆ instituti ┆ instituti ┆ … ┆ total_par ┆ total_ful ┆ total_all ┆ total_al │
# │ on_requir ┆ _time_fir ┆ on_requir ┆ on_allow_ ┆   ┆ t_time_gr ┆ l_time_gr ┆ _graduate ┆ l_gradua │
# │ es_high_s ┆ st_year_s ┆ es_or_rec ┆ students_ ┆   ┆ aduate_de ┆ aduate_de ┆ _degree_s ┆ te_stude │
# │ cho…      ┆ tud…      ┆ omm…      ┆ to_…      ┆   ┆ gre…      ┆ gre…      ┆ eek…      ┆ nts_en…  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ bool      ┆ bool      ┆ bool      ┆ bool      ┆   ┆ i64       ┆ i64       ┆ null      ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ true      ┆ true      ┆ true      ┆ true      ┆ … ┆ 3552      ┆ 1489      ┆ null      ┆ 6989     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# shape: (1, 326)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ instituti ┆ are_first ┆ instituti ┆ instituti ┆ … ┆ total_par ┆ total_ful ┆ total_all ┆ total_al │
# │ on_requir ┆ _time_fir ┆ on_requir ┆ on_allow_ ┆   ┆ t_time_gr ┆ l_time_gr ┆ _graduate ┆ l_gradua │
# │ es_high_s ┆ st_year_s ┆ es_or_rec ┆ students_ ┆   ┆ aduate_de ┆ aduate_de ┆ _degree_s ┆ te_stude │
# │ cho…      ┆ tud…      ┆ omm…      ┆ to_…      ┆   ┆ gre…      ┆ gre…      ┆ eek…      ┆ nts_en…  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ bool      ┆ bool      ┆ bool      ┆ bool      ┆   ┆ i64       ┆ f64       ┆ i64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ true      ┆ true      ┆ true      ┆ false     ┆ … ┆ 6119      ┆ 6798.0    ┆ 12917     ┆ 13041.0  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# determine schema
cols = df_1.columns

dtype_counts = {col: {} for col in cols}

for i, dtype in enumerate(df_1.dtypes):
    col = cols[i]

    if dtype not in dtype_counts[col]:
        dtype_counts[col][dtype] = 1
    else:
        dtype_counts[col][dtype] += 1

for i, dtype in enumerate(df_2.dtypes):
    col = cols[i]

    if dtype not in dtype_counts[col]:
        dtype_counts[col][dtype] = 1
    else:
        dtype_counts[col][dtype] += 1

# print(dtype_counts)

for col in dtype_counts:
    dtypes = [dtype for dtype in dtype_counts[col]]
    if pl.Null not in dtypes and len(dtypes) > 1:
        print(col, ":", dtypes)
        print(df_1[col])
        print(df_2[col])
        
# combine datarames with possible null columns
# Out:
# {'institution_requires_high_school_completion': {Boolean: 2}, 'are_first_time_first_year_students_accepted_for_terms_other_than_the_fall': {Boolean: 2}, 'institution_requires_or_recommends_college_preparatory_program': {Boolean: 2}, 'institution_allow_students_to_postpone_enrollment_after_admission': {Boolean: 2}, 'maximum_period_of_postponement': {String: 1, Null: 1}, 'average_high_school_gpa': {Float64: 2}, 'percent_of_total_first_time_first_year_students_who_submitted_high_school_gpa': {Float64: 2}, 'do_tuition_and_fees_vary_by_undergraduate_instructional_program': {String: 2}, 'percent_of_full_time_undergraduates_pay_more_than_the_tuition_and_fees_reported_in_g1': {String: 1, Null: 1}, 'institution_has_application_closing_date': {Boolean: 2}, 'application_closing_date_fall': {Null: 2}, 'application_priority_date': {Null: 2}, 'has_waiting_list_policy': {Boolean: 2}, 'number_of_qualified_applicants_offered_a_place_on_waiting_list': {Int64: 2}, 'number_accepting_a_place_on_the_waiting_list': {Int64: 2}, 'number_of_wait_listed_students_admitted': {Int64: 2}, 'is_waiting_list_ranked': {Boolean: 2}, 'net_price_calculator_url': {String: 1, Null: 1}, 'tuition_and_fee_data_status': {Null: 1, String: 1}, 'academic_costs_available': {String: 2}, 'approximate_date_costs_available': {String: 1, Null: 1}, 'are_notifications_to_applicants_of_admission_decision_sent_on_a_rolling_basis': {Boolean: 1, Null: 1}, 'what_date_do_rolling_notifications_begin': {String: 1, Null: 1}, 'notifications_of_admission_decision_sent_by_date': {String: 1, Null: 1}, 'deadline_for_housing_deposits': {String: 2}, 'amount_of_housing_deposit_dollars': {Int64: 2}, 'housing_deposits_refundable_if_student_does_not_enroll': {Boolean: 2}, 'in_district_students_per_credit_hour_charge_tuition_only_dollars': {Null: 1, Int64: 1}, 'in_state_out_of_district_students_per_credit_hour_charge_tuition_only_dollars': {Null: 1, Int64: 1}, 'out_of_state_students_per_credit_hour_charge_tuition_only_dollars': {Null: 1, Int64: 1}, 'international_non_resident_students_per_credit_hour_charge_tuition_only_dollars': {Null: 1, Int64: 1}, 'has_application_fee': {Boolean: 2}, 'amount_of_application_fee_dollars': {Int64: 2}, 'can_the_fee_be_waived_for_applicants_with_financial_need': {Boolean: 2}, 'has_fee_if_applying_online': {Boolean: 1, String: 1}, 'can_the_fee_be_waived_for_students_with_financial_need': {Boolean: 2}, 'percent_in_top_tenth_of_high_school_graduating_class_percent': {Int64: 1, Float64: 1}, 'percent_in_top_quarter_of_high_school_graduating_class_percent': {Int64: 1, Float64: 1}, 'percent_in_top_half_of_high_school_graduating_class_percent': {Int64: 1, Float64: 1}, 'percent_in_bottom_half_of_high_school_graduating_class_percent': {Int64: 1, Float64: 1}, 'percent_in_bottom_quarter_of_high_school_graduating_class_percent': {Int64: 1, Float64: 1}, 'percent_of_total_first_time_first_year_students_who_submitted_high_school_class_rank_percent': {Int64: 1, Float64: 1}, 'institution_offers_early_decision_plan': {Boolean: 2}, 'first_or_only_early_decision_plan_closing_date': {Null: 2}, 'first_or_only_early_decision_plan_notification_date': {Null: 2}, 'other_early_decision_plan_closing_date': {Null: 2}, 'other_early_decision_plan_notification_date': {Null: 2}, 'number_of_early_decision_applications_received_by_your_institution': {Null: 2}, 'number_of_applicants_admitted_under_early_decision_plan': {Null: 2}, 'significant_details_about_early_decision_plan': {String: 1, Null: 1}, 'has_a_nonbinding_early_action_plan': {Boolean: 2}, 'early_action_closing_date': {Null: 1, String: 1}, 'early_action_notification_date': {String: 2}, 'is_your_early_action_plan_a_restrictive_plan_under_which_you_limit_students_from_applying_to_other_early_plans': {Null: 1, Boolean: 1}, 'number_of_early_action_applications_received_by_your_institution': {Null: 2}, 'number_of_applicants_admitted_under_early_action_plan': {Null: 2}, 'number_of_applicants_enrolled_under_early_action_plan': {Null: 2}, 'estimated_exp ...
# has_fee_if_applying_online : [Boolean, String]
# shape: (1,)
# Series: 'has_fee_if_applying_online' [bool]
# [
# 	true
# ]
# percent_in_top_tenth_of_high_school_graduating_class_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_in_top_tenth_of_high_school_graduating_class_percent' [i64]
# [
# 	25
# ]
# percent_in_top_quarter_of_high_school_graduating_class_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_in_top_quarter_of_high_school_graduating_class_percent' [i64]
# [
# 	52
# ]
# percent_in_top_half_of_high_school_graduating_class_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_in_top_half_of_high_school_graduating_class_percent' [i64]
# [
# 	83
# ]
# percent_in_bottom_half_of_high_school_graduating_class_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_in_bottom_half_of_high_school_graduating_class_percent' [i64]
# [
# 	17
# ]
# percent_in_bottom_quarter_of_high_school_graduating_class_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_in_bottom_quarter_of_high_school_graduating_class_percent' [i64]
# [
# 	2
# ]
# percent_of_total_first_time_first_year_students_who_submitted_high_school_class_rank_percent : [Int64, Float64]
# shape: (1,)
# Series: 'percent_of_total_first_time_first_year_students_who_submitted_high_school_class_rank_percent' [i64]
# [
# 	43
# ]
# percent_who_had_gpa_of_4 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_of_4' [i64]
# [
# 	41
# ]
# percent_who_had_gpa_between_3_75_and_3_99 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_3_75_and_3_99' [i64]
# [
# 	20
# ]
# percent_who_had_gpa_between_3_50_and_3_74 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_3_50_and_3_74' [i64]
# [
# 	19
# ]
# percent_who_had_gpa_between_3_25_and_3_49 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_3_25_and_3_49' [i64]
# [
# 	11
# ]
# percent_who_had_gpa_between_3_00_and_3_24 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_3_00_and_3_24' [i64]
# [
# 	5
# ]
# percent_who_had_gpa_between_2_50_and_2_99 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_2_50_and_2_99' [i64]
# [
# 	3
# ]
# percent_who_had_gpa_between_1_0_and_1_99 : [Int64, Float64]
# shape: (1,)
# Series: 'percent_who_had_gpa_between_1_0_and_1_99' [i64]
# [
# 	0
# ]
# total_first_time_first_year_out_of_state_applied : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_out_of_state_applied' [i64]
# [
# 	40264
# ]
# total_first_time_first_year_international_applied : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_international_applied' [i64]
# [
# 	2179
# ]
# total_first_time_first_year_total_applied : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_total_applied' [i64]
# [
# 	57541
# ]
# total_first_time_first_year_in_state_admitted : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_in_state_admitted' [i64]
# [
# 	13749
# ]
# total_first_time_first_year_total_admitted : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_total_admitted' [i64]
# [
# 	46693
# ]
# total_first_time_first_year_in_state_enrolled : [Int64, Float64]
# shape: (1,)
# Series: 'total_first_time_first_year_in_state_enrolled' [i64]
# [
# 	4016
# ]
# final_2016_cohort_no_pell_grant_or_stafford_loan : [Int64, Float64]
# shape: (1,)
# Series: 'final_2016_cohort_no_pell_grant_or_stafford_loan' [i64]
# [
# 	4599
# ]
# initial_2017_cohort_subsidized_stafford_loan_recipients : [Int64, Float64]
# shape: (1,)
# Series: 'initial_2017_cohort_subsidized_stafford_loan_recipients' [i64]
# [
# 	850
# ]
# initial_2017_cohort_no_pell_grant_or_subsized_loan : [Int64, Float64]
# shape: (1,)
# Series: 'initial_2017_cohort_no_pell_grant_or_subsized_loan' [i64]
# [
# 	4627
# ]
# initial_2017_cohort_total : [Int64, Float64]
# shape: (1,)
# Series: 'initial_2017_cohort_total' [i64]
# [
# 	6482
# ]
# final_2017_cohort_subsidized_stafford_loan_recipients : [Int64, Float64]
# shape: (1,)
# Series: 'final_2017_cohort_subsidized_stafford_loan_recipients' [i64]
# [
# 	850
# ]
# final_2017_cohort_no_pell_grant_or_subsized_loan : [Int64, Float64]
# shape: (1,)
# Series: 'final_2017_cohort_no_pell_grant_or_subsized_loan' [i64]
# [
# 	4622
# ]
# final_2017_cohort_total : [Int64, Float64]
# shape: (1,)
# Series: 'final_2017_cohort_total' [i64]
# [
# 	6476
# ]
# international_nonresidents_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'international_nonresidents_degree_seeking_first_time_first_year' [i64]
# [
# 	132
# ]
# international_nonresidents_degree_seeking_undergraduates : [Int64, Float64]
# shape: (1,)
# Series: 'international_nonresidents_degree_seeking_undergraduates' [i64]
# [
# 	861
# ]
# hispanic_latino_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'hispanic_latino_degree_seeking_first_time_first_year' [i64]
# [
# 	1048
# ]
# black_or_african_american_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'black_or_african_american_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	147
# ]
# white_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'white_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	5067
# ]
# white_non_hispanic_degree_seeking_undergraduates : [Int64, Float64]
# shape: (1,)
# Series: 'white_non_hispanic_degree_seeking_undergraduates' [i64]
# [
# 	21471
# ]
# american_indian_or_alaska_native_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'american_indian_or_alaska_native_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	8
# ]
# asian_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'asian_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	519
# ]
# asian_non_hispanic_degree_seeking_undergraduates : [Int64, Float64]
# shape: (1,)
# Series: 'asian_non_hispanic_degree_seeking_undergraduates' [i64]
# [
# 	1963
# ]
# native_hawaiian_or_other_pacific_islander_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'native_hawaiian_or_other_pacific_islander_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	10
# ]
# native_hawaiian_or_other_pacific_islander_non_hispanic_degree_seeking_undergraduates : [Int64, Float64]
# shape: (1,)
# Series: 'native_hawaiian_or_other_pacific_islander_non_hispanic_degree_seeking_undergraduates' [i64]
# [
# 	35
# ]
# two_or_more_races_non_hispanic_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'two_or_more_races_non_hispanic_degree_seeking_first_time_first_year' [i64]
# [
# 	560
# ]
# race_and_or_ethnicity_unknown_degree_seeking_first_time_first_year : [Int64, Float64]
# shape: (1,)
# Series: 'race_and_or_ethnicity_unknown_degree_seeking_first_time_first_year' [i64]
# [
# 	55
# ]
# race_and_or_ethnicity_unknown_total_undergraduates : [Int64, Float64]
# shape: (1,)
# Series: 'race_and_or_ethnicity_unknown_total_undergraduates' [i64]
# [
# 	307
# ]
# undergraduate_students_degree_seeking_first_time_first_year_men_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_degree_seeking_first_time_first_year_men_full_time_enrollment' [i64]
# [
# 	3753
# ]
# undergraduate_students_degree_seeking_first_time_first_year_men_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_degree_seeking_first_time_first_year_men_part_time_enrollment' [i64]
# [
# 	47
# ]
# undergraduate_students_degree_seeking_first_time_first_year_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_degree_seeking_first_time_first_year_women_full_time_enrollment' [i64]
# [
# 	3792
# ]
# undergraduate_students_degree_seeking_first_time_first_year_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_degree_seeking_first_time_first_year_women_part_time_enrollment' [i64]
# [
# 	50
# ]
# undergraduate_students_other_first_year_degree_seeking_men_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_other_first_year_degree_seeking_men_part_time_enrollment' [i64]
# [
# 	106
# ]
# undergraduate_students_other_first_year_degree_seeking_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_other_first_year_degree_seeking_women_part_time_enrollment' [i64]
# [
# 	84
# ]
# undergraduate_students_all_other_degree_seeking_men_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_all_other_degree_seeking_men_full_time_enrollment' [i64]
# [
# 	10793
# ]
# undergraduate_students_all_other_degree_seeking_men_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_all_other_degree_seeking_men_part_time_enrollment' [i64]
# [
# 	1006
# ]
# undergraduate_students_all_other_degree_seeking_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_all_other_degree_seeking_women_full_time_enrollment' [i64]
# [
# 	9365
# ]
# undergraduate_students_all_other_degree_seeking_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_all_other_degree_seeking_women_part_time_enrollment' [i64]
# [
# 	611
# ]
# undergraduate_students_total_degree_seeking_men_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_total_degree_seeking_men_part_time_enrollment' [i64]
# [
# 	1159
# ]
# undergraduate_students_total_degree_seeking_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_total_degree_seeking_women_full_time_enrollment' [i64]
# [
# 	14051
# ]
# undergraduate_students_total_degree_seeking_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'undergraduate_students_total_degree_seeking_women_part_time_enrollment' [i64]
# [
# 	745
# ]
# total_undergraduate_students_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'total_undergraduate_students_women_full_time_enrollment' [i64]
# [
# 	14086
# ]
# total_undergraduate_students_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'total_undergraduate_students_women_part_time_enrollment' [i64]
# [
# 	929
# ]
# total_all_undergraduate_students_enrolled : [Int64, Float64]
# shape: (1,)
# Series: 'total_all_undergraduate_students_enrolled' [i64]
# [
# 	32100
# ]
# graduate_students_degree_seeking_first_time_men_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'graduate_students_degree_seeking_first_time_men_part_time_enrollment' [i64]
# [
# 	360
# ]
# graduate_students_degree_seeking_first_time_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'graduate_students_degree_seeking_first_time_women_full_time_enrollment' [i64]
# [
# 	518
# ]
# graduate_students_degree_seeking_first_time_women_part_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'graduate_students_degree_seeking_first_time_women_part_time_enrollment' [i64]
# [
# 	254
# ]
# total_graduate_students_women_full_time_enrollment : [Int64, Float64]
# shape: (1,)
# Series: 'total_graduate_students_women_full_time_enrollment' [i64]
# [
# 	1375
# ]
# total_full_time_graduate_degree_seeking_students : [Int64, Float64]
# shape: (1,)
# Series: 'total_full_time_graduate_degree_seeking_students' [i64]
# [
# 	1489
# ]
# total_all_graduate_students_enrolled : [Int64, Float64]
# shape: (1,)
# Series: 'total_all_graduate_students_enrolled' [i64]
# [
# 	6989
# ]
