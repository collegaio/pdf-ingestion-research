# %%
import os
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_parse import LlamaParse
import nest_asyncio; nest_asyncio.apply()

llama_cloud_api_key = os.environ["LLAMA_CLOUD_API_KEY"]
openai_api_key = os.environ["OPENAI_API_KEY"]

# set up parser
parser = LlamaParse(
    result_type="markdown",  # "markdown" and "text" are available
    api_key=llama_cloud_api_key,
    gpt4o_mode=True,
    gpt4o_api_key=openai_api_key,
)

# use SimpleDirectoryReader to parse our file
file_extractor = {".pdf": parser}
# reader = SimpleDirectoryReader(input_dir='./datasets/cds/pdf', file_extractor=file_extractor)
# reader = SimpleDirectoryReader(input_files=['./datasets/cds/pdf/Brigham Young University CDS_2023-2024.pdf'], file_extractor=file_extractor)
reader = SimpleDirectoryReader(input_files=['./datasets/cds/md/mississippi-state.md'])
documents = await reader.aload_data()

documents
# print("documents loaded:", len(documents))
# Out:
# [Document(id_='09a93438-991e-4020-9a42-db09f7d3997c', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a28b3117-cdec-4c1d-b1fa-42edfc7a7cfa', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='f94e666c-2e18-45d3-a9d5-fea5ed9a6107', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nA. General Information\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0c523745-e70d-4d84-ab76-9a6598826c0d', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nA0. Respondent Information\n\n| **Office:** | Office of Institutional Research and Effectiveness |\n|-------------|----------------------------------------------------|\n| **Address:** | P.O. Drawer EY |\n| **City:** | Mississippi State |\n| **State:** | Mississippi |\n| **Zip:** | 39762 |\n| **Country:** | United States |\n| **Phone Number:** | 662-325-3920 |\n| **Email Address:** | oir@ir.msstate.edu |\n\nAre your responses to the CDS posted for reference on your institution's website?  \n**Yes**\n\nIf yes, please provide a direct link to the posted CDS responses:  \nhttps://ir.msstate.edu/cdsets.php\n", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8e38672f-6858-45cb-affc-bfdb86eacd04', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nA1. Address Information\n\n**Please enter general institution information below:**\n\n| **Name of College or University** | Mississippi State University |\n|-----------------------------------|------------------------------|\n| **Street Address:** | 75 B.S. Hood Road |\n| **City:** | Mississippi State |\n| **State:** | Mississippi |\n| **Zip:** | 39762 |\n| **Country:** | United States |\n| **Main Institution Phone Number:** | 662-325-2323 |\n| **Main Institution Website:** | https://www.msstate.edu/ |\n\n**Please enter Admissions Office information below:**\n\n| **Street Address:** | 25 Old Main |\n|---------------------|-------------|\n| **City:** | Mississippi State |\n| **State:** | Mississippi |\n| **Zip:** | 39762 |\n| **Country:** | United States |\n| **Admissions Phone Number:** | 662-325-2224 |\n| **Admissions Website:** | https://www.admissions.msstate.edu/ |\n| **Admissions Email Address:** | admit@msstate.edu |\n\nIs there a separate URL for your school's online application? If yes, please specify:  \nhttps://apply.msstate.edu\n\nIf you have a mailing address other than the one listed above to which applications should be sent, please provide:  \nP.O. Box 6334  \nMississippi State  \nMississippi 39762\n\n*Updated: 2/13/2024*\n---", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='65ec3aa7-72c4-4bec-85cf-76cdb8e36309', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='38943783-67fb-4a36-aced-c519a1e89df4', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='27bceec5-eea1-4348-bb80-3e9afe0aa674', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nA2. Source of Institutional Control: (click to select from dropdown)\n**Public**\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='18a7af3f-c798-4150-88cf-7071f175adff', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nA3. Classify your undergraduate institution: (click to select from dropdown)\n**Coeducational**\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='6e32f259-e76d-448b-933e-f387cb9ec4aa', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nA4. Academic year calendar: (click to select from dropdown)\n**Semester**\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='f42fc0dd-8979-4a58-a05d-5271d05271ec', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nA5. Degrees offered by your institution (select all that apply).\n\n- [x] Certificate\n- [ ] Diploma\n- [ ] Associate\n- [ ] Terminal\n- [ ] Transfer\n- [x] Bachelor's\n- [x] Post-Bachelor's certificate\n- [x] Master's\n- [ ] Post-Master's certificate\n- [x] Doctoral degree - research/scholarship\n- [ ] Doctoral degree - professional practice\n- [ ] Doctoral degree - other\n", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='6773d76c-be92-4c24-9602-703d689a8d28', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nA6. Diversity, Equity, and Inclusion\nIf you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:  \nhttps://www.oidi.msstate.edu/\n\n*Updated: 2/13/2024*  \n*A. General Information*  \n*Common Data Set 2023-24*\n---', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1f9ed85a-4725-4705-bac3-aa7aa6ecc61a', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='63e31f58-0012-4d6c-877b-2cbf75cd40e9', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a1ce2b60-0d11-47cf-90a4-ad7930e1d508', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nB. ENROLLMENT AND PERSISTENCE\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e67cfdbd-9196-497a-b872-16780bd0cba1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nB1. Institutional Enrollment\nProvide numbers of students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n|                            | Men |        |        | Women |        |        | Another Gender |        |\n|----------------------------|-----|--------|--------|-------|--------|--------|----------------|--------|\n|                            | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment |\n| UNDERGRADUATE STUDENTS     |     |        |        |       |        |        |                |        |\n| Degree-seeking first-time, first-year students | 1,673 | 9      | 2,059  | 10    | 0      | 0      |\n| Other first-year, degree-seeking students      | 823   | 79     | 765    | 82    | 0      | 0      |\n| All other degree-seeking undergraduate students | 5,369 | 756    | 5,640  | 573   | 0      | 0      |\n| **Total degree-seeking undergraduate students** | **7,865** | **844** | **8,464** | **665** | **0** | **0** |\n| All other undergraduates enrolled in credit courses | 144   | 87     | 110    | 51    | 0      | 0      |\n| **Total Undergraduate Students**               | **8,009** | **931** | **8,574** | **716** | **0** | **0** |\n\n- Total part-time undergraduate degree-seeking students: **1,509**\n- Total full-time undergraduate degree-seeking students: **16,329**\n- Total of all undergraduate degree-seeking students: **17,838**\n- Total of all undergraduate students enrolled: **18,230**\n\n|                            | Men |        |        | Women |        |        | Another Gender |        |\n|----------------------------|-----|--------|--------|-------|--------|--------|----------------|--------|\n|                            | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment |\n| GRADUATE STUDENTS          |     |        |        |       |        |        |                |        |\n| Degree-seeking first-time  | 219   | 129    | 270    | 155   | 0      | 0      |\n| All other degree-seeking   | 720   | 865    | 1,067  | 931   | 0      | 0      |\n| All other graduates enrolled in credit courses | 4     | 26     | 3      | 38    | 0      | 0      |\n| **Total Graduate Students** | **943** | **1,020** | **1,340** | **1,124** | **0** | **0** |\n\n- Total part-time graduate degree-seeking students: **2,080**\n- Total full-time graduate degree-seeking students: **2,276**\n- Total of all graduate degree-seeking students: **4,356**\n- Total of all graduate students enrolled: **4,427**\n\n*Updated: 2/13/2024*\n---', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='74f037dd-3f51-4502-bdde-2704ba644f9e', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='efce62b1-33af-493f-8689-130332bc0378', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8c9cf056-d277-4a2a-b7b9-3a088f631216', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nB2. Enrollment by Racial/Ethnic Category\n\nProvide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n|                                | Degree-seeking, First-time, First-year | Degree-seeking Undergraduates (include first-time, first-year) | Total Undergraduates (both degree-seeking and non-degree-seeking) |\n|--------------------------------|----------------------------------------|---------------------------------------------------------------|-------------------------------------------------------------------|\n| International (nonresidents)   | 73                                     | 230                                                           | 238                                                               |\n| Hispanic/Latino                | 160                                    | 746                                                           | 761                                                               |\n| Black or African American, non-Hispanic | 620                            | 2,634                                                         | 2,733                                                             |\n| White, non-Hispanic            | 2,677                                  | 13,236                                                        | 13,452                                                            |\n| American Indian or Alaska Native, non-Hispanic | 16                      | 86                                                            | 87                                                                |\n| Asian, non-Hispanic            | 56                                     | 291                                                           | 299                                                               |\n| Native Hawaiian or other Pacific Islander, non-Hispanic | 0              | 7                                                             | 7                                                                 |\n| Two or more races, non-Hispanic | 115                                   | 472                                                           | 482                                                               |\n| Race and/or ethnicity unknown  | 34                                     | 136                                                           | 171                                                               |\n| **Total**                      | **3,751**                              | **17,838**                                                    | **18,230**                                                        |\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='545dff19-f8be-4ff6-822d-288c8f6a7c37', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nB3. Persistence / Degrees\n\nNumber of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n\n| Degree Type                                | Number of Degrees Awarded |\n|--------------------------------------------|---------------------------|\n| Bachelor's Degrees                         | 4,541                     |\n| Post-Bachelor's Degrees                    |                           |\n| Master's Degrees                           | 1,129                     |\n| Post-Master's Degrees                      | 39                        |\n| Doctoral degree - research/scholarship     | 148                       |\n| Doctoral degree - professional practice    | 93                        |\n\n*Updated: 2/13/2024*\n\n*B. Enrollment and Persistence*\n\n*Common Data Set 2023-24*\n---", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d80ed288-24c8-409f-8ca0-aaa8b11400b4', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d445102c-28b9-456c-94a2-4d4823ea531b', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8261dc50-34fe-4c9e-8c9f-c37eef3b3628', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nB4 - B21. Graduation Rates\n\nThe items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System's Graduation Rate Survey (GRS).\n\n**For Bachelor's or Equivalent Programs: Please provide data for the Fall 2017 cohort if available. If Fall 2017 cohort data are not available, provide data for the Fall 2016 cohort.**\n\n| 2016 COHORT | Recipients of a Federal Pell Grant | Recipients of a Subsidized Stafford Loan, who did not receive a Pell Grant | Students who did not receive either a Pell Grant or a subsidized Stafford Loan | Total |\n|-------------|------------------------------------|------------------------------------------------------|----------------------------------------------------------|-------|\n| A. Initial 2016 cohort of first-time, full-time, bachelor's (or equivalent) degree-seeking undergraduate students | 1,180 | 535 | 1,902 | 3,617 |\n| B. Of the initial 2016 cohort, how many did not persist and did not graduate for any of the following reasons (report total allowable exclusions) | 1 | 0 | 1 | 2 |\n| - Deceased | | | | |\n| - Permanently Disabled | | | | |\n| - Armed Forces | | | | |\n| - Foreign Aid Service of the Federal Government | | | | |\n| C. Final 2016 cohort, after adjusting for allowable exclusions | 1,179 | 535 | 1,901 | 3,615 |\n| D. Of the initial 2016 cohort, how many completed the program in four years or less (by Aug. 31, 2020)? | 553 | 330 | 1,398 | 2,281 |\n| E. Of the initial 2016 cohort, how many completed the program in more than four years but in five years or less (after Aug. 31, 2020 and by Aug. 31, 2021)? | 307 | 215 | 952 | 1,474 |\n| F. Of the initial 2016 cohort, how many completed the program in more than five years but in six years or less (after Aug. 31, 2021 and by Aug. 31, 2022)? | 188 | 96 | 385 | 669 |\n| G. Total graduating within six years (Sum of D., E., and F.) | 1,048 | 641 | 2,735 | 4,424 |\n| H. Six-year graduation rate for 2016 cohort (G. divided by C.) | 46.9% | 61.7% | 73.5% | 63.1% |\n", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='17d9c9de-866e-4ac6-b539-ff26daec5b82', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nB22. Retention Rates\n\nFor the cohort of all full-time bachelor's (or equivalent) degree-seeking undergraduate students who entered your institution as first-year students in Fall 2022 (or the preceding summer term), what percentage was enrolled at your institution as of the date your institution calculates its official enrollment in Fall 2023.\n\n**Enter retention rate:** 83%\n\n---\n\n*Updated: 2/13/2024*\n\n*B. Enrollment and Persistence*\n\n*Common Data Set 2023-24*\n---", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='dcaad0a6-a7e3-4d5c-8efb-f6929c58adc7', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b26a88ed-a7c8-4141-9936-952df1f9b33d', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a9f8269d-4164-46b9-a73b-76fa98234078', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC. FIRST-TIME, FIRST-YEAR ADMISSION\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4af99c72-4b80-4335-bb56-e1bb031ffb07', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC1. Applications: First-time, First-year Students\nProvide the number of degree-seeking, first-time, first-year students who applied, were admitted, and enrolled (full- or part-time) in Fall 2023.\n\n| | Men | Women | Unknown Gender | Total |\n|---|---|---|---|---|\n| Total first-time, first-year students who applied in Fall 2023 | 8,895 | 11,937 | 45 | 20,877 |\n| Total first-time, first-year students admitted in Fall 2023 | 6,857 | 9,049 | 28 | 15,934 |\n| Total first-time, first-year students enrolled in Fall 2023 | 1,682 | 2,069 | 0 | 3,751 |\n| Full-time, first-time, first-year students enrolled in Fall 2023 | 1,673 | 2,059 | 0 | 3,732 |\n| Part-time, first-time, first-year students enrolled in Fall 2023 | 9 | 10 | 0 | 19 |\n\n| | In-State | Out-of-State | International | Total |\n|---|---|---|---|---|\n| Total first-time, first-year (degree seeking) who applied | 7,377 | 11,877 | 1,623 | 20,877 |\n| Total first-time, first-year (degree seeking) who were admitted | 5,654 | 9,529 | 751 | 15,934 |\n| Total first-time, first-year (degree seeking) enrolled | 2,068 | 1,611 | 72 | 3,751 |\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='083481a6-6e3a-431d-a965-d4bd9ae668d6', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC2. Applications: First-time, First-year Wait-Listed Students\nStudents who met admission requirements but whose final admission was contingent on space availability.\n\nDo you have a policy of placing students on a waiting list? **No**\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1972c6b7-4d64-430e-8a51-c18c9391d37f', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC3. Admission Requirements: High School Completion Requirement\nDoes your institution require high school completion for degree-seeking entering students?\n\n**High school diploma is required and GED is accepted**\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5e083e8d-63a6-4dc7-b72a-67e383f05901', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC4. Admission Requirements: General College-Preparatory Program\nDoes your institution require OR recommend a general college-preparatory program for degree-seeking students?\n\n| | |\n|---|---|\n| Require |  |\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c0cd14b9-181e-4c9f-8fbb-f9a512c794d7', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC5. Admission Requirements: High School Units Required/Recommended\nSpecify the distribution of academic high school course units required and/or recommend of all or most degree-seeking students using Carnegie units (one unit equals one year of study or its equivalent). If you use a different system, please convert to Carnegie.\n\n| Units | Units Required | Units Recommended |\n|---|---|---|\n| Total Academic Units | 18 | 20 |\n| English | 4 | 4 |\n| Mathematics | 4 | 4 |\n| Science | 3 | 4 |\n| of Science Units, how many units must be lab | 3 | 4 |\n| Foreign Language |  |  |\n| Social Studies | 3 | 4 |\n| History |  |  |\n| Computer Science | 1 |  |\n| Visual/Performing Arts | 1 | 1 |\n| Academic Electives | 2 | 2 |\n\n*Updated: 2/13/2024*\n\n*Common Data Set 2023-24*\n---', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='49f09a2c-b779-4186-b466-ac05f6fa3c1a', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d83f8c3c-cc8d-4387-ac98-847f030914bd', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='46df1f25-700c-47ea-8d8e-b5ef6c34d14e', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC6. Basis for Selection: Open Admission Policy\n\nDoes your institution have an open admission policy, under which virtually all secondary school graduates or students with GED equivalency diplomas are admitted without regard to academic record, test scores, or other qualifications?\n\n|   |   |\n|---|---|\n|   | No |\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b1d4d73c-e34c-4f71-a633-e8a2151825b1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nC7. Basis for Selection: Relative Importance of Factors in Admission Decisions\n\nPlease indicate the relative importance of each of the following academic and non-academic factors in your first-time, first-year degree-seeking general admission decisions (not including programs with specific criteria): *select from the dropdown menus*.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a0531032-cd1f-42a6-acb1-e01ab6b33904', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nACADEMIC\n\n| Factor | Importance |\n|--------|-------------|\n| Rigor of secondary school record | Considered |\n| Class rank | Important |\n| Academic Grade Point Average (GPA) | Very Important |\n| Recommendations | Not Considered |\n| Standardized test scores | Considered |\n| Application essay | Not Considered |\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='6dee1f07-24a8-4d67-9fba-facda01cde60', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nNONACADEMIC\n\n| Factor | Importance |\n|--------|-------------|\n| Interview | Not Considered |\n| Extracurricular activities | Not Considered |\n| Talent/ability | Not Considered |\n| Character/personal qualities | Not Considered |\n| First generation | Not Considered |\n| Alumni/ae relation | Not Considered |\n| Geographical residence | Not Considered |\n| State residency | Not Considered |\n| Religious affiliation/commitment | Not Considered |\n| Volunteer work | Not Considered |\n| Work experience | Not Considered |\n| Level of applicant's interest | Not Considered |\n", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7fad6fd1-29ba-4ef7-9212-b4577b9ad0e1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nC8. SAT and ACT Policies\n\nDoes your institution make use of SAT or ACT scores in admissions decisions for first-time, first-year, degree-seeking applicants?\n\n|   |   |\n|---|---|\n|   | Yes |\n\nIf yes, please select the appropriate response from the dropdown menus for each possible option below for admission for Fall 2025.\n\n| SAT and/or ACT | Considered if submitted |\n\nDoes your institution use applicants' test scores for academic advising?\n\n|   |   |\n|---|---|\n|   | Yes |\n\nPlease indicate which tests your institution uses for placement (e.g. state tests):\n\n|   |   |   |   |\n|---|---|---|---|\n| ☑ SAT | ☐ CLEP | ☐ AP |   |\n| ☑ ACT | ☐ Institutional Exam | ☐ State Exam |   |\n\n*Updated: 2/13/2024*\n\n*Common Data Set 2023-24*\n---", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='88dda97a-bad1-42a7-b9d3-0607d4eafa20', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5d58ec90-7ce2-423c-8dc8-9c1fa897981c', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  Document(id_='ab2b81d7-4409-46a7-acc2-c61c08b26f7c', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nI. INSTRUCTIONAL FACULTY AND CLASS SIZE\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0d54699b-3547-401f-8318-619f7bbf2d96', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nI1. Instructional Faculty by Category\nPlease report the number of instructional faculty members in each category for Fall 2023. Include faculty who are on your institution’s payroll on the census date your institution uses for IPEDS/AAUP.\n\n| Category                                                                 | Full-Time | Part-Time | Total |\n|--------------------------------------------------------------------------|-----------|-----------|-------|\n| A. Total number of instructional faculty                                 | 1081      | 377       | 1458  |\n| B. Total number who are members of minority groups                       | 227       | 88        | 315   |\n| C. Total number who are women                                            | 489       | 211       | 700   |\n| D. Total number who are men                                              | 592       | 166       | 758   |\n| E. Total number who are international (non-residents)                    | 66        | 9         | 75    |\n| F. Total number with doctorate, or other terminal degrees                | 892       | 149       | 1041  |\n| G. Total number whose highest degree is a master’s but not a terminal master’s | 176       | 150       | 326   |\n| H. Total number whose highest degree is a bachelor’s                     | 8         | 61        | 69    |\n| I. Total number whose highest degree is unknown or other                 | 5         | 17        | 22    |\n| J. Total number in stand-alone graduate/professional programs in which faculty teach virtually only graduate-level students | 0         | 0         | 0     |\n\n**NOTE:** Rows F, G, H and I should equal row A.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b4e39291-a955-49c6-bc80-60e5660135d1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nI2. Student to Faculty Ratio\nReport the Fall 2023 ratio of full-time equivalent students (full-time plus 1/3 part time) to full-time equivalent instructional faculty (full time plus 1/3 part time). In the ratio calculation, exclude both faculty and students in stand-alone graduate or professional programs such as medicine, law, veterinary, dentistry, social work, business, or public health in which faculty teach virtually only graduate level students.\n\nDo not count undergraduate or graduate student teaching assistants as faculty.\n\n| Fall 2023 Student to Faculty Ratio: | 16 | to | 1 |\n|-------------------------------------|----|----|---|\n| Ratio is based on number of students: | 19,652 |\n| Ratio is based on number of faculty:  | 1,207  |\n\n---\n\n*Updated: 2/13/2024*\n\n*Common Data Set 2023-24*\n---', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='bab9f02f-110d-46e5-ac3f-8377bf65d21d', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ca137cd4-62a0-48c4-8d83-f8bee7b1dcd1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3a4413d9-0132-4d46-92c4-b66f1d3508e1', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nI3. Undergraduate Class Size\n\nIn the table below, please report information about the size of classes and class sections offered in the Fall 2023 term.\n\n**Class Sections:** A class section is an organized course offered for credit, identified by discipline and number, meeting at a stated time or times in a classroom or similar setting, and not a subsection such as a laboratory or discussion session. Undergraduate class sections are defined as any sections in which at least one degree-seeking undergraduate student is enrolled for credit. Exclude distance learning classes and noncredit classes and individual instruction such as dissertation or thesis research, music instruction, or one-to-one readings. Exclude students in independent study, co-operative programs, internships, foreign language taped tutor sessions, practicums, and all students in one-on-one classes. Each class section should be counted only once and should not be duplicated because of course catalog cross-listings.\n\n**Class Subsections:** A class subsection includes any subsection of a course, such as laboratory, recitation, and discussion subsections that are supplementary in nature and are scheduled to meet separately from the lecture portion of the course. Undergraduate subsections are defined as any subsections of courses in which degree-seeking undergraduate students enrolled for credit. As above, exclude noncredit classes and individual instruction such as dissertation or thesis research, music instruction, or one-to-one readings. Each class subsection should be counted only once and should not be duplicated because of cross-listings.\n\nUsing the above definitions, please report for each of the following class-size intervals the number of class sections and class subsections offered in Fall 2023. For example, a lecture class with 800 students who meet at another time in 40 separate labs with 20 students should be counted once in the "100+" column in the class section column and 40 times under the "20-29" column of the class subsections table.\n\n| Number of class sections with undergraduates enrolled -- Undergraduate Class Size (provide numbers) | Class Sections | Class Sub-Sections |\n|----------------------------------------------------------------------------------------------------|----------------|-------------------|\n| 2 - 9                                                                                              | 519            | 253               |\n| 10 - 19                                                                                            | 891            | 229               |\n| 20 - 29                                                                                            | 776            | 114               |\n| 30 - 39                                                                                            | 303            | 32                |\n| 40 - 49                                                                                            | 218            | 37                |\n| 50 - 99                                                                                            | 339            | 11                |\n| 100+                                                                                               | 106            | 0                 |\n| **Total**                                                                                          | **3,152**      | **676 ...
#  Document(id_='ac1a546d-a3f7-43a4-af8c-5a9d65ae6d5f', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nMississippi State University\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1d992655-a16e-42b1-a3d8-49e4fea86779', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOffice of Institutional Research and Effectiveness\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3c6b1b94-aef9-4232-9bb6-82d229a782bc', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="\n\nJ. DISCIPLINARY AREAS OF DEGREES CONFERRED\n\nDegrees conferred between July 1, 2022 and June 30, 2023.\n\nFor each of the following discipline areas, provide the percentage of diplomas/certificates, and bachelor's degrees awarded. To determine the percentage, use majors, not headcount (e.g., students with one degree but a double major will be represented twice). Calculate the percentage from your institution's IPEDS Completions by using the sum of 1st and 2nd majors for each CIP code as the numerator and the sum of the Grand Total by 1st Majors and the Grand Total by 2nd major as the denominator. If you prefer, you can compute the percentages using 1st majors only.\n\n| Category                                      | Diploma/Certificates | Bachelor's | CIP 2020 Categories to Include |\n|-----------------------------------------------|----------------------|------------|-------------------------------|\n| Agriculture                                   |                      | 6.1        | 1                             |\n| Natural resources and conservation            |                      | 2.6        | 3                             |\n| Architecture                                  |                      | 1.6        | 4                             |\n| Communication/journalism                      |                      | 3.2        | 9                             |\n| Computer and information sciences             |                      | 2.2        | 11                            |\n| Education                                     |                      | 8.3        | 13                            |\n| Engineering                                   |                      | 17.0       | 14                            |\n| Engineering technologies                      |                      | 1.7        | 15                            |\n| Foreign languages, literatures, and linguistics |                    | 0.7        | 16                            |\n| Family and consumer sciences                  |                      | 1.9        | 19                            |\n| English                                       |                      | 0.4        | 23                            |\n| Liberal arts/general studies                  |                      | 1.3        | 24                            |\n| Biological/life sciences                      |                      | 6.1        | 26                            |\n| Mathematics and statistics                    |                      | 0.7        | 27                            |\n| Interdisciplinary studies                     |                      | 6.5        | 30                            |\n| Parks and recreation                          |                      | 5.9        | 31                            |\n| Philosophy and religious studies              |                      | 0.2        | 38                            |\n| Physical sciences                             |                      | 1.9        | 40                            |\n| Psychology                                    |                      | 6.9        | 42                            |\n| Public administration and social services     |                      | 0.8        | 44                            |\n| Social sciences                               |                      | 3.1        | 45                            |\n| Visual and performing arts           ...

# %%
parser.get_json_result('./datasets/cds/pdf/Brigham Young University CDS_2023-2024.pdf')
# Out:
# Started parsing the file under job_id cac11eca-937d-4da2-a80d-c283183746f6
# [{'pages': [{'page': 1,
#     'text': "Common Data Set 2023-2024\n\n\n                                                A. General Information\n\n\nA0     Respondent Information (Not for Publication)\n       Name:                                                         Scott Briggs\n       Title:                                                        Data and Reporting Manager\n       Office:                                                       BYU Office of Assessment and Planning\n       Mailing Address:                                              ASB B-356, Brigham Young University\n       City/State/Zip/Country:                                       Provo, UT 84602\n       Phone:                                                        801-422-7987\n       Fax:\n       E-mail Address:                                               scott.briggs@byu.edu\n\n\n       Are your responses to the CDS posted for                  x Yes\n       reference on your institution's Web site?                     No\n\n\n       If yes, please provide the URL of the corresponding Web page:\n       https://data.byu.edu/common-data-set\n\n\nA0A    We invite you to indicate if there are items on the CDS for which you cannot use the requested analytic\n       convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which\n       you have questions or comments in general. This information will not be published but will help the\n       publishers further refine CDS items.\n\n\nA1     Address Information\n       Name of College/University:                                   Brigham Young University\n       Mailing Address:                                              Brigham Young University, A-209 ASB\n       City/State/Zip/Country:                                       Provo, UT 84602, United States\n       Street Address (if different):\n       City/State/Zip/Country:\n       Main Phone Number:                                            801-422-1211\n       WWW Home Page Address:                                        www.byu.edu\n       Admissions Phone Number:                                      801-422-2507\n       Admissions Toll-Free Phone Number:\n       Admissions Office Mailing Address:                            A-153 ASB\n       City/State/Zip/Country:                                       Provo, UT 84602, United States\n       Admissions E-mail Address:                                    admissions@byu.edu\n       If there is a separate URL for your school’s online application, please specify:\n       https://www.churchofjesuschrist.org/church-education/apply-to-church-schools?lang=eng\n       If you have a mailing address other than the above to which applications should be sent, please provide:\n\n\nA2     Source of institutional control (Check only one):\n\n\n       Public\n   x   Private (nonprofit)\n       Proprietary\n\n\nA3     Classify your undergraduate institution:\n\n\n   x   Coeducational college\n       Men's college\n       Women's college\n\n\nA4     Academic year calendar:\n\n\n   x   Semester                                                      If your academic year has changed because of the\n       Quarter                                                       COVID-19 pandemic, please indicate as other\n       Trimester                                                     below.\n       4-1-4\n       Continuous\n       Differs by program (describe):\n\n\n       Other (describe):\n\n\nA5     Degrees offered by your institution:\n\n\nCDS-A                                                                                                                  Page 1",
#     'md': "# Common Data Set 2023-2024\n\n# A. General Information\n\n|A0|Respondent Information (Not for Publication)|\n|---|---|\n|Name:|Scott Briggs|\n|Title:|Data and Reporting Manager|\n|Office:|BYU Office of Assessment and Planning|\n|Mailing Address:|ASB B-356, Brigham Young University|\n|City/State/Zip/Country:|Provo, UT 84602|\n|Phone:|801-422-7987|\n|Fax:| |\n|E-mail Address:|scott.briggs@byu.edu|\n|Are your responses to the CDS posted for reference on your institution's Web site?|Yes|\n|If yes, please provide the URL of the corresponding Web page:|https://data.byu.edu/common-data-set|\n\n# A0A\n\nWe invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.\n\n# A1\n\n|Name of College/University:|Brigham Young University|\n|---|---|\n|Mailing Address:|Brigham Young University, A-209 ASB|\n|City/State/Zip/Country:|Provo, UT 84602, United States|\n|Main Phone Number:|801-422-1211|\n|WWW Home Page Address:|www.byu.edu|\n|Admissions Phone Number:|801-422-2507|\n|Admissions Office Mailing Address:|A-153 ASB, Provo, UT 84602, United States|\n|Admissions E-mail Address:|admissions@byu.edu|\n|If there is a separate URL for your school’s online application, please specify:|https://www.churchofjesuschrist.org/church-education/apply-to-church-schools?lang=eng|\n|If you have a mailing address other than the above to which applications should be sent, please provide:| |\n\n# A2\n\nSource of institutional control (Check only one): Private (nonprofit)\n\n# A3\n\nClassify your undergraduate institution: Coeducational college\n\n# A4\n\nAcademic year calendar: Semester If your academic year has changed because of the COVID-19 pandemic, please indicate as other below.\n\nOther (describe):\n\n# A5\n\nDegrees offered by your institution:\n\nCDS-A Page 1",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Common Data Set 2023-2024',
#       'md': '# Common Data Set 2023-2024'},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'A. General Information',
#       'md': '# A. General Information'},
#      {'type': 'table',
#       'rows': [['A0', 'Respondent Information (Not for Publication)'],
#        ['Name:', 'Scott Briggs'],
#        ['Title:', 'Data and Reporting Manager'],
#        ['Office:', 'BYU Office of Assessment and Planning'],
#        ['Mailing Address:', 'ASB B-356, Brigham Young University'],
#        ['City/State/Zip/Country:', 'Provo, UT 84602'],
#        ['Phone:', '801-422-7987'],
#        ['Fax:', ''],
#        ['E-mail Address:', 'scott.briggs@byu.edu'],
#        ["Are your responses to the CDS posted for reference on your institution's Web site?",
#         'Yes'],
#        ['If yes, please provide the URL of the corresponding Web page:',
#         'https://data.byu.edu/common-data-set']],
#       'md': "|A0|Respondent Information (Not for Publication)|\n|---|---|\n|Name:|Scott Briggs|\n|Title:|Data and Reporting Manager|\n|Office:|BYU Office of Assessment and Planning|\n|Mailing Address:|ASB B-356, Brigham Young University|\n|City/State/Zip/Country:|Provo, UT 84602|\n|Phone:|801-422-7987|\n|Fax:| |\n|E-mail Address:|scott.briggs@byu.edu|\n|Are your responses to the CDS posted for reference on your institution's Web site?|Yes|\n|If yes, please provide the URL of the corresponding Web page:|https://data.byu.edu/common-data-set|",
#       'isPerfectTable': True,
#       'csv': '"A0","Respondent Information (Not for Publication)"\n"Name:","Scott Briggs"\n"Title:","Data and Reporting Manager"\n"Office:","BYU Office of Assessment and Planning"\n"Mailing Address:","ASB B-356, Brigham Young University"\n"City/State/Zip/Country:","Provo, UT 84602"\n"Phone:","801-422-7987"\n"Fax:",""\n"E-mail Address:","scott.briggs@byu.edu"\n"Are your responses to the CDS posted for reference on your institution\'s Web site?","Yes"\n"If yes, please provide the URL of the corresponding Web page:","https://data.byu.edu/common-data-set"'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A0A', 'md': '# A0A'},
#      {'type': 'text',
#       'value': 'We invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.',
#       'md': 'We invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A1', 'md': '# A1'},
#      {'type': 'table',
#       'rows': [['Name of College/University:', 'Brigham Young University'],
#        ['Mailing Address:', 'Brigham Young University, A-209 ASB'],
#        ['City/State/Zip/Country:', 'Provo, UT 84602, United States'],
#        ['Main Phone Number:', '801-422-1211'],
#        ['WWW Home Page Address:', 'www.byu.edu'],
#        ['Admissions Phone Number:', '801-422-2507'],
#        ['Admissions Office Mailing Address:',
#         'A-153 ASB, Provo, UT 84602, United States'],
#        ['Admissions E-mail Address:', 'admissions@byu.edu'],
#        ['If there is a separate URL for your school’s online application, please specify:',
#         'https://www.churchofjesuschrist.org/church-education/apply-to-church-schools?lang=eng'],
#        ['If you have a mailing address other than the above to which applications should be sent, please provide:',
#         '']],
#       'md': '|Name of College/University:|Brigham Young University|\n|---|---|\n|Mailing Address:|Brigham Young University, A-209 ASB|\n|City/State/Zip/Country:|Provo, UT 84602, United States|\n|Main Phone Number:|801-422-1211|\n|WWW Home Page Address:|www.byu.edu|\n|Admissions Phone Number:|801-422-2507|\n|Admissions Office Mailing Address:|A-153 ASB, Provo, UT 84602, United States|\n|Admissions E-mail Address:|admissions@byu.edu|\n|If there is a separate URL for your school’s online application, please specify:|https://www.churchofjesuschrist.org/church-education/apply-to-church-schools?lang=eng|\n|If you have a mailing address other than the above to which applications should be sent, please provide:| |',
#       'isPerfectTable': True,
#       'csv': '"Name of College/University:","Brigham Young University"\n"Mailing Address:","Brigham Young University, A-209 ASB"\n"City/State/Zip/Country:","Provo, UT 84602, United States"\n"Main Phone Number:","801-422-1211"\n"WWW Home Page Address:","www.byu.edu"\n"Admissions Phone Number:","801-422-2507"\n"Admissions Office Mailing Address:","A-153 ASB, Provo, UT 84602, United States"\n"Admissions E-mail Address:","admissions@byu.edu"\n"If there is a separate URL for your school’s online application, please specify:","https://www.churchofjesuschrist.org/church-education/apply-to-church-schools?lang=eng"\n"If you have a mailing address other than the above to which applications should be sent, please provide:",""'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A2', 'md': '# A2'},
#      {'type': 'text',
#       'value': 'Source of institutional control (Check only one): Private (nonprofit)',
#       'md': 'Source of institutional control (Check only one): Private (nonprofit)'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A3', 'md': '# A3'},
#      {'type': 'text',
#       'value': 'Classify your undergraduate institution: Coeducational college',
#       'md': 'Classify your undergraduate institution: Coeducational college'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A4', 'md': '# A4'},
#      {'type': 'text',
#       'value': 'Academic year calendar: Semester If your academic year has changed because of the COVID-19 pandemic, please indicate as other below.\n\nOther (describe):',
#       'md': 'Academic year calendar: Semester If your academic year has changed because of the COVID-19 pandemic, please indicate as other below.\n\nOther (describe):'},
#      {'type': 'heading', 'lvl': 1, 'value': 'A5', 'md': '# A5'},
#      {'type': 'text',
#       'value': 'Degrees offered by your institution:\n\nCDS-A Page 1',
#       'md': 'Degrees offered by your institution:\n\nCDS-A Page 1'}]},
#    {'page': 2,
#     'text': "Common Data Set 2023-2024\n\n\n        Certificate\n        Diploma\n        Associate\n        Transfer Associate\n        Terminal Associate\n   x    Bachelor's\n        Postbachelor's certificate\n   x    Master's\n        Post-master's certificate\n   x    Doctoral degree research/scholarship\n   x    Doctoral degree – professional practice\n        Doctoral degree -- other\n A5     Doctoral degree -- other\n A6     Diversity, Equity, and Inclusion\n\n\n        If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:\n\n\nCDS-A                                                                                                                               Page 2",
#     'md': "Certificate\nDiploma\nAssociate\nTransfer Associate\nTerminal Associate\nBachelor's\nPostbachelor's certificate\nMaster's\nDoctoral degree research/scholarship\nDoctoral degree – professional practice\nDoctoral degree -- oper\nDoctoral degree -- oper\nDiversity, Equity, and Inclusion\n\nIf you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:",
#     'images': [],
#     'items': [{'type': 'text',
#       'value': "Certificate\nDiploma\nAssociate\nTransfer Associate\nTerminal Associate\nBachelor's\nPostbachelor's certificate\nMaster's\nDoctoral degree research/scholarship\nDoctoral degree – professional practice\nDoctoral degree -- oper\nDoctoral degree -- oper\nDiversity, Equity, and Inclusion\n\nIf you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:",
#       'md': "Certificate\nDiploma\nAssociate\nTransfer Associate\nTerminal Associate\nBachelor's\nPostbachelor's certificate\nMaster's\nDoctoral degree research/scholarship\nDoctoral degree – professional practice\nDoctoral degree -- oper\nDoctoral degree -- oper\nDiversity, Equity, and Inclusion\n\nIf you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:"}]},
#    {'page': 3,
#     'text': 'Common Data Set 2023-2024\n\n\n                                                        B. ENROLLMENT AND PERSISTENCE\n\n\n B1    Institutional Enrollment - Men and Women\n        Provide numbers of students for each of the following categories as of the institution\'s official fall reporting date or as of October 15, 2023.\n       •    Note: Report students formerly designated as “first professional” in the graduate cells.\n       •    For information on reporting study abroad students please see: This Document at NCES.GOV\n       •    If your institution collects and reports non-binary gender data, please use the "Another Gender" category.\n       •    In cases where gender information is not provided, please distribute across the two-binary categories.\n       Undergraduate Students: Full-Time                               Men                  Women             Another Gender\n       Degree-seeking, first-time freshmen                                    2435                 3,433                           0\n       Other first-year, degree-seeking                                                                                            0\n       All other degree-seeking                                            11,629                 11,763                           0\n       Total degree-seeking                                                14,064                 15,196                           0\n       All other undergraduates enrolled in credit                                                                                 0\n       Total undergraduate Full-Time Students                              14,064                 15,196                           0\n\n\n       Undergraduate Students: Part-Time                               Men                  Women             Another Gender\n       Degree-seeking, first-time freshmen                                       91                   107                          0\n       Other first-year, degree-seeking                                                                                            0\n       All other degree-seeking                                             1,324                  1,439                           0\n       Total degree-seeking                                                 1,415                  1,546                           0\n       All other undergraduates enrolled in credit                                                                                 0\n       Total undergraduate Part-Time Students                               1,415                  1,546                           0\n\n\n       Undergraduate Students: All                                     Men                  Women             Another Gender\n       Total undergraduate Students                                        15,479                 16,742                           0\n\n\n       Graduate Students: Full-Time\n       Degree-seeking, first-time                                                                                                   0\n       All other degree-seeking                                                 929                    866                          0\n       All other graduates enrolled in credit                                                                                       0\n       Total graduate Full-Time Students                                        929                    866                          0\n\n\n       Graduate Students:Part-Time\n       Degree-seeking, first-time                                                                                                   0\n       All other degree-seeking                                                 581                    477                          0\n       All other graduates enrolled in credit                                                                                       0\n       Total graduate Part-Time Students                            ...
#     'md': '# B. ENROLLMENT AND PERSISTENCE\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: Full-Time|2435|3,433|0|\n|Degree-seeking, first-time freshmen| | | |\n|Other first-year, degree-seeking| | | |\n|All other degree-seeking|11,629|11,763|0|\n|Total degree-seeking|14,064|15,196|0|\n|All other undergraduates enrolled in credit| | | |\n|Total undergraduate Full-Time Students|14,064|15,196|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: Part-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time freshmen|91|107|0|\n|Other first-year, degree-seeking| | | |\n|All other degree-seeking|1,324|1,439|0|\n|Total degree-seeking|1,415|1,546|0|\n|All other undergraduates enrolled in credit| | | |\n|Total undergraduate Part-Time Students|1,415|1,546|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: All|Men|Women|Another Gender|\n|Total undergraduate Students|15,479|16,742|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: Full-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time| | | |\n|All other degree-seeking|929|866|0|\n|All other graduates enrolled in credit| | | |\n|Total graduate Full-Time Students|929|866|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: Part-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time| | | |\n|All other degree-seeking|581|477|0|\n|All other graduates enrolled in credit| | | |\n|Total graduate Part-Time Students|581|477|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: All|Men|Women|Another Gender|\n|Total Graduate Students|1510|1343|0|\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|All Students: Total|Men|Women|Another Gender|\n|Total all students|14,993|16,062|0|\n\nTotal all undergraduates: 32,221\n\nTotal all graduate: 2853\n\nGRAND TOTAL ALL STUDENTS: 35,074\n\n# B2 Enrollment by Racial/Ethnic Category\n\nProvide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n- Include international students only in the category "Nonresidents."\n- Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n- Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non-Hispanic multi-racial should be reported only under "Two or more races."\n- New guidance from IPEDS for reporting aggregate data:\n\nRacial/ethnic designations are requested only for United States citizens, residents, and other eligible non-citizens. Eligible non-citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F-1 non-immigrant student visa at the time of high school graduation. More information about other eligible (for financial aid purposes) non-citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non-us-citizens.',
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'B. ENROLLMENT AND PERSISTENCE',
#       'md': '# B. ENROLLMENT AND PERSISTENCE'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Undergraduate Students: Full-Time', '2435', '3,433', '0'],
#        ['Degree-seeking, first-time freshmen', '', '', ''],
#        ['Other first-year, degree-seeking', '', '', ''],
#        ['All other degree-seeking', '11,629', '11,763', '0'],
#        ['Total degree-seeking', '14,064', '15,196', '0'],
#        ['All other undergraduates enrolled in credit', '', '', ''],
#        ['Total undergraduate Full-Time Students', '14,064', '15,196', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: Full-Time|2435|3,433|0|\n|Degree-seeking, first-time freshmen| | | |\n|Other first-year, degree-seeking| | | |\n|All other degree-seeking|11,629|11,763|0|\n|Total degree-seeking|14,064|15,196|0|\n|All other undergraduates enrolled in credit| | | |\n|Total undergraduate Full-Time Students|14,064|15,196|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Undergraduate Students: Full-Time","2435","3,433","0"\n"Degree-seeking, first-time freshmen","","",""\n"Other first-year, degree-seeking","","",""\n"All other degree-seeking","11,629","11,763","0"\n"Total degree-seeking","14,064","15,196","0"\n"All other undergraduates enrolled in credit","","",""\n"Total undergraduate Full-Time Students","14,064","15,196","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Undergraduate Students: Part-Time', 'Men', 'Women', 'Another Gender'],
#        ['Degree-seeking, first-time freshmen', '91', '107', '0'],
#        ['Other first-year, degree-seeking', '', '', ''],
#        ['All other degree-seeking', '1,324', '1,439', '0'],
#        ['Total degree-seeking', '1,415', '1,546', '0'],
#        ['All other undergraduates enrolled in credit', '', '', ''],
#        ['Total undergraduate Part-Time Students', '1,415', '1,546', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: Part-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time freshmen|91|107|0|\n|Other first-year, degree-seeking| | | |\n|All other degree-seeking|1,324|1,439|0|\n|Total degree-seeking|1,415|1,546|0|\n|All other undergraduates enrolled in credit| | | |\n|Total undergraduate Part-Time Students|1,415|1,546|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Undergraduate Students: Part-Time","Men","Women","Another Gender"\n"Degree-seeking, first-time freshmen","91","107","0"\n"Other first-year, degree-seeking","","",""\n"All other degree-seeking","1,324","1,439","0"\n"Total degree-seeking","1,415","1,546","0"\n"All other undergraduates enrolled in credit","","",""\n"Total undergraduate Part-Time Students","1,415","1,546","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Undergraduate Students: All', 'Men', 'Women', 'Another Gender'],
#        ['Total undergraduate Students', '15,479', '16,742', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Undergraduate Students: All|Men|Women|Another Gender|\n|Total undergraduate Students|15,479|16,742|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Undergraduate Students: All","Men","Women","Another Gender"\n"Total undergraduate Students","15,479","16,742","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Graduate Students: Full-Time', 'Men', 'Women', 'Another Gender'],
#        ['Degree-seeking, first-time', '', '', ''],
#        ['All other degree-seeking', '929', '866', '0'],
#        ['All other graduates enrolled in credit', '', '', ''],
#        ['Total graduate Full-Time Students', '929', '866', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: Full-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time| | | |\n|All other degree-seeking|929|866|0|\n|All other graduates enrolled in credit| | | |\n|Total graduate Full-Time Students|929|866|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Graduate Students: Full-Time","Men","Women","Another Gender"\n"Degree-seeking, first-time","","",""\n"All other degree-seeking","929","866","0"\n"All other graduates enrolled in credit","","",""\n"Total graduate Full-Time Students","929","866","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Graduate Students: Part-Time', 'Men', 'Women', 'Another Gender'],
#        ['Degree-seeking, first-time', '', '', ''],
#        ['All other degree-seeking', '581', '477', '0'],
#        ['All other graduates enrolled in credit', '', '', ''],
#        ['Total graduate Part-Time Students', '581', '477', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: Part-Time|Men|Women|Another Gender|\n|Degree-seeking, first-time| | | |\n|All other degree-seeking|581|477|0|\n|All other graduates enrolled in credit| | | |\n|Total graduate Part-Time Students|581|477|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Graduate Students: Part-Time","Men","Women","Another Gender"\n"Degree-seeking, first-time","","",""\n"All other degree-seeking","581","477","0"\n"All other graduates enrolled in credit","","",""\n"Total graduate Part-Time Students","581","477","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Graduate Students: All', 'Men', 'Women', 'Another Gender'],
#        ['Total Graduate Students', '1510', '1343', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Graduate Students: All|Men|Women|Another Gender|\n|Total Graduate Students|1510|1343|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Graduate Students: All","Men","Women","Another Gender"\n"Total Graduate Students","1510","1343","0"'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['All Students: Total', 'Men', 'Women', 'Another Gender'],
#        ['Total all students', '14,993', '16,062', '0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|All Students: Total|Men|Women|Another Gender|\n|Total all students|14,993|16,062|0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"All Students: Total","Men","Women","Another Gender"\n"Total all students","14,993","16,062","0"'},
#      {'type': 'text',
#       'value': 'Total all undergraduates: 32,221\n\nTotal all graduate: 2853\n\nGRAND TOTAL ALL STUDENTS: 35,074',
#       'md': 'Total all undergraduates: 32,221\n\nTotal all graduate: 2853\n\nGRAND TOTAL ALL STUDENTS: 35,074'},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'B2 Enrollment by Racial/Ethnic Category',
#       'md': '# B2 Enrollment by Racial/Ethnic Category'},
#      {'type': 'text',
#       'value': 'Provide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n- Include international students only in the category "Nonresidents."\n- Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n- Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non-Hispanic multi-racial should be reported only under "Two or more races."\n- New guidance from IPEDS for reporting aggregate data:\n\nRacial/ethnic designations are requested only for United States citizens, residents, and other eligible non-citizens. Eligible non-citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F-1 non-immigrant student visa at the time of high school graduation. More information about other eligible (for financial aid purposes) non-citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non-us-citizens.',
#       'md': 'Provide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n- Include international students only in the category "Nonresidents."\n- Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n- Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non-Hispanic multi-racial should be reported only under "Two or more races."\n- New guidance from IPEDS for reporting aggregate data:\n\nRacial/ethnic designations are requested only for United States citizens, residents, and other eligible non-citizens. Eligible non-citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F-1 non-immigrant student visa at the time of high school graduation. More information about other eligible (for financial aid purposes) non-citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non-us-citizens.'}]},
#    {'page': 4,
#     'text': 'Common Data Set 2023-2024\n\n\n        Nonresident - A person who is not a citizen or national of the United States and who is in this country on a student visa\n        or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other\n        eligible noncitizens in this category.\n        NOTE - Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven\n        racial/ethnic categories or in race/ethnicity unknown.\n\n\n                                                                                           Degree-Seeking            Degree-Seeking                  Total\n                                                                                               First-Time            Undergraduates             Undergraduates\n                                                                                               First Year        (include first-time first-  (both degree & non-\n                                                                                                                           year)               degree-seeking)\n        Nonresidents                                                                                       76                       898\n        Hispanic/Latino                                                                                   428                     2,578\n        Black or African American, non-Hispanic                                                            13                       127\n        White, non-Hispanic                                                                            4,986                     25,994\n        American Indian or Alaska Native, non-Hispanic                                                     10                         60\n        Asian, non-Hispanic                                                                                71                       491\n\n\n        Native Hawaiian or other Pacific Islander, non-Hispanic                                            29                       176\n        Two or more races, non-Hispanic                                                                   263                     1,285\n        Race and/or ethnicity unknown                                                                     166                       382\n        TOTAL                                                                                          6,042                     31,991                           0\n        Persistence\n B3     Number of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n        Certificate/diploma\n        Associate degrees\n        Bachelor\'s degrees                                                6640\n        Postbachelor\'s certificates\n        Master\'s degrees                                                  1119\n        Post-Master\'s certificates\n        Doctoral degrees – research/scholarship                            107\n\n\n        Doctoral degrees – professional practice                           111\n        Doctoral degrees – other\n        B4-B21: Graduation Rates\n            The items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System’s Graduation Rate\n                                                                                         Survey (GRS).\n\n\n        •    For complete instructions and definitions of data elements, see the IPEDS GRS Forms and Instructions\n             for the 2023-2024 Survey. https://nces.ed.gov/ipeds/use-the-data/survey-components/9/graduation-rates\n\n\n        In the following section for bachelor’s or equivalent programs, please disaggregate the Fall 2016 and Fall 2017 cohorts (formerly\n        CDS B4-B11) into four groups:\n        •    Students who received a Federal Pell Grant*\n        •    Recipients of a subsidized Stafford Loan who did  ...
#     'md': '# Common Data Set 2023-2024\n\nNonresident - A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category.\n\nNOTE - Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.\n\n| |Degree-Seeking First-Time First Year|Degree-Seeking Undergraduates (include first-time first-year)|Total Undergraduates (both degree & non-degree-seeking)|\n|---|---|---|---|\n|Nonresidents|76|898| |\n|Hispanic/Latino|428|2,578| |\n|Black or African American, non-Hispanic|13|127| |\n|White, non-Hispanic|4,986|25,994| |\n|American Indian or Alaska Native, non-Hispanic|10|60| |\n|Asian, non-Hispanic|71|491| |\n|Native Hawaiian or other Pacific Islander, non-Hispanic|29|176| |\n|Two or more races, non-Hispanic|263|1,285| |\n|Race and/or ethnicity unknown|166|382| |\n|TOTAL|6,042|31,991|0|\n\nPersistence\n\nNumber of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n\n- Certificate/diploma\n- Associate degrees\n- Bachelor\'s degrees: 6640\n- Postbachelor\'s certificates\n- Master\'s degrees: 1119\n- Post-Master\'s certificates\n- Doctoral degrees – research/scholarship: 107\n- Doctoral degrees – professional practice: 111\n- Doctoral degrees – other\n\nB4-B21: Graduation Rates\n\nThe items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System’s Graduation Rate Survey (GRS).\n\nFor complete instructions and definitions of data elements, see the IPEDS GRS Forms and Instructions for the 2023-2024 Survey. https://nces.ed.gov/ipeds/use-the-data/survey-components/9/graduation-rates\n\nIn the following section for bachelor’s or equivalent programs, please disaggregate the Fall 2016 and Fall 2017 cohorts (formerly CDS B4-B11) into four groups:\n\n- Students who received a Federal Pell Grant*\n- Recipients of a subsidized Stafford Loan who did not receive a Pell Grant\n- Students who did not receive either a Pell Grant or a subsidized Stafford Loan\n- Total (all students, regardless of Pell Grant or subsidized loan status)\n\n*Students who received both a Federal Pell Grant and a subsidized Stafford Loan should be reported in the "Recipients of a Federal Pell Grant" column.\n\nFor each graduation rate grid below, the numbers in the first three columns for Questions A-G should sum to the cohort total in the fourth column (formerly CDS B4-B11).\n\n**For Bachelor’s or Equivalent Programs**\n| |Recipients of a Federal Pell Grant|Recipients of a Subsidized Stafford Loan who did not receive a Pell Grant|Students who did not receive either a Pell Grant or a subsidized Stafford Loan|Total (sum of 3 columns to the left)|\n|---|---|---|---|---|\n|Fall 2017 Cohort| | | | |',
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'Common Data Set 2023-2024',
#       'md': '# Common Data Set 2023-2024'},
#      {'type': 'text',
#       'value': 'Nonresident - A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category.\n\nNOTE - Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.',
#       'md': 'Nonresident - A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category.\n\nNOTE - Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.'},
#      {'type': 'table',
#       'rows': [['',
#         'Degree-Seeking First-Time First Year',
#         'Degree-Seeking Undergraduates (include first-time first-year)',
#         'Total Undergraduates (both degree & non-degree-seeking)'],
#        ['Nonresidents', '76', '898', ''],
#        ['Hispanic/Latino', '428', '2,578', ''],
#        ['Black or African American, non-Hispanic', '13', '127', ''],
#        ['White, non-Hispanic', '4,986', '25,994', ''],
#        ['American Indian or Alaska Native, non-Hispanic', '10', '60', ''],
#        ['Asian, non-Hispanic', '71', '491', ''],
#        ['Native Hawaiian or other Pacific Islander, non-Hispanic',
#         '29',
#         '176',
#         ''],
#        ['Two or more races, non-Hispanic', '263', '1,285', ''],
#        ['Race and/or ethnicity unknown', '166', '382', ''],
#        ['TOTAL', '6,042', '31,991', '0']],
#       'md': '| |Degree-Seeking First-Time First Year|Degree-Seeking Undergraduates (include first-time first-year)|Total Undergraduates (both degree & non-degree-seeking)|\n|---|---|---|---|\n|Nonresidents|76|898| |\n|Hispanic/Latino|428|2,578| |\n|Black or African American, non-Hispanic|13|127| |\n|White, non-Hispanic|4,986|25,994| |\n|American Indian or Alaska Native, non-Hispanic|10|60| |\n|Asian, non-Hispanic|71|491| |\n|Native Hawaiian or other Pacific Islander, non-Hispanic|29|176| |\n|Two or more races, non-Hispanic|263|1,285| |\n|Race and/or ethnicity unknown|166|382| |\n|TOTAL|6,042|31,991|0|',
#       'isPerfectTable': True,
#       'csv': '"","Degree-Seeking First-Time First Year","Degree-Seeking Undergraduates (include first-time first-year)","Total Undergraduates (both degree & non-degree-seeking)"\n"Nonresidents","76","898",""\n"Hispanic/Latino","428","2,578",""\n"Black or African American, non-Hispanic","13","127",""\n"White, non-Hispanic","4,986","25,994",""\n"American Indian or Alaska Native, non-Hispanic","10","60",""\n"Asian, non-Hispanic","71","491",""\n"Native Hawaiian or other Pacific Islander, non-Hispanic","29","176",""\n"Two or more races, non-Hispanic","263","1,285",""\n"Race and/or ethnicity unknown","166","382",""\n"TOTAL","6,042","31,991","0"'},
#      {'type': 'text',
#       'value': 'Persistence\n\nNumber of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n\n- Certificate/diploma\n- Associate degrees\n- Bachelor\'s degrees: 6640\n- Postbachelor\'s certificates\n- Master\'s degrees: 1119\n- Post-Master\'s certificates\n- Doctoral degrees – research/scholarship: 107\n- Doctoral degrees – professional practice: 111\n- Doctoral degrees – other\n\nB4-B21: Graduation Rates\n\nThe items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System’s Graduation Rate Survey (GRS).\n\nFor complete instructions and definitions of data elements, see the IPEDS GRS Forms and Instructions for the 2023-2024 Survey. https://nces.ed.gov/ipeds/use-the-data/survey-components/9/graduation-rates\n\nIn the following section for bachelor’s or equivalent programs, please disaggregate the Fall 2016 and Fall 2017 cohorts (formerly CDS B4-B11) into four groups:\n\n- Students who received a Federal Pell Grant*\n- Recipients of a subsidized Stafford Loan who did not receive a Pell Grant\n- Students who did not receive either a Pell Grant or a subsidized Stafford Loan\n- Total (all students, regardless of Pell Grant or subsidized loan status)\n\n*Students who received both a Federal Pell Grant and a subsidized Stafford Loan should be reported in the "Recipients of a Federal Pell Grant" column.\n\nFor each graduation rate grid below, the numbers in the first three columns for Questions A-G should sum to the cohort total in the fourth column (formerly CDS B4-B11).\n\n**For Bachelor’s or Equivalent Programs**',
#       'md': 'Persistence\n\nNumber of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n\n- Certificate/diploma\n- Associate degrees\n- Bachelor\'s degrees: 6640\n- Postbachelor\'s certificates\n- Master\'s degrees: 1119\n- Post-Master\'s certificates\n- Doctoral degrees – research/scholarship: 107\n- Doctoral degrees – professional practice: 111\n- Doctoral degrees – other\n\nB4-B21: Graduation Rates\n\nThe items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System’s Graduation Rate Survey (GRS).\n\nFor complete instructions and definitions of data elements, see the IPEDS GRS Forms and Instructions for the 2023-2024 Survey. https://nces.ed.gov/ipeds/use-the-data/survey-components/9/graduation-rates\n\nIn the following section for bachelor’s or equivalent programs, please disaggregate the Fall 2016 and Fall 2017 cohorts (formerly CDS B4-B11) into four groups:\n\n- Students who received a Federal Pell Grant*\n- Recipients of a subsidized Stafford Loan who did not receive a Pell Grant\n- Students who did not receive either a Pell Grant or a subsidized Stafford Loan\n- Total (all students, regardless of Pell Grant or subsidized loan status)\n\n*Students who received both a Federal Pell Grant and a subsidized Stafford Loan should be reported in the "Recipients of a Federal Pell Grant" column.\n\nFor each graduation rate grid below, the numbers in the first three columns for Questions A-G should sum to the cohort total in the fourth column (formerly CDS B4-B11).\n\n**For Bachelor’s or Equivalent Programs**'},
#      {'type': 'table',
#       'rows': [['',
#         'Recipients of a Federal Pell Grant',
#         'Recipients of a Subsidized Stafford Loan who did not receive a Pell Grant',
#         'Students who did not receive either a Pell Grant or a subsidized Stafford Loan',
#         'Total (sum of 3 columns to the left)'],
#        ['Fall 2017 Cohort', '', '', '', '']],
#       'md': '| |Recipients of a Federal Pell Grant|Recipients of a Subsidized Stafford Loan who did not receive a Pell Grant|Students who did not receive either a Pell Grant or a subsidized Stafford Loan|Total (sum of 3 columns to the left)|\n|---|---|---|---|---|\n|Fall 2017 Cohort| | | | |',
#       'isPerfectTable': True,
#       'csv': '"","Recipients of a Federal Pell Grant","Recipients of a Subsidized Stafford Loan who did not receive a Pell Grant","Students who did not receive either a Pell Grant or a subsidized Stafford Loan","Total (sum of 3 columns to the left)"\n"Fall 2017 Cohort","","","",""'}]},
#    {'page': 5,
# ...
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Common Data Set 2023-2024'],
#        ['Look beyond the bachelor\'s degree. Some of these degrees, such as those in Theology (M.Div., M.H.L./Rav) that were formerly classified as "first-professional", may require more than two full-time equivalent academic years of work.'],
#        ['grant for the purpose of obtaining permanent resident status (and who holds either a registration card [Form I-551 or I-151], a Temporary Resident Card [Form I-688], or an Arrival-Departure Record [Form I-94] with a notation.'],
#        ['that is received after completion of a program that is eligible for Title IV federal student aid. Credentials that are awarded to recognize an individual’s attainment of measurable technical or industry/occupational skills necessary.'],
#        ['operating on a trimester system or the fourth term of an institution operating on a quarter calendar system. The institution may have 2 or more sessions occurring in the summer months. Some schools, such as vocational and beauty.'],
#        ['CDS Definitions', 'Page 36']],
#       'md': '|Common Data Set 2023-2024|\n|---|\n|Look beyond the bachelor\'s degree. Some of these degrees, such as those in Theology (M.Div., M.H.L./Rav) that were formerly classified as "first-professional", may require more than two full-time equivalent academic years of work.|\n|grant for the purpose of obtaining permanent resident status (and who holds either a registration card [Form I-551 or I-151], a Temporary Resident Card [Form I-688], or an Arrival-Departure Record [Form I-94] with a notation.|\n|that is received after completion of a program that is eligible for Title IV federal student aid. Credentials that are awarded to recognize an individual’s attainment of measurable technical or industry/occupational skills necessary.|\n|operating on a trimester system or the fourth term of an institution operating on a quarter calendar system. The institution may have 2 or more sessions occurring in the summer months. Some schools, such as vocational and beauty.|\n|CDS Definitions|Page 36|',
#       'isPerfectTable': False,
#       'csv': '"Common Data Set 2023-2024"\n"Look beyond the bachelor\'s degree. Some of these degrees, such as those in Theology (M.Div., M.H.L./Rav) that were formerly classified as ""first-professional"", may require more than two full-time equivalent academic years of work."\n"grant for the purpose of obtaining permanent resident status (and who holds either a registration card [Form I-551 or I-151], a Temporary Resident Card [Form I-688], or an Arrival-Departure Record [Form I-94] with a notation."\n"that is received after completion of a program that is eligible for Title IV federal student aid. Credentials that are awarded to recognize an individual’s attainment of measurable technical or industry/occupational skills necessary."\n"operating on a trimester system or the fourth term of an institution operating on a quarter calendar system. The institution may have 2 or more sessions occurring in the summer months. Some schools, such as vocational and beauty."\n"CDS Definitions","Page 36"'}]},
#    {'page': 37,
#     'text': '                                                                                                                  Common Data Set 2023-2024\n\n\nrestricted funds or gifts and endowment income) awarded solely on the basis of academic achievement, merit, or any other non-need-based reason. When reporting questions H1 and H2, non-need-based aid that is used to meet nee\n\n\n                                                                                                                             CDS Definitions                                                                                     Page 37',
#     'md': '|Common Data Set 2023-2024|\n|---|\n|restricted funds or gifts and endowment income) awarded solely on the basis of academic achievement, merit, or any other non-need-based reason. When reporting questions H1 and H2, non-need-based aid that is used to meet nee|\n|CDS Definitions|Page 37|',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Common Data Set 2023-2024'],
#        ['restricted funds or gifts and endowment income) awarded solely on the basis of academic achievement, merit, or any other non-need-based reason. When reporting questions H1 and H2, non-need-based aid that is used to meet nee'],
#        ['CDS Definitions', 'Page 37']],
#       'md': '|Common Data Set 2023-2024|\n|---|\n|restricted funds or gifts and endowment income) awarded solely on the basis of academic achievement, merit, or any other non-need-based reason. When reporting questions H1 and H2, non-need-based aid that is used to meet nee|\n|CDS Definitions|Page 37|',
#       'isPerfectTable': False,
#       'csv': '"Common Data Set 2023-2024"\n"restricted funds or gifts and endowment income) awarded solely on the basis of academic achievement, merit, or any other non-need-based reason. When reporting questions H1 and H2, non-need-based aid that is used to meet nee"\n"CDS Definitions","Page 37"'}]},
#    {'page': 38,
#     'text': '                                                                                                                         Common Data Set 2023-2024\n\n\nn) program. (A cooperative plan provides for alternate class attendance and employment in business, industry, or government; thus, it allows students to combine actual work experience with their college studies.) Also, it includes\n\n\nfessional preparation, equals at least six full-time equivalent academic years. Some of these degrees were formerly classified as “first-professional” and may include: Chiropractic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); L\n\n\n                                                                                                                                    CDS Definitions                                                                                     Page 38',
#     'md': '|Common Data Set 2023-2024|\n|---|\n|program. (A cooperative plan provides for alternate class attendance and employment in business, industry, or government; thus, it allows students to combine actual work experience with their college studies.) Also, it includes|\n|fessional preparation, equals at least six full-time equivalent academic years. Some of these degrees were formerly classified as “first-professional” and may include: Chiropractic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); L|\n|CDS Definitions|Page 38|',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Common Data Set 2023-2024'],
#        ['program. (A cooperative plan provides for alternate class attendance and employment in business, industry, or government; thus, it allows students to combine actual work experience with their college studies.) Also, it includes'],
#        ['fessional preparation, equals at least six full-time equivalent academic years. Some of these degrees were formerly classified as “first-professional” and may include: Chiropractic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); L'],
#        ['CDS Definitions', 'Page 38']],
#       'md': '|Common Data Set 2023-2024|\n|---|\n|program. (A cooperative plan provides for alternate class attendance and employment in business, industry, or government; thus, it allows students to combine actual work experience with their college studies.) Also, it includes|\n|fessional preparation, equals at least six full-time equivalent academic years. Some of these degrees were formerly classified as “first-professional” and may include: Chiropractic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); L|\n|CDS Definitions|Page 38|',
#       'isPerfectTable': False,
#       'csv': '"Common Data Set 2023-2024"\n"program. (A cooperative plan provides for alternate class attendance and employment in business, industry, or government; thus, it allows students to combine actual work experience with their college studies.) Also, it includes"\n"fessional preparation, equals at least six full-time equivalent academic years. Some of these degrees were formerly classified as “first-professional” and may include: Chiropractic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); L"\n"CDS Definitions","Page 38"'}]},
#    {'page': 39,
#     'text': '                                                                                                                       Common Data Set 2023-2024\n\n\nparture Record [Form I-94] with a notation that conveys legal immigrant status, such as Section 207 Refugee, Section 208 Asylee, Conditional Entrant Parolee or Cuban-Haitian).\n\n\nl or industry/occupational skills necessary to obtain employment or advance within an industry occupation. (Generally based on standards developed or endorsed by employers or industry associations).\n\n\n                                                                                                                                 CDS Definitions                                                        Page 39',
#     'md': '|Common Data Set 2023-2024|\n|---|\n|parture Record [Form I-94] with a notation that conveys legal immigrant status, such as Section 207 Refugee, Section 208 Asylee, Conditional Entrant Parolee or Cuban-Haitian).|\n|l or industry/occupational skills necessary to obtain employment or advance within an industry occupation. (Generally based on standards developed or endorsed by employers or industry associations).|\n|CDS Definitions|Page 39|',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Common Data Set 2023-2024'],
#        ['parture Record [Form I-94] with a notation that conveys legal immigrant status, such as Section 207 Refugee, Section 208 Asylee, Conditional Entrant Parolee or Cuban-Haitian).'],
#        ['l or industry/occupational skills necessary to obtain employment or advance within an industry occupation. (Generally based on standards developed or endorsed by employers or industry associations).'],
#        ['CDS Definitions', 'Page 39']],
#       'md': '|Common Data Set 2023-2024|\n|---|\n|parture Record [Form I-94] with a notation that conveys legal immigrant status, such as Section 207 Refugee, Section 208 Asylee, Conditional Entrant Parolee or Cuban-Haitian).|\n|l or industry/occupational skills necessary to obtain employment or advance within an industry occupation. (Generally based on standards developed or endorsed by employers or industry associations).|\n|CDS Definitions|Page 39|',
#       'isPerfectTable': False,
#       'csv': '"Common Data Set 2023-2024"\n"parture Record [Form I-94] with a notation that conveys legal immigrant status, such as Section 207 Refugee, Section 208 Asylee, Conditional Entrant Parolee or Cuban-Haitian)."\n"l or industry/occupational skills necessary to obtain employment or advance within an industry occupation. (Generally based on standards developed or endorsed by employers or industry associations)."\n"CDS Definitions","Page 39"'}]},
#    {'page': 40,
#     'text': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 40',
#     'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 40',
#     'images': [],
#     'items': [{'type': 'text',
#       'value': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 40',
#       'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 40'}]},
#    {'page': 41,
#     'text': '                                                                                                                 Common Data Set 2023-2024\n\n\nic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); Law (L.L.B. or J.D.); Medicine (M.D.); Optometry (O.D.); Osteopathic Medicine (D.O); Pharmacy (Pharm.D.); Podiatry (D.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M\n\n\n                                                                                                                           CDS Definitions                                                                                    Page 41',
#     'md': '|Common Data Set 2023-2024|\n|---|\n|ic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); Law (L.L.B. or J.D.); Medicine (M.D.); Optometry (O.D.); Osteopathic Medicine (D.O); Pharmacy (Pharm.D.); Podiatry (D.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M|\n|CDS Definitions|Page 41|',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Common Data Set 2023-2024'],
#        ['ic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); Law (L.L.B. or J.D.); Medicine (M.D.); Optometry (O.D.); Osteopathic Medicine (D.O); Pharmacy (Pharm.D.); Podiatry (D.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M'],
#        ['CDS Definitions', 'Page 41']],
#       'md': '|Common Data Set 2023-2024|\n|---|\n|ic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); Law (L.L.B. or J.D.); Medicine (M.D.); Optometry (O.D.); Osteopathic Medicine (D.O); Pharmacy (Pharm.D.); Podiatry (D.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M|\n|CDS Definitions|Page 41|',
#       'isPerfectTable': False,
#       'csv': '"Common Data Set 2023-2024"\n"ic (D.C. or D.C.M.); Dentistry (D.D.S. or D.M.D.); Law (L.L.B. or J.D.); Medicine (M.D.); Optometry (O.D.); Osteopathic Medicine (D.O); Pharmacy (Pharm.D.); Podiatry (D.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M"\n"CDS Definitions","Page 41"'}]},
#    {'page': 42,
#     'text': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 42',
#     'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 42',
#     'images': [],
#     'items': [{'type': 'text',
#       'value': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 42',
#       'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 42'}]},
#    {'page': 43,
#     'text': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 43',
#     'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 43',
#     'images': [],
#     'items': [{'type': 'text',
#       'value': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 43',
#       'md': 'Common Data Set 2023-2024\n\n\n        CDS Definitions    Page 43'}]},
#    {'page': 44,
#     'text': '                                                                                                               Common Data Set 2023-2024\n\n\nD.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M.), and others, as designated by the awarding institution.\n\n\n                                                                                                                         CDS Definitions  Page 44',
#     'md': 'Common Data Set 2023-2024\nD.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M.), and opers, as designated by pe awarding institution.\nCDS Definitions  Page 44',
#     'images': [],
#     'items': [{'type': 'text',
#       'value': 'Common Data Set 2023-2024\nD.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M.), and opers, as designated by pe awarding institution.\nCDS Definitions  Page 44',
#       'md': 'Common Data Set 2023-2024\nD.P.M., Pod.D., D.P.); or, Veterinary Medicine (D.V.M.), and opers, as designated by pe awarding institution.\nCDS Definitions  Page 44'}]}],
#   'job_metadata': {'credits_used': 1867.0,
#    'credits_max': 1000,
#    'job_credits_usage': 44,
#    'job_pages': 44,
#    'job_is_cache_hit': True},
#   'job_id': 'cac11eca-937d-4da2-a80d-c283183746f6',
#   'file_path': './datasets/cds/pdf/Brigham Young University CDS_2023-2024.pdf'}]

# %%
parser.get_json_result('./datasets/cds/pdf/Penn State CDS_2023-2024.pdf')
# Out:
# Started parsing the file under job_id cac11eca-30f4-457e-8cdc-bc2f8a3d6117
# [{'pages': [{'page': 1,
#     'text': "                                                                          CDS_2023_2024_FINAL\nUP                                                                    A. General Information\nSELECT CAMPUS IN A1\nA0. Respondent Information (not for publication)\n\n\n                First Name:                                          Matthew\n                Last Name:                                           Gueguen\n                Title:                                               Analysis and Planning Consultant\n                Office:                                              OPAIR\n                Address:                                             203 Rider Building\n                City:                                                University Park\n                State:                                               PA\n                Zip:                                                 16802\n                Country:                                             USA\n                Phone Number:                                        814-863-8721\n                Extension:\n                Email Address:                                       mpg5717@psu.edu\n\n\n                Are your responses to the CDS posted for reference on your institution's website?                   (click to select from dropdown)\n                                                                     Yes\n                If yes, please provide a direct link to the posted CDS responses:\n                                                                     https://opair.psu.edu/institutional‐research/projects/cds/\n\n\nA0A. Comments About CDS (not for publication)\n\n\nWe invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention,\ncannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or\ncomments in general. This information will not be published but will help the publishers further refine CDS items.\n\n\n                                                Enter comments\n                                                about CDS here:",
#     'md': "# CDS_2023_2024_FINAL\n\n# A. General Information\n\nSELECT CAMPUS IN A1\n\n# A0. Respondent Information (not for publication)\n\n|First Name:|Matthew|\n|---|---|\n|Last Name:|Gueguen|\n|Title:|Analysis and Planning Consultant|\n|Office:|OPAIR|\n|Address:|203 Rider Building|\n|City:|University Park|\n|State:|PA|\n|Zip:|16802|\n|Country:|USA|\n|Phone Number:|814-863-8721|\n|Extension:| |\n|Email Address:|mpg5717@psu.edu|\n\nAre your responses to the CDS posted for reference on your institution's website? (click to select from dropdown)\n\nYes\n\nIf yes, please provide a direct link to the posted CDS responses:\n\nhttps://opair.psu.edu/institutional‐research/projects/cds/\n\n# A0A. Comments About CDS (not for publication)\n\nWe invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.\n\nEnter comments about CDS here:",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'CDS_2023_2024_FINAL',
#       'md': '# CDS_2023_2024_FINAL'},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'A. General Information',
#       'md': '# A. General Information'},
#      {'type': 'text',
#       'value': 'SELECT CAMPUS IN A1',
#       'md': 'SELECT CAMPUS IN A1'},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'A0. Respondent Information (not for publication)',
#       'md': '# A0. Respondent Information (not for publication)'},
#      {'type': 'table',
#       'rows': [['First Name:', 'Matthew'],
#        ['Last Name:', 'Gueguen'],
#        ['Title:', 'Analysis and Planning Consultant'],
#        ['Office:', 'OPAIR'],
#        ['Address:', '203 Rider Building'],
#        ['City:', 'University Park'],
#        ['State:', 'PA'],
#        ['Zip:', '16802'],
#        ['Country:', 'USA'],
#        ['Phone Number:', '814-863-8721'],
#        ['Extension:', ''],
#        ['Email Address:', 'mpg5717@psu.edu']],
#       'md': '|First Name:|Matthew|\n|---|---|\n|Last Name:|Gueguen|\n|Title:|Analysis and Planning Consultant|\n|Office:|OPAIR|\n|Address:|203 Rider Building|\n|City:|University Park|\n|State:|PA|\n|Zip:|16802|\n|Country:|USA|\n|Phone Number:|814-863-8721|\n|Extension:| |\n|Email Address:|mpg5717@psu.edu|',
#       'isPerfectTable': True,
#       'csv': '"First Name:","Matthew"\n"Last Name:","Gueguen"\n"Title:","Analysis and Planning Consultant"\n"Office:","OPAIR"\n"Address:","203 Rider Building"\n"City:","University Park"\n"State:","PA"\n"Zip:","16802"\n"Country:","USA"\n"Phone Number:","814-863-8721"\n"Extension:",""\n"Email Address:","mpg5717@psu.edu"'},
#      {'type': 'text',
#       'value': "Are your responses to the CDS posted for reference on your institution's website? (click to select from dropdown)\n\nYes\n\nIf yes, please provide a direct link to the posted CDS responses:\n\nhttps://opair.psu.edu/institutional‐research/projects/cds/",
#       'md': "Are your responses to the CDS posted for reference on your institution's website? (click to select from dropdown)\n\nYes\n\nIf yes, please provide a direct link to the posted CDS responses:\n\nhttps://opair.psu.edu/institutional‐research/projects/cds/"},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'A0A. Comments About CDS (not for publication)',
#       'md': '# A0A. Comments About CDS (not for publication)'},
#      {'type': 'text',
#       'value': 'We invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.\n\nEnter comments about CDS here:',
#       'md': 'We invite you to indicate if there are items on the CDS for which you cannot use the requested analytic convention, cannot provide data for the cohort requested, whose methodology is unclear, or about which you have questions or comments in general. This information will not be published but will help the publishers further refine CDS items.\n\nEnter comments about CDS here:'}]},
#    {'page': 2,
#     'text': "                                                                              CDS_2023_2024_FINAL\n A1. Address Information\nPlease enter general institution information below:\n                  Name of College or University                         Penn State University Park\n                  Street Address:                                       201 Old Main\n                  City:                                                 University Park\n                  State:                                                PA\n                  Zip:                                                  16802\n                  Country:                                              USA\n                  Main Institution Phone Number:                        (814) 865-4700\n                  Main Institution Website:                             http://www.psu.edu\n                  Main Institution Email:\n\n\nPlease enter Admissions Office information below:\n                  Street Address:                                       201 Shields Building\n                  City:                                                 University Park\n                  State:                                                PA\n                  Zip:                                                  16802\n                  Country:                                              USA\n                  Admissions Phone Number:                              (814) 865-5471\n                  Admissions Toll‐free Number:\n                  Admissions Website:                                   https://www.psu.edu/admission/\n                  Admissions Email Address:                             admissions@psu.edu\n\n\n                  Is there a separate URL for your school's online application? If yes, please specify:\n                                                                        http://admissions.psu.edu/\n\n\n                  If you have a mailing address other than the one listed above to which applications should be sent, please provide:",
#     'md': "# A1. Address Information\n\n|Name of College or University|Penn State University Park|\n|---|---|\n|Street Address|201 Old Main|\n|City|University Park|\n|State|PA|\n|Zip|16802|\n|Country|USA|\n|Main Institution Phone Number|(814) 865-4700|\n|Main Institution Website|http://www.psu.edu|\n|Main Institution Email| |\n\n# Admissions Office Information\n\n|Street Address|201 Shields Building|\n|---|---|\n|City|University Park|\n|State|PA|\n|Zip|16802|\n|Country|USA|\n|Admissions Phone Number|(814) 865-5471|\n|Admissions Toll-free Number| |\n|Admissions Website|https://www.psu.edu/admission/|\n|Admissions Email Address|admissions@psu.edu|\n\nIs there a separate URL for your school's online application? If yes, please specify:\n\nhttp://admissions.psu.edu/\n\nIf you have a mailing address other than the one listed above to which applications should be sent, please provide:",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'A1. Address Information',
#       'md': '# A1. Address Information'},
#      {'type': 'table',
#       'rows': [['Name of College or University', 'Penn State University Park'],
#        ['Street Address', '201 Old Main'],
#        ['City', 'University Park'],
#        ['State', 'PA'],
#        ['Zip', '16802'],
#        ['Country', 'USA'],
#        ['Main Institution Phone Number', '(814) 865-4700'],
#        ['Main Institution Website', 'http://www.psu.edu'],
#        ['Main Institution Email', '']],
#       'md': '|Name of College or University|Penn State University Park|\n|---|---|\n|Street Address|201 Old Main|\n|City|University Park|\n|State|PA|\n|Zip|16802|\n|Country|USA|\n|Main Institution Phone Number|(814) 865-4700|\n|Main Institution Website|http://www.psu.edu|\n|Main Institution Email| |',
#       'isPerfectTable': True,
#       'csv': '"Name of College or University","Penn State University Park"\n"Street Address","201 Old Main"\n"City","University Park"\n"State","PA"\n"Zip","16802"\n"Country","USA"\n"Main Institution Phone Number","(814) 865-4700"\n"Main Institution Website","http://www.psu.edu"\n"Main Institution Email",""'},
#      {'type': 'heading',
#       'lvl': 1,
#       'value': 'Admissions Office Information',
#       'md': '# Admissions Office Information'},
#      {'type': 'table',
#       'rows': [['Street Address', '201 Shields Building'],
#        ['City', 'University Park'],
#        ['State', 'PA'],
#        ['Zip', '16802'],
#        ['Country', 'USA'],
#        ['Admissions Phone Number', '(814) 865-5471'],
#        ['Admissions Toll-free Number', ''],
#        ['Admissions Website', 'https://www.psu.edu/admission/'],
#        ['Admissions Email Address', 'admissions@psu.edu']],
#       'md': '|Street Address|201 Shields Building|\n|---|---|\n|City|University Park|\n|State|PA|\n|Zip|16802|\n|Country|USA|\n|Admissions Phone Number|(814) 865-5471|\n|Admissions Toll-free Number| |\n|Admissions Website|https://www.psu.edu/admission/|\n|Admissions Email Address|admissions@psu.edu|',
#       'isPerfectTable': True,
#       'csv': '"Street Address","201 Shields Building"\n"City","University Park"\n"State","PA"\n"Zip","16802"\n"Country","USA"\n"Admissions Phone Number","(814) 865-5471"\n"Admissions Toll-free Number",""\n"Admissions Website","https://www.psu.edu/admission/"\n"Admissions Email Address","admissions@psu.edu"'},
#      {'type': 'text',
#       'value': "Is there a separate URL for your school's online application? If yes, please specify:\n\nhttp://admissions.psu.edu/\n\nIf you have a mailing address other than the one listed above to which applications should be sent, please provide:",
#       'md': "Is there a separate URL for your school's online application? If yes, please specify:\n\nhttp://admissions.psu.edu/\n\nIf you have a mailing address other than the one listed above to which applications should be sent, please provide:"}]},
#    {'page': 3,
#     'text': "                                                                     CDS_2023_2024_FINAL\nA2. Source of Institutional Control: (click to select from dropdown)\n                                                                                                 Public\n\n\nA3. Classify your undergraduate institution: (click to select from dropdown)\n                                                                                             Coeducational\n\n\nA4. Academic year calendar: (click to select from dropdown)\n                                                                                               Semester\n\n\nA4A. Describe if calendar differs by program or other:\n\n\nA5. Degrees offered by your institution (select all that apply).\n\n\n       X        Certificate                        X             Master's\n\n\n                Diploma                                          Post‐Master's certificate\n\n\n       X        Associate                          X             Doctoral degree ‐ research/scholarship\n\n\n                Terminal                           X             Doctoral degree ‐ professional practice\n\n\n                Transfer                                         Doctoral degree ‐ other\n\n\n       X        Bachelor's\n\n\n       X        Post‐Bachelor's certificate\n\n\nA6. Diversity, Equity, and Inclusion\nIf you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:\n                                                                https://www.psu.edu/this-is-penn-state/belonging/\n\n\n                                                               END OF SECTION A",
#     'md': "# CDS_2023_2024_FINAL\n\n|A2. Source of Institutional Control:|Public|\n|---|---|\n|A3. Classify your undergraduate institution:|Coeducational|\n|A4. Academic year calendar:|Semester|\n|A4A. Describe if calendar differs by program or other:| |\n|A5. Degrees offered by your institution (select all that apply).| |\n| |Certificate|\n|X|Master's|\n| |Diploma|\n|X|Post-Master's certificate|\n| |Associate|\n|X|Doctoral degree - research/scholarship|\n| |Terminal|\n|X|Doctoral degree - professional practice|\n| |Transfer|\n|X|Bachelor's|\n|X|Post-Bachelor's certificate|\n|A6. Diversity, Equity, and Inclusion| |\n|If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:|https://www.psu.edu/this-is-penn-state/belonging/|\n|END OF SECTION A| |",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'CDS_2023_2024_FINAL',
#       'md': '# CDS_2023_2024_FINAL'},
#      {'type': 'table',
#       'rows': [['A2. Source of Institutional Control:', 'Public'],
#        ['A3. Classify your undergraduate institution:', 'Coeducational'],
#        ['A4. Academic year calendar:', 'Semester'],
#        ['A4A. Describe if calendar differs by program or other:', ''],
#        ['A5. Degrees offered by your institution (select all that apply).',
#         ''],
#        ['', 'Certificate'],
#        ['X', "Master's"],
#        ['', 'Diploma'],
#        ['X', "Post-Master's certificate"],
#        ['', 'Associate'],
#        ['X', 'Doctoral degree - research/scholarship'],
#        ['', 'Terminal'],
#        ['X', 'Doctoral degree - professional practice'],
#        ['', 'Transfer'],
#        ['X', "Bachelor's"],
#        ['X', "Post-Bachelor's certificate"],
#        ['A6. Diversity, Equity, and Inclusion', ''],
#        ['If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:',
#         'https://www.psu.edu/this-is-penn-state/belonging/'],
#        ['END OF SECTION A', '']],
#       'md': "|A2. Source of Institutional Control:|Public|\n|---|---|\n|A3. Classify your undergraduate institution:|Coeducational|\n|A4. Academic year calendar:|Semester|\n|A4A. Describe if calendar differs by program or other:| |\n|A5. Degrees offered by your institution (select all that apply).| |\n| |Certificate|\n|X|Master's|\n| |Diploma|\n|X|Post-Master's certificate|\n| |Associate|\n|X|Doctoral degree - research/scholarship|\n| |Terminal|\n|X|Doctoral degree - professional practice|\n| |Transfer|\n|X|Bachelor's|\n|X|Post-Bachelor's certificate|\n|A6. Diversity, Equity, and Inclusion| |\n|If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:|https://www.psu.edu/this-is-penn-state/belonging/|\n|END OF SECTION A| |",
#       'isPerfectTable': True,
#       'csv': '"A2. Source of Institutional Control:","Public"\n"A3. Classify your undergraduate institution:","Coeducational"\n"A4. Academic year calendar:","Semester"\n"A4A. Describe if calendar differs by program or other:",""\n"A5. Degrees offered by your institution (select all that apply).",""\n"","Certificate"\n"X","Master\'s"\n"","Diploma"\n"X","Post-Master\'s certificate"\n"","Associate"\n"X","Doctoral degree - research/scholarship"\n"","Terminal"\n"X","Doctoral degree - professional practice"\n"","Transfer"\n"X","Bachelor\'s"\n"X","Post-Bachelor\'s certificate"\n"A6. Diversity, Equity, and Inclusion",""\n"If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:","https://www.psu.edu/this-is-penn-state/belonging/"\n"END OF SECTION A",""'}]},
#    {'page': 4,
#     'text': '                                                                              CDS_2023_2024_FINAL\n                                                               B. ENROLLMENT AND PERSISTENCE\n\n\nB1. Institutional Enrollment\nProvide numbers of students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n\n   1. Report students formaly designated as "first professional" in the graduate counts.\n\n\n   2. If your institution collects and reports non‐binary gender data, please use the "Another Gender" category.\n      In cases where gender information is not provided, please distribute across the two binary categories.\n For more information on how to report study abroad students, please see NCES.GOV documentation.\n                                                                          Men                                   Women                               Another Gender\n                                                            Full Time            Part Time           Full Time           Part Time            Full Time           Part Time\n                                                           Enrollment           Enrollment          Enrollment           Enrollment          Enrollment          Enrollment\n                                                                                                    UNDERGRADUATE STUDENTS\n    Degree‐seeking, first‐time, first‐year\n    students                                                          4450                   20               4475                    15                  79                 1\n\n\n    Other first‐year, degree‐seeking students                          816                   23                 649                   10                  11                 1\n    All other degree‐seeking undergraduate\n    students                                                        16123                   535              14128                  296                  220                 8\n\n\n  Total degree‐seeking undergraduate students                21,389.0              578.0              19,252.0              321.0                310.0                10.0\n\n\n    All other undergraduates enrolled in credit\n    courses                                                              35                 213                   24                  85                    1                5\n\n\n                    Total Undergraduate Students             21,424.0              791.0              19,276.0              406.0                311.0                15.0\n\n\n                                       Total part‐time undergraduate degree‐seeking students                                909.0\n\n\n                                       Total full‐time undergraduate degree‐seeking students                              40,951.0\n\n\n                                       Total of all undergraduate degree‐seeking students                                 41,860.0\n                                       Total of all undergraduate students enrolled                                       42,223.0',
#     'md': '# B. ENROLLMENT AND PERSISTENCE\n\n| |Men|Women|Another Gender|\n|---|---|---|---|\n|Full Time Enrollment|21,424.0|19,276.0|311.0|\n|Part Time Enrollment|791.0|406.0|15.0|\n\n| |Full Time|Part Time|Full Time|Part Time|Full Time|Part Time|\n|---|---|---|---|---|---|---|\n| |Enrollment|Enrollment|Enrollment|Enrollment|Enrollment|Enrollment|\n|Degree-seeking, first-time, first-year students|4450|20|4475|15|79|1|\n|Other first-year, degree-seeking students|816|23|649|10|11|1|\n|All other degree-seeking undergraduate students|16123|535|14128|296|220|8|\n|Total degree-seeking undergraduate students|21,389.0|578.0|19,252.0|321.0|310.0|10.0|\n|All other undergraduates enrolled in credit courses|35|213|24|85|1|5|\n|Total Undergraduate Students|21,424.0|791.0|19,276.0|406.0|311.0|15.0|\n\nTotal part-time undergraduate degree-seeking students: 909.0\n\nTotal full-time undergraduate degree-seeking students: 40,951.0\n\nTotal of all undergraduate degree-seeking students: 41,860.0\n\nTotal of all undergraduate students enrolled: 42,223.0',
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'B. ENROLLMENT AND PERSISTENCE',
#       'md': '# B. ENROLLMENT AND PERSISTENCE'},
#      {'type': 'table',
#       'rows': [['', 'Men', 'Women', 'Another Gender'],
#        ['Full Time Enrollment', '21,424.0', '19,276.0', '311.0'],
#        ['Part Time Enrollment', '791.0', '406.0', '15.0']],
#       'md': '| |Men|Women|Another Gender|\n|---|---|---|---|\n|Full Time Enrollment|21,424.0|19,276.0|311.0|\n|Part Time Enrollment|791.0|406.0|15.0|',
#       'isPerfectTable': True,
#       'csv': '"","Men","Women","Another Gender"\n"Full Time Enrollment","21,424.0","19,276.0","311.0"\n"Part Time Enrollment","791.0","406.0","15.0"'},
#      {'type': 'table',
#       'rows': [['',
#         'Full Time',
#         'Part Time',
#         'Full Time',
#         'Part Time',
#         'Full Time',
#         'Part Time'],
#        ['',
#         'Enrollment',
#         'Enrollment',
#         'Enrollment',
#         'Enrollment',
#         'Enrollment',
#         'Enrollment'],
#        ['Degree-seeking, first-time, first-year students',
#         '4450',
#         '20',
#         '4475',
#         '15',
#         '79',
#         '1'],
#        ['Other first-year, degree-seeking students',
#         '816',
#         '23',
#         '649',
#         '10',
#         '11',
#         '1'],
#        ['All other degree-seeking undergraduate students',
#         '16123',
#         '535',
#         '14128',
#         '296',
#         '220',
#         '8'],
#        ['Total degree-seeking undergraduate students',
#         '21,389.0',
#         '578.0',
#         '19,252.0',
#         '321.0',
#         '310.0',
#         '10.0'],
#        ['All other undergraduates enrolled in credit courses',
#         '35',
#         '213',
#         '24',
#         '85',
#         '1',
#         '5'],
#        ['Total Undergraduate Students',
#         '21,424.0',
#         '791.0',
#         '19,276.0',
#         '406.0',
#         '311.0',
#         '15.0']],
#       'md': '| |Full Time|Part Time|Full Time|Part Time|Full Time|Part Time|\n|---|---|---|---|---|---|---|\n| |Enrollment|Enrollment|Enrollment|Enrollment|Enrollment|Enrollment|\n|Degree-seeking, first-time, first-year students|4450|20|4475|15|79|1|\n|Other first-year, degree-seeking students|816|23|649|10|11|1|\n|All other degree-seeking undergraduate students|16123|535|14128|296|220|8|\n|Total degree-seeking undergraduate students|21,389.0|578.0|19,252.0|321.0|310.0|10.0|\n|All other undergraduates enrolled in credit courses|35|213|24|85|1|5|\n|Total Undergraduate Students|21,424.0|791.0|19,276.0|406.0|311.0|15.0|',
#       'isPerfectTable': True,
#       'csv': '"","Full Time","Part Time","Full Time","Part Time","Full Time","Part Time"\n"","Enrollment","Enrollment","Enrollment","Enrollment","Enrollment","Enrollment"\n"Degree-seeking, first-time, first-year students","4450","20","4475","15","79","1"\n"Other first-year, degree-seeking students","816","23","649","10","11","1"\n"All other degree-seeking undergraduate students","16123","535","14128","296","220","8"\n"Total degree-seeking undergraduate students","21,389.0","578.0","19,252.0","321.0","310.0","10.0"\n"All other undergraduates enrolled in credit courses","35","213","24","85","1","5"\n"Total Undergraduate Students","21,424.0","791.0","19,276.0","406.0","311.0","15.0"'},
#      {'type': 'text',
#       'value': 'Total part-time undergraduate degree-seeking students: 909.0\n\nTotal full-time undergraduate degree-seeking students: 40,951.0\n\nTotal of all undergraduate degree-seeking students: 41,860.0\n\nTotal of all undergraduate students enrolled: 42,223.0',
#       'md': 'Total part-time undergraduate degree-seeking students: 909.0\n\nTotal full-time undergraduate degree-seeking students: 40,951.0\n\nTotal of all undergraduate degree-seeking students: 41,860.0\n\nTotal of all undergraduate students enrolled: 42,223.0'}]},
#    {'page': 5,
#     'text': '                                                                        CDS_2023_2024_FINAL\n\n\n                                                                    Men                                 Women                            Another Gender\n\n\n                                                       Full Time           Part Time          Full Time          Part Time          Full Time          Part Time\n                                                      Enrollment          Enrollment         Enrollment          Enrollment       Enrollment          Enrollment\n\n\n                                                                                                 GRADUATE STUDENTS\n\n\nDegree‐seeking, first‐time                                       929                   25               840                   16                33                0\n\n\nAll other degree‐seeking                                        2488                 176               2127                 179                 61                0\nAll other graduates enrolled in credit\ncourses                                                              1                 24                   3                 10                 0                0\n\n\n                      Total Graduate Students           3,418.0              225.0             2,970.0              205.0              94.0                 0.0\n\n\n                                  Total part‐time graduate degree‐seeking students                                  396.0\n\n\n                                  Total full‐time graduate degree‐seeking students                                 6,478.0\n\n\n                                  Total of all graduate degree‐seeking students                                    6,874.0\n\n\n                                  Total of all graduate   students enrolled                                        6,912.0',
#     'md': '| |Men| |Women| |Another Gender|\n|---|---|---|---|---|---|\n| |Full Time|Part Time|Full Time|Part Time|Full Time|Part Time|\n| | | |GRADUATE STUDENTS|\n|Degree-seeking, first-time|929|25|840|16|33|0|\n|All other degree-seeking|2488|176|2127|179|61|0|\n|All other graduates enrolled in credit courses|1|24|3|10|0|0|\n|Total Graduate Students|3,418.0|225.0|2,970.0|205.0|94.0|0.0|\n|Total part-time graduate degree-seeking students| | | |396.0|\n|Total full-time graduate degree-seeking students| | | |6,478.0|\n|Total of all graduate degree-seeking students| | | |6,874.0|\n|Total of all graduate students enrolled| | | |6,912.0|',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['', 'Men', '', 'Women', '', 'Another Gender'],
#        ['',
#         'Full Time',
#         'Part Time',
#         'Full Time',
#         'Part Time',
#         'Full Time',
#         'Part Time'],
#        ['', '', '', 'GRADUATE STUDENTS'],
#        ['Degree-seeking, first-time', '929', '25', '840', '16', '33', '0'],
#        ['All other degree-seeking', '2488', '176', '2127', '179', '61', '0'],
#        ['All other graduates enrolled in credit courses',
#         '1',
#         '24',
#         '3',
#         '10',
#         '0',
#         '0'],
#        ['Total Graduate Students',
#         '3,418.0',
#         '225.0',
#         '2,970.0',
#         '205.0',
#         '94.0',
#         '0.0'],
#        ['Total part-time graduate degree-seeking students',
#         '',
#         '',
#         '',
#         '396.0'],
#        ['Total full-time graduate degree-seeking students',
#         '',
#         '',
#         '',
#         '6,478.0'],
#        ['Total of all graduate degree-seeking students',
#         '',
#         '',
#         '',
#         '6,874.0'],
#        ['Total of all graduate students enrolled', '', '', '', '6,912.0']],
#       'md': '| |Men| |Women| |Another Gender|\n|---|---|---|---|---|---|\n| |Full Time|Part Time|Full Time|Part Time|Full Time|Part Time|\n| | | |GRADUATE STUDENTS|\n|Degree-seeking, first-time|929|25|840|16|33|0|\n|All other degree-seeking|2488|176|2127|179|61|0|\n|All other graduates enrolled in credit courses|1|24|3|10|0|0|\n|Total Graduate Students|3,418.0|225.0|2,970.0|205.0|94.0|0.0|\n|Total part-time graduate degree-seeking students| | | |396.0|\n|Total full-time graduate degree-seeking students| | | |6,478.0|\n|Total of all graduate degree-seeking students| | | |6,874.0|\n|Total of all graduate students enrolled| | | |6,912.0|',
#       'isPerfectTable': False,
#       'csv': '"","Men","","Women","","Another Gender"\n"","Full Time","Part Time","Full Time","Part Time","Full Time","Part Time"\n"","","","GRADUATE STUDENTS"\n"Degree-seeking, first-time","929","25","840","16","33","0"\n"All other degree-seeking","2488","176","2127","179","61","0"\n"All other graduates enrolled in credit courses","1","24","3","10","0","0"\n"Total Graduate Students","3,418.0","225.0","2,970.0","205.0","94.0","0.0"\n"Total part-time graduate degree-seeking students","","","","396.0"\n"Total full-time graduate degree-seeking students","","","","6,478.0"\n"Total of all graduate degree-seeking students","","","","6,874.0"\n"Total of all graduate students enrolled","","","","6,912.0"'}]},
#    {'page': 6,
#     'text': '                                                                                CDS_2023_2024_FINAL\n\n\nB2. Enrollment by Racial/Ethnic Category\n\n\nProvide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15,\n2023.\n1. Include international students only in the category "Nonresidents."\n2. Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n3. Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons\nwho are non‐Hispanic multi‐racial should be reported only under "Two or more races."\n4. New guidance from IPEDS for reporting aggregate data: "Racial/ethnic designations are requested only for United States citizens, residents, and other\neligible non‐citizens. Eligible non‐citizens include all students who completed high school or a GED equivalency within the United States (including DACA\nand undocumented students) and who were not on an F‐1 non‐immigrant student visa at the Ɵme of high school graduaƟon."\n5. More information about other eligible (for financial aid purposes) non‐citizens is available at\nhttps://studentaid.gov/understandaid/eligibility/requirements/non‐us‐citizens.\n6. Nonresident – A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does\nnot have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category. Nonresidents are to be\nreported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.\n                                                                    Degree‐seeking,                            Degree‐seeking                        Total Undergraduates\n                                                                 First‐time, First‐year                       Undergraduates                   (both degree‐seeking and non‐\n                                                                                                      (include first‐time, first‐year)                   degree‐seeking)\nInternational (nonresidents)                                                                  652                                      4097                                      4169\nHispanic/Latino                                                                              1058                                      3833                                      3846\nBlack or African American, non‐Hispanic                                                       468                                      1968                                      1974\nWhite, non‐Hispanic                                                                          5712                                    26352                                      26523\nAmerican Indian or Alaska Native, non‐\nHispanic                                                                                        19                                        58                                         58\nAsian, non‐Hispanic                                                                           542                                      2991                                      2996\nNative Hawaiian or other Pacific Islander,\nnon‐Hispanic                                                                                      6                                       29                                         29\nTwo or more races, non‐Hispanic                                                               378                                      1613                                      1614\nRace and/or ethnicity unknown                                                                 205                                        9 ...
#     'md': '# B2. Enrollment by Racial/Ethnic Category\n\nProvide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n1. Include international students only in the category "Nonresidents."\n\n2. Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n\n3. Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non‐Hispanic multi‐racial should be reported only under "Two or more races."\n\n4. New guidance from IPEDS for reporting aggregate data: "Racial/ethnic designations are requested only for United States citizens, residents, and other eligible non‐citizens. Eligible non‐citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F‐1 non‐immigrant student visa at the time of high school graduation."\n\n5. More information about other eligible (for financial aid purposes) non‐citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non‐us‐citizens.\n\n6. Nonresident – A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category. Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.\n\n| |Degree‐seeking, First‐time, First‐year|Degree‐seeking Undergraduates (include first‐time, first‐year)|Total Undergraduates (both degree‐seeking and non‐degree‐seeking)|\n|---|---|---|---|\n|International (nonresidents)|652|4097|4169|\n|Hispanic/Latino|1058|3833|3846|\n|Black or African American, non‐Hispanic|468|1968|1974|\n|White, non‐Hispanic|5712|26352|26523|\n|American Indian or Alaska Native, non‐Hispanic|19|58|58|\n|Asian, non‐Hispanic|542|2991|2996|\n|Native Hawaiian or other Pacific Islander, non‐Hispanic|6|29|29|\n|Two or more races, non‐Hispanic|378|1613|1614|\n|Race and/or ethnicity unknown|205|919|1014|\n|Total|9,040.0|41,860.0|42,223.0|',
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'B2. Enrollment by Racial/Ethnic Category',
#       'md': '# B2. Enrollment by Racial/Ethnic Category'},
#      {'type': 'text',
#       'value': 'Provide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n1. Include international students only in the category "Nonresidents."\n\n2. Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n\n3. Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non‐Hispanic multi‐racial should be reported only under "Two or more races."\n\n4. New guidance from IPEDS for reporting aggregate data: "Racial/ethnic designations are requested only for United States citizens, residents, and other eligible non‐citizens. Eligible non‐citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F‐1 non‐immigrant student visa at the time of high school graduation."\n\n5. More information about other eligible (for financial aid purposes) non‐citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non‐us‐citizens.\n\n6. Nonresident – A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category. Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.',
#       'md': 'Provide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.\n\n1. Include international students only in the category "Nonresidents."\n\n2. Complete the “Total Undergraduates” column only if you cannot provide data for the first two columns.\n\n3. Report as your institution reports to IPEDS: persons who are Hispanic should be reported only on the Hispanic line, not under any race, and persons who are non‐Hispanic multi‐racial should be reported only under "Two or more races."\n\n4. New guidance from IPEDS for reporting aggregate data: "Racial/ethnic designations are requested only for United States citizens, residents, and other eligible non‐citizens. Eligible non‐citizens include all students who completed high school or a GED equivalency within the United States (including DACA and undocumented students) and who were not on an F‐1 non‐immigrant student visa at the time of high school graduation."\n\n5. More information about other eligible (for financial aid purposes) non‐citizens is available at https://studentaid.gov/understandaid/eligibility/requirements/non‐us‐citizens.\n\n6. Nonresident – A person who is not a citizen or national of the United States and who is in this country on a student visa or temporary basis and does not have the right to remain indefinitely. Do not include DACA, undocumented, or other eligible noncitizens in this category. Nonresidents are to be reported separately, in the boxes provided, rather than included in any of the seven racial/ethnic categories or in race/ethnicity unknown.'},
#      {'type': 'table',
#       'rows': [['',
#         'Degree‐seeking, First‐time, First‐year',
#         'Degree‐seeking Undergraduates (include first‐time, first‐year)',
#         'Total Undergraduates (both degree‐seeking and non‐degree‐seeking)'],
#        ['International (nonresidents)', '652', '4097', '4169'],
#        ['Hispanic/Latino', '1058', '3833', '3846'],
#        ['Black or African American, non‐Hispanic', '468', '1968', '1974'],
#        ['White, non‐Hispanic', '5712', '26352', '26523'],
#        ['American Indian or Alaska Native, non‐Hispanic', '19', '58', '58'],
#        ['Asian, non‐Hispanic', '542', '2991', '2996'],
#        ['Native Hawaiian or other Pacific Islander, non‐Hispanic',
#         '6',
#         '29',
#         '29'],
#        ['Two or more races, non‐Hispanic', '378', '1613', '1614'],
#        ['Race and/or ethnicity unknown', '205', '919', '1014'],
#        ['Total', '9,040.0', '41,860.0', '42,223.0']],
#       'md': '| |Degree‐seeking, First‐time, First‐year|Degree‐seeking Undergraduates (include first‐time, first‐year)|Total Undergraduates (both degree‐seeking and non‐degree‐seeking)|\n|---|---|---|---|\n|International (nonresidents)|652|4097|4169|\n|Hispanic/Latino|1058|3833|3846|\n|Black or African American, non‐Hispanic|468|1968|1974|\n|White, non‐Hispanic|5712|26352|26523|\n|American Indian or Alaska Native, non‐Hispanic|19|58|58|\n|Asian, non‐Hispanic|542|2991|2996|\n|Native Hawaiian or other Pacific Islander, non‐Hispanic|6|29|29|\n|Two or more races, non‐Hispanic|378|1613|1614|\n|Race and/or ethnicity unknown|205|919|1014|\n|Total|9,040.0|41,860.0|42,223.0|',
#       'isPerfectTable': True,
#       'csv': '"","Degree‐seeking, First‐time, First‐year","Degree‐seeking Undergraduates (include first‐time, first‐year)","Total Undergraduates (both degree‐seeking and non‐degree‐seeking)"\n"International (nonresidents)","652","4097","4169"\n"Hispanic/Latino","1058","3833","3846"\n"Black or African American, non‐Hispanic","468","1968","1974"\n"White, non‐Hispanic","5712","26352","26523"\n"American Indian or Alaska Native, non‐Hispanic","19","58","58"\n"Asian, non‐Hispanic","542","2991","2996"\n"Native Hawaiian or other Pacific Islander, non‐Hispanic","6","29","29"\n"Two or more races, non‐Hispanic","378","1613","1614"\n"Race and/or ethnicity unknown","205","919","1014"\n"Total","9,040.0","41,860.0","42,223.0"'}]},
#    {'page': 7,
#     'text': "                                                                               CDS_2023_2024_FINAL\n\n\nB3. Persistence / Degrees\nNumber of degrees awarded by your institution from July 1, 2022, to June 30, 2023.\n\n\n                        Certificate/Diploma                      774                                               Associate's Degrees    5\n\n\n                         Bachelor's Degrees                    10769                                           Post‐Bachelor's Degrees   65\n\n\n                           Master's Degrees                     1532                                            Post‐Master's Degrees     0\n\n\n  Doctoral degree ‐ research/scholarship                         661                         Doctoral degree ‐ professional practice    113\n\n\n                    Doctoral degree ‐ other                       0",
#     'md': "# CDS_2023_2024_FINAL\n\n|Certificate/Diploma|774|Associate's Degrees|5|\n|---|---|---|---|\n|Bachelor's Degrees|10769|Post‐Bachelor's Degrees|65|\n|Master's Degrees|1532|Post‐Master's Degrees|0|\n|Doctoral degree ‐ research/scholarship|661|Doctoral degree ‐ professional practice|113|\n|Doctoral degree ‐ other|0| | |",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'CDS_2023_2024_FINAL',
#       'md': '# CDS_2023_2024_FINAL'},
#      {'type': 'table',
#       'rows': [['Certificate/Diploma', '774', "Associate's Degrees", '5'],
#        ["Bachelor's Degrees", '10769', "Post‐Bachelor's Degrees", '65'],
#        ["Master's Degrees", '1532', "Post‐Master's Degrees", '0'],
#        ['Doctoral degree ‐ research/scholarship',
#         '661',
#         'Doctoral degree ‐ professional practice',
#         '113'],
#        ['Doctoral degree ‐ other', '0', '', '']],
#       'md': "|Certificate/Diploma|774|Associate's Degrees|5|\n|---|---|---|---|\n|Bachelor's Degrees|10769|Post‐Bachelor's Degrees|65|\n|Master's Degrees|1532|Post‐Master's Degrees|0|\n|Doctoral degree ‐ research/scholarship|661|Doctoral degree ‐ professional practice|113|\n|Doctoral degree ‐ other|0| | |",
#       'isPerfectTable': True,
#       'csv': '"Certificate/Diploma","774","Associate\'s Degrees","5"\n"Bachelor\'s Degrees","10769","Post‐Bachelor\'s Degrees","65"\n"Master\'s Degrees","1532","Post‐Master\'s Degrees","0"\n"Doctoral degree ‐ research/scholarship","661","Doctoral degree ‐ professional practice","113"\n"Doctoral degree ‐ other","0","",""'}]},
#    {'page': 8,
# ...
#     'md': "# CDS_2023_2024_FINAL\n\n|Category|Diploma/Certificates|Associate|Bachelor's|Categories to Include|\n|---|---|---|---|---|\n|Agriculture|0.00%|0.00%|3.64%|1|\n|Natural resources and conservation|0.00%|0.00%|0.98%|3|\n|Architecture|0.00%|0.00%|0.67%|4|\n|Area, ethnic, and gender studies|0.56%|0.00%|0.31%|5|\n|Communication/journalism|0.00%|0.00%|6.95%|9|\n|Communication technologies|0.00%|0.00%|0.00%|10|\n|Computer and information sciences|91.06%|0.00%|11.49%|11|\n|Personal and culinary services|0.00%|0.00%|0.00%|12|\n|Education|0.00%|0.00%|3.21%|13|\n|Engineering|0.00%|0.00%|14.74%|14|\n|Engineering technologies|0.00%|0.00%|0.00%|15|\n|Foreign languages, literatures, and linguistics|0.00%|0.00%|1.01%|16|\n|Family and consumer sciences|0.00%|0.00%|0.73%|19|\n|Law/legal studies|0.00%|0.00%|0.00%|22|\n|English|0.00%|0.00%|0.69%|23|\n|Liberal arts/general studies|0.00%|80.00%|0.10%|24|",
#     'images': [],
#     'items': [{'type': 'heading',
#       'lvl': 1,
#       'value': 'CDS_2023_2024_FINAL',
#       'md': '# CDS_2023_2024_FINAL'},
#      {'type': 'table',
#       'rows': [['Category',
#         'Diploma/Certificates',
#         'Associate',
#         "Bachelor's",
#         'Categories to Include'],
#        ['Agriculture', '0.00%', '0.00%', '3.64%', '1'],
#        ['Natural resources and conservation', '0.00%', '0.00%', '0.98%', '3'],
#        ['Architecture', '0.00%', '0.00%', '0.67%', '4'],
#        ['Area, ethnic, and gender studies', '0.56%', '0.00%', '0.31%', '5'],
#        ['Communication/journalism', '0.00%', '0.00%', '6.95%', '9'],
#        ['Communication technologies', '0.00%', '0.00%', '0.00%', '10'],
#        ['Computer and information sciences',
#         '91.06%',
#         '0.00%',
#         '11.49%',
#         '11'],
#        ['Personal and culinary services', '0.00%', '0.00%', '0.00%', '12'],
#        ['Education', '0.00%', '0.00%', '3.21%', '13'],
#        ['Engineering', '0.00%', '0.00%', '14.74%', '14'],
#        ['Engineering technologies', '0.00%', '0.00%', '0.00%', '15'],
#        ['Foreign languages, literatures, and linguistics',
#         '0.00%',
#         '0.00%',
#         '1.01%',
#         '16'],
#        ['Family and consumer sciences', '0.00%', '0.00%', '0.73%', '19'],
#        ['Law/legal studies', '0.00%', '0.00%', '0.00%', '22'],
#        ['English', '0.00%', '0.00%', '0.69%', '23'],
#        ['Liberal arts/general studies', '0.00%', '80.00%', '0.10%', '24']],
#       'md': "|Category|Diploma/Certificates|Associate|Bachelor's|Categories to Include|\n|---|---|---|---|---|\n|Agriculture|0.00%|0.00%|3.64%|1|\n|Natural resources and conservation|0.00%|0.00%|0.98%|3|\n|Architecture|0.00%|0.00%|0.67%|4|\n|Area, ethnic, and gender studies|0.56%|0.00%|0.31%|5|\n|Communication/journalism|0.00%|0.00%|6.95%|9|\n|Communication technologies|0.00%|0.00%|0.00%|10|\n|Computer and information sciences|91.06%|0.00%|11.49%|11|\n|Personal and culinary services|0.00%|0.00%|0.00%|12|\n|Education|0.00%|0.00%|3.21%|13|\n|Engineering|0.00%|0.00%|14.74%|14|\n|Engineering technologies|0.00%|0.00%|0.00%|15|\n|Foreign languages, literatures, and linguistics|0.00%|0.00%|1.01%|16|\n|Family and consumer sciences|0.00%|0.00%|0.73%|19|\n|Law/legal studies|0.00%|0.00%|0.00%|22|\n|English|0.00%|0.00%|0.69%|23|\n|Liberal arts/general studies|0.00%|80.00%|0.10%|24|",
#       'isPerfectTable': True,
#       'csv': '"Category","Diploma/Certificates","Associate","Bachelor\'s","Categories to Include"\n"Agriculture","0.00%","0.00%","3.64%","1"\n"Natural resources and conservation","0.00%","0.00%","0.98%","3"\n"Architecture","0.00%","0.00%","0.67%","4"\n"Area, ethnic, and gender studies","0.56%","0.00%","0.31%","5"\n"Communication/journalism","0.00%","0.00%","6.95%","9"\n"Communication technologies","0.00%","0.00%","0.00%","10"\n"Computer and information sciences","91.06%","0.00%","11.49%","11"\n"Personal and culinary services","0.00%","0.00%","0.00%","12"\n"Education","0.00%","0.00%","3.21%","13"\n"Engineering","0.00%","0.00%","14.74%","14"\n"Engineering technologies","0.00%","0.00%","0.00%","15"\n"Foreign languages, literatures, and linguistics","0.00%","0.00%","1.01%","16"\n"Family and consumer sciences","0.00%","0.00%","0.73%","19"\n"Law/legal studies","0.00%","0.00%","0.00%","22"\n"English","0.00%","0.00%","0.69%","23"\n"Liberal arts/general studies","0.00%","80.00%","0.10%","24"'}]},
#    {'page': 57,
#     'text': '                                                   CDS_2023_2024_FINAL\n\n\nLibrary science                                                         0.00%   0.00%   0.00%      25\nBiological/life sciences                                                0.00%   0.00%   6.54%      26\nMathematics and statistics                                              0.00%   0.00%   2.14%      27\nMilitary science and military technologies                              0.00%   0.00%   0.00%  28 and 29\nInterdisciplinary studies                                               0.00%   0.00%   3.26%      30\nParks and recreation                                                    0.00%   0.00%   2.66%      31\nPhilosophy and religious studies                                        5.59%   0.00%   0.33%      38\nTheology and religious vocations                                        0.00%   0.00%   0.00%      39\nPhysical sciences                                                       2.23%   0.00%   3.06%      40\nScience technologies                                                    0.00%   0.00%   0.20%      41\nPsychology                                                              0.00%   0.00%   4.14%      42\nHomeland Security, law enforcement, firefighting,                                                  43\nand protective services                                                 0.00%  20.00%   2.46%\nPublic administration and social services                               0.00%   0.00%   0.00%      44\nSocial sciences                                                         0.00%   0.00%   6.88%      45\nConstruction trades                                                     0.00%   0.00%   0.00%      46\nMechanic and repair technologies                                        0.00%   0.00%   0.00%      47\nPrecision production                                                    0.00%   0.00%   0.00%      48\nTransportation and materials moving                                     0.00%   0.00%   0.00%      49\nVisual and performing arts                                              0.00%   0.00%   2.23%      50\nHealth professions and related programs                                 0.56%   0.00%   4.45%      51\nBusiness/marketing                                                      0.00%   0.00%  16.64%      52\nHistory                                                                 0.00%   0.00%   0.48%      54\nOther\n\n\n                                                   END OF SECTION J',
#     'md': '|Field of Study|2023|2024|Final|Code|\n|---|---|---|---|---|\n|Library science|0.00%|0.00%|0.00%|25|\n|Biological/life sciences|0.00%|0.00%|6.54%|26|\n|Mathematics and statistics|0.00%|0.00%|2.14%|27|\n|Military science and military technologies|0.00%|0.00%|0.00%|28 and 29|\n|Interdisciplinary studies|0.00%|0.00%|3.26%|30|\n|Parks and recreation|0.00%|0.00%|2.66%|31|\n|Philosophy and religious studies|5.59%|0.00%|0.33%|38|\n|Theology and religious vocations|0.00%|0.00%|0.00%|39|\n|Physical sciences|2.23%|0.00%|3.06%|40|\n|Science technologies|0.00%|0.00%|0.20%|41|\n|Psychology|0.00%|0.00%|4.14%|42|\n|Homeland Security, law enforcement, firefighting, and protective services|0.00%|20.00%|2.46%| |\n|Public administration and social services|0.00%|0.00%|0.00%|44|\n|Social sciences|0.00%|0.00%|6.88%|45|\n|Construction trades|0.00%|0.00%|0.00%|46|\n|Mechanic and repair technologies|0.00%|0.00%|0.00%|47|\n|Precision production|0.00%|0.00%|0.00%|48|\n|Transportation and materials moving|0.00%|0.00%|0.00%|49|\n|Visual and performing arts|0.00%|0.00%|2.23%|50|\n|Health professions and related programs|0.56%|0.00%|4.45%|51|\n|Business/marketing|0.00%|0.00%|16.64%|52|\n|History|0.00%|0.00%|0.48%|54|\n|Other| | | | |',
#     'images': [],
#     'items': [{'type': 'table',
#       'rows': [['Field of Study', '2023', '2024', 'Final', 'Code'],
#        ['Library science', '0.00%', '0.00%', '0.00%', '25'],
#        ['Biological/life sciences', '0.00%', '0.00%', '6.54%', '26'],
#        ['Mathematics and statistics', '0.00%', '0.00%', '2.14%', '27'],
#        ['Military science and military technologies',
#         '0.00%',
#         '0.00%',
#         '0.00%',
#         '28 and 29'],
#        ['Interdisciplinary studies', '0.00%', '0.00%', '3.26%', '30'],
#        ['Parks and recreation', '0.00%', '0.00%', '2.66%', '31'],
#        ['Philosophy and religious studies', '5.59%', '0.00%', '0.33%', '38'],
#        ['Theology and religious vocations', '0.00%', '0.00%', '0.00%', '39'],
#        ['Physical sciences', '2.23%', '0.00%', '3.06%', '40'],
#        ['Science technologies', '0.00%', '0.00%', '0.20%', '41'],
#        ['Psychology', '0.00%', '0.00%', '4.14%', '42'],
#        ['Homeland Security, law enforcement, firefighting, and protective services',
#         '0.00%',
#         '20.00%',
#         '2.46%',
#         ''],
#        ['Public administration and social services',
#         '0.00%',
#         '0.00%',
#         '0.00%',
#         '44'],
#        ['Social sciences', '0.00%', '0.00%', '6.88%', '45'],
#        ['Construction trades', '0.00%', '0.00%', '0.00%', '46'],
#        ['Mechanic and repair technologies', '0.00%', '0.00%', '0.00%', '47'],
#        ['Precision production', '0.00%', '0.00%', '0.00%', '48'],
#        ['Transportation and materials moving',
#         '0.00%',
#         '0.00%',
#         '0.00%',
#         '49'],
#        ['Visual and performing arts', '0.00%', '0.00%', '2.23%', '50'],
#        ['Health professions and related programs',
#         '0.56%',
#         '0.00%',
#         '4.45%',
#         '51'],
#        ['Business/marketing', '0.00%', '0.00%', '16.64%', '52'],
#        ['History', '0.00%', '0.00%', '0.48%', '54'],
#        ['Other', '', '', '', '']],
#       'md': '|Field of Study|2023|2024|Final|Code|\n|---|---|---|---|---|\n|Library science|0.00%|0.00%|0.00%|25|\n|Biological/life sciences|0.00%|0.00%|6.54%|26|\n|Mathematics and statistics|0.00%|0.00%|2.14%|27|\n|Military science and military technologies|0.00%|0.00%|0.00%|28 and 29|\n|Interdisciplinary studies|0.00%|0.00%|3.26%|30|\n|Parks and recreation|0.00%|0.00%|2.66%|31|\n|Philosophy and religious studies|5.59%|0.00%|0.33%|38|\n|Theology and religious vocations|0.00%|0.00%|0.00%|39|\n|Physical sciences|2.23%|0.00%|3.06%|40|\n|Science technologies|0.00%|0.00%|0.20%|41|\n|Psychology|0.00%|0.00%|4.14%|42|\n|Homeland Security, law enforcement, firefighting, and protective services|0.00%|20.00%|2.46%| |\n|Public administration and social services|0.00%|0.00%|0.00%|44|\n|Social sciences|0.00%|0.00%|6.88%|45|\n|Construction trades|0.00%|0.00%|0.00%|46|\n|Mechanic and repair technologies|0.00%|0.00%|0.00%|47|\n|Precision production|0.00%|0.00%|0.00%|48|\n|Transportation and materials moving|0.00%|0.00%|0.00%|49|\n|Visual and performing arts|0.00%|0.00%|2.23%|50|\n|Health professions and related programs|0.56%|0.00%|4.45%|51|\n|Business/marketing|0.00%|0.00%|16.64%|52|\n|History|0.00%|0.00%|0.48%|54|\n|Other| | | | |',
#       'isPerfectTable': True,
#       'csv': '"Field of Study","2023","2024","Final","Code"\n"Library science","0.00%","0.00%","0.00%","25"\n"Biological/life sciences","0.00%","0.00%","6.54%","26"\n"Mathematics and statistics","0.00%","0.00%","2.14%","27"\n"Military science and military technologies","0.00%","0.00%","0.00%","28 and 29"\n"Interdisciplinary studies","0.00%","0.00%","3.26%","30"\n"Parks and recreation","0.00%","0.00%","2.66%","31"\n"Philosophy and religious studies","5.59%","0.00%","0.33%","38"\n"Theology and religious vocations","0.00%","0.00%","0.00%","39"\n"Physical sciences","2.23%","0.00%","3.06%","40"\n"Science technologies","0.00%","0.00%","0.20%","41"\n"Psychology","0.00%","0.00%","4.14%","42"\n"Homeland Security, law enforcement, firefighting, and protective services","0.00%","20.00%","2.46%",""\n"Public administration and social services","0.00%","0.00%","0.00%","44"\n"Social sciences","0.00%","0.00%","6.88%","45"\n"Construction trades","0.00%","0.00%","0.00%","46"\n"Mechanic and repair technologies","0.00%","0.00%","0.00%","47"\n"Precision production","0.00%","0.00%","0.00%","48"\n"Transportation and materials moving","0.00%","0.00%","0.00%","49"\n"Visual and performing arts","0.00%","0.00%","2.23%","50"\n"Health professions and related programs","0.56%","0.00%","4.45%","51"\n"Business/marketing","0.00%","0.00%","16.64%","52"\n"History","0.00%","0.00%","0.48%","54"\n"Other","","","",""'}]}],
#   'job_metadata': {'credits_used': 1867.0,
#    'credits_max': 1000,
#    'job_credits_usage': 57,
#    'job_pages': 57,
#    'job_is_cache_hit': True},
#   'job_id': 'cac11eca-30f4-457e-8cdc-bc2f8a3d6117',
#   'file_path': './datasets/cds/pdf/Penn State CDS_2023-2024.pdf'}]

# %%
# extract features
from llama_index.core.ingestion import IngestionPipeline
from llama_index.core.node_parser import  MarkdownNodeParser
from llama_index.core.schema import TransformComponent
from llama_index.core import PromptTemplate
from llama_index.llms.cohere import Cohere
from llama_index.llms.openai import OpenAI
from llama_index.core.extractors import SummaryExtractor

cohere_api_key = os.environ["COHERE_API_KEY"]
openai_api_key = os.environ["OPENAI_API_KEY"]

# llm = Cohere(model="command-r-plus", api_key=cohere_api_key)
llm = OpenAI(api_key=openai_api_key)

class TableCleaner(TransformComponent):    
    def _format_prompt(self, text: str):
        template = PromptTemplate((
            "This is a node from a markdown file:\n"
            "---------------------\n"
            "{node}"
            "\n---------------------\n"
            "Return the node from the document and ensure any markdown tables are valid. Reformat the tables if necessary.\n"
            "Only return the text from the document. Do not respond to the prompt.\n"
        ))

        return template.format(node=text)
    
    def __call__(self, nodes, **kwargs):
        for node in nodes:
            completion = llm.complete(self._format_prompt(node.text), formatted=True)
            print("completion:", completion)
            
            node.text = completion.text

        return nodes
    
    async def acall(self, nodes, **kwargs):
        for node in nodes:
            completion = await llm.acomplete(self._format_prompt(node.text), formatted=True)
            print("completion:", completion)
            
            node.text = completion.text

        return nodes

# pipeline = IngestionPipeline(transformations=[MarkdownNodeParser(), TableCleaner()])
# pipeline = IngestionPipeline(transformations=[MarkdownNodeParser(), SummaryExtractor(llm=llm)])
pipeline = IngestionPipeline(transformations=[MarkdownNodeParser()])

nodes = await pipeline.arun(documents=documents)

for i, node in enumerate(nodes):
    print(f"Node {i+1}:")
    print(node.text)
# Out:
# Node 1:
# Mississippi State University
# Node 2:
# Office of Institutional Research and Effectiveness
# Node 3:
# A. General Information
# Node 4:
# A0. Respondent Information
#
# | **Office:** | Office of Institutional Research and Effectiveness |
# |-------------|----------------------------------------------------|
# | **Address:** | P.O. Drawer EY |
# | **City:** | Mississippi State |
# | **State:** | Mississippi |
# | **Zip:** | 39762 |
# | **Country:** | United States |
# | **Phone Number:** | 662-325-3920 |
# | **Email Address:** | oir@ir.msstate.edu |
#
# Are your responses to the CDS posted for reference on your institution's website?
# **Yes**
#
# If yes, please provide a direct link to the posted CDS responses:
# https://ir.msstate.edu/cdsets.php
# Node 5:
# A1. Address Information
#
# **Please enter general institution information below:**
#
# | **Name of College or University** | Mississippi State University |
# |-----------------------------------|------------------------------|
# | **Street Address:** | 75 B.S. Hood Road |
# | **City:** | Mississippi State |
# | **State:** | Mississippi |
# | **Zip:** | 39762 |
# | **Country:** | United States |
# | **Main Institution Phone Number:** | 662-325-2323 |
# | **Main Institution Website:** | https://www.msstate.edu/ |
#
# **Please enter Admissions Office information below:**
#
# | **Street Address:** | 25 Old Main |
# |---------------------|-------------|
# | **City:** | Mississippi State |
# | **State:** | Mississippi |
# | **Zip:** | 39762 |
# | **Country:** | United States |
# | **Admissions Phone Number:** | 662-325-2224 |
# | **Admissions Website:** | https://www.admissions.msstate.edu/ |
# | **Admissions Email Address:** | admit@msstate.edu |
#
# Is there a separate URL for your school's online application? If yes, please specify:
# https://apply.msstate.edu
#
# If you have a mailing address other than the one listed above to which applications should be sent, please provide:
# P.O. Box 6334
# Mississippi State
# Mississippi 39762
#
# *Updated: 2/13/2024*
# ---
# Node 6:
# Mississippi State University
# Node 7:
# Office of Institutional Research and Effectiveness
# Node 8:
# A2. Source of Institutional Control: (click to select from dropdown)
# **Public**
# Node 9:
# A3. Classify your undergraduate institution: (click to select from dropdown)
# **Coeducational**
# Node 10:
# A4. Academic year calendar: (click to select from dropdown)
# **Semester**
# Node 11:
# A5. Degrees offered by your institution (select all that apply).
#
# - [x] Certificate
# - [ ] Diploma
# - [ ] Associate
# - [ ] Terminal
# - [ ] Transfer
# - [x] Bachelor's
# - [x] Post-Bachelor's certificate
# - [x] Master's
# - [ ] Post-Master's certificate
# - [x] Doctoral degree - research/scholarship
# - [ ] Doctoral degree - professional practice
# - [ ] Doctoral degree - other
# Node 12:
# A6. Diversity, Equity, and Inclusion
# If you have a diversity, equity, and inclusion office or department, please provide the URL of the corresponding Web page:
# https://www.oidi.msstate.edu/
#
# *Updated: 2/13/2024*
# *A. General Information*
# *Common Data Set 2023-24*
# ---
# Node 13:
# Mississippi State University
# Node 14:
# Office of Institutional Research and Effectiveness
# Node 15:
# B. ENROLLMENT AND PERSISTENCE
# Node 16:
# B1. Institutional Enrollment
# Provide numbers of students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.
#
# |                            | Men |        |        | Women |        |        | Another Gender |        |
# |----------------------------|-----|--------|--------|-------|--------|--------|----------------|--------|
# |                            | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment |
# | UNDERGRADUATE STUDENTS     |     |        |        |       |        |        |                |        |
# | Degree-seeking first-time, first-year students | 1,673 | 9      | 2,059  | 10    | 0      | 0      |
# | Other first-year, degree-seeking students      | 823   | 79     | 765    | 82    | 0      | 0      |
# | All other degree-seeking undergraduate students | 5,369 | 756    | 5,640  | 573   | 0      | 0      |
# | **Total degree-seeking undergraduate students** | **7,865** | **844** | **8,464** | **665** | **0** | **0** |
# | All other undergraduates enrolled in credit courses | 144   | 87     | 110    | 51    | 0      | 0      |
# | **Total Undergraduate Students**               | **8,009** | **931** | **8,574** | **716** | **0** | **0** |
#
# - Total part-time undergraduate degree-seeking students: **1,509**
# - Total full-time undergraduate degree-seeking students: **16,329**
# - Total of all undergraduate degree-seeking students: **17,838**
# - Total of all undergraduate students enrolled: **18,230**
#
# |                            | Men |        |        | Women |        |        | Another Gender |        |
# |----------------------------|-----|--------|--------|-------|--------|--------|----------------|--------|
# |                            | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment | Full Time Enrollment | Part Time Enrollment |
# | GRADUATE STUDENTS          |     |        |        |       |        |        |                |        |
# | Degree-seeking first-time  | 219   | 129    | 270    | 155   | 0      | 0      |
# | All other degree-seeking   | 720   | 865    | 1,067  | 931   | 0      | 0      |
# | All other graduates enrolled in credit courses | 4     | 26     | 3      | 38    | 0      | 0      |
# | **Total Graduate Students** | **943** | **1,020** | **1,340** | **1,124** | **0** | **0** |
#
# - Total part-time graduate degree-seeking students: **2,080**
# - Total full-time graduate degree-seeking students: **2,276**
# - Total of all graduate degree-seeking students: **4,356**
# - Total of all graduate students enrolled: **4,427**
#
# *Updated: 2/13/2024*
# ---
# Node 17:
# Mississippi State University
# Node 18:
# Office of Institutional Research and Effectiveness
# Node 19:
# B2. Enrollment by Racial/Ethnic Category
#
# Provide numbers of undergraduate students for each of the following categories as of the institution’s official fall reporting date or as of October 15, 2023.
#
# |                                | Degree-seeking, First-time, First-year | Degree-seeking Undergraduates (include first-time, first-year) | Total Undergraduates (both degree-seeking and non-degree-seeking) |
# |--------------------------------|----------------------------------------|---------------------------------------------------------------|-------------------------------------------------------------------|
# | International (nonresidents)   | 73                                     | 230                                                           | 238                                                               |
# | Hispanic/Latino                | 160                                    | 746                                                           | 761                                                               |
# | Black or African American, non-Hispanic | 620                            | 2,634                                                         | 2,733                                                             |
# | White, non-Hispanic            | 2,677                                  | 13,236                                                        | 13,452                                                            |
# | American Indian or Alaska Native, non-Hispanic | 16                      | 86                                                            | 87                                                                |
# | Asian, non-Hispanic            | 56                                     | 291                                                           | 299                                                               |
# | Native Hawaiian or other Pacific Islander, non-Hispanic | 0              | 7                                                             | 7                                                                 |
# | Two or more races, non-Hispanic | 115                                   | 472                                                           | 482                                                               |
# | Race and/or ethnicity unknown  | 34                                     | 136                                                           | 171                                                               |
# | **Total**                      | **3,751**                              | **17,838**                                                    | **18,230**                                                        |
# Node 20:
# B3. Persistence / Degrees
#
# Number of degrees awarded by your institution from July 1, 2022, to June 30, 2023.
#
# | Degree Type                                | Number of Degrees Awarded |
# |--------------------------------------------|---------------------------|
# | Bachelor's Degrees                         | 4,541                     |
# | Post-Bachelor's Degrees                    |                           |
# | Master's Degrees                           | 1,129                     |
# | Post-Master's Degrees                      | 39                        |
# | Doctoral degree - research/scholarship     | 148                       |
# | Doctoral degree - professional practice    | 93                        |
#
# *Updated: 2/13/2024*
#
# *B. Enrollment and Persistence*
#
# *Common Data Set 2023-24*
# ---
# Node 21:
# Mississippi State University
# Node 22:
# Office of Institutional Research and Effectiveness
# Node 23:
# B4 - B21. Graduation Rates
#
# The items in this section correspond to data elements collected by the IPEDS Web-based Data Collection System's Graduation Rate Survey (GRS).
#
# **For Bachelor's or Equivalent Programs: Please provide data for the Fall 2017 cohort if available. If Fall 2017 cohort data are not available, provide data for the Fall 2016 cohort.**
#
# | 2016 COHORT | Recipients of a Federal Pell Grant | Recipients of a Subsidized Stafford Loan, who did not receive a Pell Grant | Students who did not receive either a Pell Grant or a subsidized Stafford Loan | Total |
# |-------------|------------------------------------|------------------------------------------------------|----------------------------------------------------------|-------|
# | A. Initial 2016 cohort of first-time, full-time, bachelor's (or equivalent) degree-seeking undergraduate students | 1,180 | 535 | 1,902 | 3,617 |
# | B. Of the initial 2016 cohort, how many did not persist and did not graduate for any of the following reasons (report total allowable exclusions) | 1 | 0 | 1 | 2 |
# | - Deceased | | | | |
# | - Permanently Disabled | | | | |
# | - Armed Forces | | | | |
# | - Foreign Aid Service of the Federal Government | | | | |
# | C. Final 2016 cohort, after adjusting for allowable exclusions | 1,179 | 535 | 1,901 | 3,615 |
# | D. Of the initial 2016 cohort, how many completed the program in four years or less (by Aug. 31, 2020)? | 553 | 330 | 1,398 | 2,281 |
# | E. Of the initial 2016 cohort, how many completed the program in more than four years but in five years or less (after Aug. 31, 2020 and by Aug. 31, 2021)? | 307 | 215 | 952 | 1,474 |
# | F. Of the initial 2016 cohort, how many completed the program in more than five years but in six years or less (after Aug. 31, 2021 and by Aug. 31, 2022)? | 188 | 96 | 385 | 669 |
# | G. Total graduating within six years (Sum of D., E., and F.) | 1,048 | 641 | 2,735 | 4,424 |
# | H. Six-year graduation rate for 2016 cohort (G. divided by C.) | 46.9% | 61.7% | 73.5% | 63.1% |
# Node 24:
# B22. Retention Rates
#
# For the cohort of all full-time bachelor's (or equivalent) degree-seeking undergraduate students who entered your institution as first-year students in Fall 2022 (or the preceding summer term), what percentage was enrolled at your institution as of the date your institution calculates its official enrollment in Fall 2023.
#
# **Enter retention rate:** 83%
#
# ---
#
# *Updated: 2/13/2024*
#
# *B. Enrollment and Persistence*
#
# *Common Data Set 2023-24*
# ---
# Node 25:
# Mississippi State University
# Node 26:
# Office of Institutional Research and Effectiveness
# Node 27:
# C. FIRST-TIME, FIRST-YEAR ADMISSION
# Node 28:
# C1. Applications: First-time, First-year Students
# Provide the number of degree-seeking, first-time, first-year students who applied, were admitted, and enrolled (full- or part-time) in Fall 2023.
#
# | | Men | Women | Unknown Gender | Total |
# |---|---|---|---|---|
# | Total first-time, first-year students who applied in Fall 2023 | 8,895 | 11,937 | 45 | 20,877 |
# | Total first-time, first-year students admitted in Fall 2023 | 6,857 | 9,049 | 28 | 15,934 |
# | Total first-time, first-year students enrolled in Fall 2023 | 1,682 | 2,069 | 0 | 3,751 |
# | Full-time, first-time, first-year students enrolled in Fall 2023 | 1,673 | 2,059 | 0 | 3,732 |
# | Part-time, first-time, first-year students enrolled in Fall 2023 | 9 | 10 | 0 | 19 |
#
# | | In-State | Out-of-State | International | Total |
# |---|---|---|---|---|
# | Total first-time, first-year (degree seeking) who applied | 7,377 | 11,877 | 1,623 | 20,877 |
# | Total first-time, first-year (degree seeking) who were admitted | 5,654 | 9,529 | 751 | 15,934 |
# | Total first-time, first-year (degree seeking) enrolled | 2,068 | 1,611 | 72 | 3,751 |
# Node 29:
# C2. Applications: First-time, First-year Wait-Listed Students
# Students who met admission requirements but whose final admission was contingent on space availability.
#
# Do you have a policy of placing students on a waiting list? **No**
# Node 30:
# C3. Admission Requirements: High School Completion Requirement
# Does your institution require high school completion for degree-seeking entering students?
#
# **High school diploma is required and GED is accepted**
# Node 31:
# C4. Admission Requirements: General College-Preparatory Program
# Does your institution require OR recommend a general college-preparatory program for degree-seeking students?
#
# | | |
# |---|---|
# | Require |  |
# Node 32:
# C5. Admission Requirements: High School Units Required/Recommended
# Specify the distribution of academic high school course units required and/or recommend of all or most degree-seeking students using Carnegie units (one unit equals one year of study or its equivalent). If you use a different system, please convert to Carnegie.
#
# | Units | Units Required | Units Recommended |
# |---|---|---|
# | Total Academic Units | 18 | 20 |
# | English | 4 | 4 |
# | Mathematics | 4 | 4 |
# | Science | 3 | 4 |
# | of Science Units, how many units must be lab | 3 | 4 |
# | Foreign Language |  |  |
# | Social Studies | 3 | 4 |
# | History |  |  |
# | Computer Science | 1 |  |
# | Visual/Performing Arts | 1 | 1 |
# | Academic Electives | 2 | 2 |
#
# *Updated: 2/13/2024*
#
# *Common Data Set 2023-24*
# ---
# Node 33:
# Mississippi State University
# Node 34:
# Office of Institutional Research and Effectiveness
# Node 35:
# C6. Basis for Selection: Open Admission Policy
#
# Does your institution have an open admission policy, under which virtually all secondary school graduates or students with GED equivalency diplomas are admitted without regard to academic record, test scores, or other qualifications?
#
# |   |   |
# |---|---|
# |   | No |
# Node 36:
# C7. Basis for Selection: Relative Importance of Factors in Admission Decisions
#
# Please indicate the relative importance of each of the following academic and non-academic factors in your first-time, first-year degree-seeking general admission decisions (not including programs with specific criteria): *select from the dropdown menus*.
# Node 37:
# ACADEMIC
#
# | Factor | Importance |
# |--------|-------------|
# | Rigor of secondary school record | Considered |
# | Class rank | Important |
# | Academic Grade Point Average (GPA) | Very Important |
# | Recommendations | Not Considered |
# | Standardized test scores | Considered |
# | Application essay | Not Considered |
# Node 38:
# NONACADEMIC
#
# | Factor | Importance |
# |--------|-------------|
# | Interview | Not Considered |
# | Extracurricular activities | Not Considered |
# | Talent/ability | Not Considered |
# | Character/personal qualities | Not Considered |
# | First generation | Not Considered |
# | Alumni/ae relation | Not Considered |
# | Geographical residence | Not Considered |
# | State residency | Not Considered |
# | Religious affiliation/commitment | Not Considered |
# | Volunteer work | Not Considered |
# | Work experience | Not Considered |
# | Level of applicant's interest | Not Considered |
# Node 39:
# C8. SAT and ACT Policies
#
# Does your institution make use of SAT or ACT scores in admissions decisions for first-time, first-year, degree-seeking applicants?
#
# |   |   |
# |---|---|
# |   | Yes |
#
# If yes, please select the appropriate response from the dropdown menus for each possible option below for admission for Fall 2025.
#
# | SAT and/or ACT | Considered if submitted |
#
# Does your institution use applicants' test scores for academic advising?
#
# |   |   |
# |---|---|
# |   | Yes |
#
# Please indicate which tests your institution uses for placement (e.g. state tests):
#
# |   |   |   |   |
# |---|---|---|---|
# | ☑ SAT | ☐ CLEP | ☐ AP |   |
# | ☑ ACT | ☐ Institutional Exam | ☐ State Exam |   |
#
# *Updated: 2/13/2024*
#
# *Common Data Set 2023-24*
# ---
# Node 40:
# Mississippi State University
# Node 41:
# Office of Institutional Research and Effectiveness
# Node 42:
# C9. First-time, first-year profile: National standardized test scores (SAT/ACT)
#
# Provide information for all enrolled, degree-seeking, full-time and part-time, first-time, first-year students enrolled in Fall 2023, including students who began studies during summer, international students/nonresidents, and students admitted under special arrangements. Report the percent and number of first-time, first-year students enrolled in Fall 2023 who submitted national standardized (SAT/ACT) test scores.
#
# |                      | Percent | Number |
# |----------------------|---------|--------|
# | Submitting SAT Scores| 5%      | 192    |
# | Submitting ACT Scores| 84%     | 3,152  |
#
# For each assessment listed below, report the score that represents the 25th percentile (the score that 25 percent of the first-time, first-year population scored at or below) and the 75th percentile score (the score that 25 percent scored at or above).
#
# | Assessment                                | 25th Percentile Score | 50th Percentile Score (not used in BCP) | 75th Percentile Score |
# |-------------------------------------------|-----------------------|----------------------------------------|-----------------------|
# | SAT Composite (400 - 1600)                | 1105                  | 1210                                   | 1405                  |
# | SAT Evidence-Based Reading and Writing (200 - 800) | 570                   | 610                                    | 690                   |
# | SAT Math (200 - 800)                      | 540                   | 610                                    | 720                   |
# | ACT Composite (0 - 36)                    | 21                    | 25                                     | 29                    |
# | ACT Math (0 - 36)                         | 19                    | 24                                     | 27                    |
# | ACT English (0 - 36)                      | 21                    | 24                                     | 30                    |
# | ACT Reading (0 - 36)                      | 22                    | 25                                     | 31                    |
# | ACT Science (0 - 36)                      | 21                    | 24                                     | 28                    |
# Node 43:
# Percent of first-time, first-year students with scores in each range:
# Sum of each column should equal 100%.
#
# | Score Range | SAT Evidence-Based Reading and Writing | SAT Math |
# |-------------|----------------------------------------|----------|
# | 700-800     | 21%                                    | 28%      |
# | 600-699     | 34%                                    | 26%      |
# | 500-599     | 37%                                    | 33%      |
# | 400-499     | 6%                                     | 8%       |
# | 300-399     | 2%                                     | 2%       |
# | 200-299     | 0%                                     | 0%       |
# | **Total**   | **100%**                               | **100%** |
#
# | Score Range | SAT Composite |
# |-------------|----------------|
# | 1400-1600   | 26%            |
# | 1200-1399   | 28%            |
# | 1000-1199   | 38%            |
# | 800-999     | 6%             |
# | 600-799     | 3%             |
# | 400-599     | 0%             |
# | **Total**   | **100%**       |
#
# | Score Range | ACT Composite |
# |-------------|----------------|
# | 30 - 36     | 23%            |
# | 24 - 29     | 36%            |
# | 18 - 23     | 32%            |
# | 12 - 17     | 7%             |
# | 6 - 11      | 1%             |
# | Below 6     | 0%             |
# | **Total**   | **100%**       |
#
# | Score Range | ACT English | ACT Math | ACT Reading | ACT Science |
# |-------------|-------------|----------|-------------|-------------|
# | 30 - 36     | 26%         | 12%      | 34%         | 19%         |
# | 24 - 29     | 30%         | 40%      | 31%         | 39%         |
# | 18 - 23     | 32%         | 32%      | 29%         | 32%         |
# | 12 - 17     | 10%         | 17%      | 6%          | 6%          |
# | 6 - 11      | 1%          | 0%       | 0%          | 1%          |
# | Below 6     | 0%          | 0%       | 0%          | 0%          |
# | **Total**   | **100%**    | **100%** | **100%**    | **100%**    |
#
# *Updated: 2/13/2024*
#
# *Common Data Set 2023-24*
# ---
# Node 44:
# Mississippi State University
# Node 45:
# Office of Institutional Research and Effectiveness
# Node 46:
# C10. Class Rank Ranges
# Percent of all degree-seeking, first-time, first-year students who had high school class rank within each of the following ranges (report information for those students from whom you collected high school rank information).
#
# | Class Rank Range | Percent |
# |------------------|---------|
# | Percent in top tenth of high school graduating class | 24.4% |
# | Percent in top quarter of high school graduating class | 48.7% |
# | Percent in top half of high school graduating class | 77.0% |
# | Percent in bottom half of high school graduating class | 23.0% |
# | Percent in bottom quarter of high school graduating class | 5.4% |
# | Percent of total first-time, first-year students who submitted high school class rank | 36.9% |
#
# *Top half and bottom half should = 100%.*
# Node 47:
# C11. High School Grade Point Ranges
# Percentage of all enrolled, degree-seeking, first-time, first-year students who had high school grade-point averages within each of the following ranges (using 4.0 scale).
#
# | Score Range | Percent of students who submitted scores |
# |-------------|------------------------------------------|
# | Percent who had GPA of 4.0 | 29.0% |
# | Percent who had GPA between 3.75 and 3.99 | 21.7% |
# | Percent who had GPA between 3.50 and 3.74 | 17.7% |
# | Percent who had GPA between 3.25 and 3.49 | 10.0% |
# | Percent who had GPA between 3.00 and 3.24 | 9.8% |
# | Percent who had GPA between 2.50 and 2.99 | 8.9% |
# | Percent who had GPA between 2.00 and 2.49 | 2.8% |
# | Percent who had GPA between 1.0 and 1.99 | 0.0% |
# | Percent who had GPA below 1.0 | 0.0% |
# | **Total** | **100.0%** |
# Node 48:
# C12. Average High School GPA
# Average high school GPA of all degree-seeking, first-time, first-year students who submitted GPA:
#
# | | |
# |----------------|-----|
# | Average high school GPA | 3.6 |
# | Percent of total first-time, first-year students who submitted high school GPA | 99.9% |
#
# *Updated: 2/13/2024*
# ---
# Node 49:
# Mississippi State University
# Node 50:
# Office of Institutional Research and Effectiveness
# Node 51:
# C13. Application Fee
#
# **Does your institution have an application fee?**
# Yes
#
# **If yes, what is the amount of the application fee:**
# $40.00
#
# **If yes, can the fee be waived for applicants with financial need?**
# Yes
# Node 52:
# C14. Application Closing Date
#
# **Does your institution have an application closing date?**
# No
# Node 53:
# C15. First-time, first-year student acceptance other than Fall
#
# **Are first-time, first-year students accepted for terms other than the Fall?**
# Yes
# Node 54:
# C16. Admissions Notification to Applicants
#
# **Are notifications to applicants of admission decision sent on a rolling basis?**
# Yes
#
# **What date do rolling notifications begin? (MM/DD)**
# 15-Aug
# Node 55:
# C17. Reply Policy for Applicants
#
# **What is your institution's reply policy for admitted applicants?**
# No set date
#
# **Deadline for housing deposits: (MM/DD)**
# 1-Apr
#
# **Amount of housing deposit:**
# $100.00
#
# **Are housing deposits refundable if student does not enroll?**
# No
# Node 56:
# C18. Deferred Admission
#
# **Does your institution allow students to postpone enrollment after admission?**
# No
# Node 57:
# C19. Early Admissions
#
# **Does your institution allow high school students to enroll as full-time, first-time, first-year students one year or more before high school graduation?**
# No
# Node 58:
# C20. Common Application (Questions Removed from CDS.)
# Node 59:
# C21. Early Decision
#
# **Does your institution offer an early decision plan (an admission plan that permits students to apply and be notified of an admission decision well in advance of the regular notification date and that asks students to commit to attending if accepted) for first-time, first-year applicants for fall enrollment?**
# No
# Node 60:
# C22. Early Action
#
# **Do you have a nonbinding early action plan whereby students are notified of an admission decision well in advance of the regular notification date but do not have to commit to attending your college?**
# No
#
# *Updated: 2/13/2024*
# *C.First-time Freshmen Admission*
# *Common Data Set 2023-24*
# ---
# Node 61:
# Mississippi State University
# Node 62:
# Office of Institutional Research and Effectiveness
# Node 63:
# D. TRANSFER ADMISSION
# Node 64:
# D1. Fall Applicants: Transfer Student Enrollment
#
# **Does your institution enroll transfer students?**
# ☑ Yes
#
# **If yes, may transfer students earn advanced standing credit by transferring credits earned from coursework completed at other colleges/universities?**
# ☑ Yes
# Node 65:
# D2. Fall Applicants: Student Counts
#
# Provide the number of students who applied, were admitted, and enrolled as degree-seeking transfer students in Fall 2023. If your institution collects and reports non-binary gender data, please use the "Another Gender" category.
#
# |                | Applicants | Admitted Applicants | Enrolled Applicants |
# |----------------|------------|---------------------|---------------------|
# | Men            | 1,722      | 1,311               | 902                 |
# | Women          | 2,180      | 1,454               | 847                 |
# | Another Gender | 0          | 0                   | 0                   |
# | **Total**      | **3,902**  | **2,765**           | **1,749**           |
# Node 66:
# D3. Enrollment Terms
#
# Please indicate which terms for which transfer students may enroll: *(select all that apply)*
#
# ☑ Fall
# ☑ Spring
# ☐ Winter
# ☑ Summer
# Node 67:
# D4. Transfer Applicants Minimum Credits
#
# **Must a transfer applicant have a minimum number of credits/courses completed or else must apply as an entering first-year student?**
# ☑ No
# Node 68:
# D5. Requirements for Admission
#
# Please indicate if the below items are required, recommended, or not of transfer students to apply for admission:
# *Select from the dropdown menu.*
#
# | Requirement                                      | Status            |
# |--------------------------------------------------|-------------------|
# | High school transcript                           | Required of Some  |
# | College transcript(s)                            | Required of All   |
# | Essay or personal statement                      | Not Required      |
# | Interview                                        | Not Required      |
# | Standardized test scores                         | Required of Some  |
# | Statement of good standing from prior institution(s) | Required of All   |
#
# *Updated: 2/13/2024*
# ---
# Node 69:
# Mississippi State University
# Node 70:
# Office of Institutional Research and Effectiveness
# Node 71:
# D6. Minimum High School GPA Required
# If a minimum high school grade point average is required of transfer applicants, specify (on a 4.0) scale:
#
# **GPA Required:** `__________`
# Node 72:
# D7. Minimum College GPA Required
# If a minimum college grade point average is required of transfer applicants, specify (on a 4.0) scale:
#
# **GPA Required:** `2.0`
# Node 73:
# D8. List any other application requirements specific to transfer applicants:
# $40 Application Fee
# Node 74:
# D9. Application Specific Dates
# List application priority, closing, notification, and candidate reply dates for transfer students. If applications are reviewed on a continuous or rolling basis, place a check mark in the "Rolling Admission" column.
#
# Use MM/DD format.
#
# | Priority Date | Closing Date | Notification Date | Reply Date | Rolling Admission         |
# |---------------|--------------|-------------------|------------|---------------------------|
# | Fall          |              |                   |            | ☑ Fall Rolling Admission  |
# | Winter        |              |                   |            | ☑ Winter Rolling Admission |
# | Spring        |              |                   |            | ☑ Spring Rolling Admission |
# | Summer        |              |                   |            | ☑ Summer Rolling Admission |
# Node 75:
# D10. Open Admission Policy
# Does an open admission policy, if reported, apply to transfer students?
#
# **No**
# Node 76:
# D11. Additional Requirements
# Please describe any additional requirements for transfer students, if applicable:
#
# `________________________________________________________________________________________`
# Node 77:
# D12. Lowest Grade Allowable for Transfer Credit
# Report the lowest grade earned for any course that may be transferred for credit:
#
# **Lowest grade:** `C *`
# Node 78:
# D13. Maximum Credits Transferred to two-year institutions
# Report the maximum number of credits or courses that may be transferred from a two-year institution:
#
# **Number:** `62 **`
# **Unit Type:** `Credit(s)`
# Node 79:
# D14. Maximum Credits Transferred to four-year institutions
# Report the maximum number of credits or courses that may be transferred from a four-year institution:
#
# **Number:** `93 **`
# **Unit Type:** `Credit(s)`
#
# *Updated: 2/13/2024*
# ---
# Node 80:
# Mississippi State University
# Node 81:
# Office of Institutional Research and Effectiveness
# Node 82:
# D15. Minimum Credits to Earn Associate Degree
# Report the minimum number of credits that transfer students must complete at your institution to earn an associate degree:
#
# **Number:** _______
# Node 83:
# D16. Minimum Credits to Earn Bachelor's Degree
# Report the minimum number of credits that transfer students must complete at your institution to earn a bachelor's degree:
#
# **Number:** 31
# Node 84:
# D17: Other Credit Policies
# Please describe any other transfer credit policies:
#
# (*) Colleges and schools may allow the transfer of credits with a grade of D at their discretion [MSU AOP 12.12]. (**) For curricula requiring 124 total credit hours. The last half of total hours applied toward graduation must be earned in a senior college, and at least the last 25% of semester credit hours of course work taken to fulfill degree requirements must be completed at Mississippi State University [MSU AOP 12.11].
# Node 85:
# D18: Military/Veteran Transfer Credits
# Does your institution accept the following military/veteran transfer credits: (select all that apply)
#
# - [ ] American Council on Education (ACE)
# - [ ] DANTES Subject Standardized Tests (DSST)
# - [x] College Level Examination Program (CLEP)
# Node 86:
# D19: Maximum Credits Transferred - ACE
# Report the maximum number of credits or courses that may be transferred based on military education evaluated by the American Council on Education (ACE):
#
# **Number:** 31
# **Unit Type:** Credit(s)
# Node 87:
# D20: Maximum Credits Transferred - CLEP, DSST
# Report the maximum number of credits or courses that may be transferred based on Department of Defense supported prior learning assessments (College Level Examination Program (CLEP) or DANTES Subject Standardized Tests (DSST)):
#
# **Number:** 31
# **Unit Type:** Credit(s)
# Node 88:
# D21: Published Transfer Policies
# Are the military/veteran credit transfer policies published on your website?
#
# **Yes** [ ] No [ ]
#
# If yes, please provide the URL where the policy can be located:
# https://www.veterans.msstate.edu/gi-bill/tran-credit/
# Node 89:
# D22: Unique Transfer Policies
# Please describe other military/veteran transfer credit policies unique to your institution:
#
# ---
#
# *Updated: 2/13/2024*
# *D. Transfer Admission*
# *Common Data Set 2023-24*
# ---
# Node 90:
# E. ACADEMIC OFFERINGS AND POLICIES
# Node 91:
# E1. Special study options
#
# Please identify the programs available at your institution. Refer to the glossary for definitions. Select all that apply.
#
# - [x] Accelerated
# - [ ] Comprehensive transition and postsecondary program for students with intellectual disabilities
# - [x] Cross-registration
# - [x] Distance learning
# - [x] Double major
# - [x] Dual enrollment
# - [x] English as a Second Language (ESL)
# - [x] Exchange student program (domestic)
# - [x] External degree program
# - [x] Honors program
# - [x] Independent study
# - [x] Internships
# - [x] Liberal arts/career combination
# - [x] Student-designed major
# - [x] Study abroad
# - [x] Teacher certification program
# - [x] Undergraduate Research
# - [ ] Weekend college
# - [ ] Other
#
# If other, please specify:
# Node 92:
# E2. Removed from the CDS.
# Node 93:
# E3. Required Coursework for Graduation
#
# Please indicate the areas in which all, or most, students are required to complete some coursework prior to graduation: Select all that apply.
#
# - [x] Arts / Fine arts
# - [ ] Computer literacy
# - [x] English (including composition)
# - [ ] Foreign languages
# - [ ] History
# - [ ] Humanities
# - [x] Intensive Writing
# - [x] Mathematics
# - [x] Philosophy
# - [ ] Physical Education
# - [x] Sciences (biological or physical)
# - [x] Social Science
# - [ ] Other
#
# If "Other" selected, please specify below:
#
# ---
#
# *Updated: 2/13/2024*
#
# *E. Academic Offerings-Policies*
#
# *Common Data Set 2023-24*
# ---
# Node 94:
# F. STUDENT LIFE
# Node 95:
# F1. First-time, first-year degree-seeking students and undergraduates enrolled
#
# Please complete the table below with the percentages or average age of first-time, first-year degree-seeking students and degree-seeking undergraduates enrolled in Fall 2023 who fit into the following categories:
#
# | Category                                                                 | First-time, First-year Students | Undergraduates |
# |--------------------------------------------------------------------------|---------------------------------|----------------|
# | Percent who are from out of state (exclude international/non-residents) | 42.9%                           | 32.2%          |
# | Percent of men who join fraternities                                     | 27.3%                           | 21.1%          |
# | Percent of women who join sororities                                     | 36.6%                           | 26.3%          |
# | Percent who live in college-owned, -operated, or -affiliated housing     | 94.9%                           | 33.6%          |
# | Percent who live off campus or commute                                   | 5.1%                            | 66.4%          |
# | Percent of students age 25 or older                                      | 0.1%                            | 8.1%           |
# | Average age of full-time students                                        | 18                              | 21             |
# | Average age of all students (full-time and part-time)                    | 18                              | 21             |
# Node 96:
# F2. Activities Offered
#
# Please identify all programs available at your institution.
#
# - [x] Campus Ministries
# - [x] Choral groups
# - [x] Concert band
# - [x] Dance
# - [ ] Drama/theater
# - [x] International Student Organization
# - [x] Jazz band
# - [ ] Literary magazine
# - [ ] Marching band
# - [x] Model UN
# - [x] Music ensembles
# - [ ] Opera
# - [ ] Pep band
# - [x] Radio station
# - [x] Student government
# - [x] Student newspaper
# - [x] Student-run film society
# - [x] Symphony orchestra
# - [x] Television station
# - [ ] Yearbook
#
# ---
#
# *Updated: 2/13/2024*
#
# *F. Student Life*
#
# *Common Data Set 2023-24*
# ---
# Node 97:
# Mississippi State University
# Node 98:
# Office of Institutional Research and Effectiveness
# Node 99:
# F3. ROTC (program offered in cooperation with Reserve Officers' Training Corps) select all that apply.
#
# **Army ROTC is offered:**
# - [x] On Campus
# - [ ] At cooperating institution
#
# If at cooperating institution, please list institution below:
#
# ---
#
# **Naval ROTC is offered:**
# - [ ] Marine Option
# - [ ] On Campus
# - [ ] At cooperating institution
#
# If at cooperating institution, please list institution below:
#
# ---
#
# **Air Force ROTC is offered:**
# - [x] On Campus
# - [ ] At cooperating institution
#
# If at cooperating institution, please list institution below:
#
# ---
# Node 100:
# F4. Housing
# Please check all types of college-owned, -operated, or -affiliated housing available for undergraduates at your institution.
#
# - [ ] Apartments for married students
# - [x] Men's residence halls
# - [ ] Apartments for single students
# - [x] Special housing for international students
# - [x] Coed residence halls
# - [x] Special housing for students with disabilities
# - [ ] Cooperative housing
# - [x] Theme housing
# - [x] Fraternity/sorority housing
# - [x] Women's residence halls
# - [ ] Living Learning Communities
# - [x] Other Housing Options
#
# If selected "Other Housing Options", please specify below:
# **Co-Residential Housing**
#
# ---
#
# *Updated: 2/13/2024*
#
# *F. Student Life*
#
# *Common Data Set 2023-24*
# ---
# Node 101:
# G. ANNUAL EXPENSES
# Node 102:
# G0. Net Price Calculator URL
# Please provide the URL of your institution's net price calculator:
# https://www.sfa.msstate.edu/cost/
#
# For the following sections, please provide 2024-2025 academic year costs of attendance for the following categories that are applicable to your institution.
#
# If your institution's 2024-2025 academic year costs of attendance are not available at this time, please select the checkbox below and enter the approximate date (i.e. MM/DD) when your institution's final 2024-2025 academic year costs of attendance will be available.
#
# **Tuition and Fee Data Provided are:** Firm and Final
#
# - [x] 2024-2025 academic costs not currently available
# - Approximate date costs will be available: **July-24**
# Node 103:
# G1. Undergraduate, full-time tuition, required fees, food and housing
# List the typical tuition, required fees, and food and housing for a full-time undergraduate student for the full 2024-2025 academic year. (30 semester hours or 45 quarter hours for institutions that derive annual tuition by multiplying credit hour cost by number of credits).
#
# - A full academic year refers to the period of time generally extending from September to June; usually equated to two semesters, two trimesters, three quarters, or the period covered by a four-one-four plan.
# - Food and housing is defined as double occupancy and 19 meals per week or the maximum meal plan.
# - Required fees include only charges that all full-time students must pay that are not included in tuition (e.g., registration, health, or activity fees).
# - Do not include optional fees (e.g., parking, laboratory use).
#
# |                          | First-Year | Undergraduate |
# |--------------------------|------------|---------------|
# | **PUBLIC INSTITUTION**   |            |               |
# | Tuition: In-state        | $9,665     | $9,665        |
# | Tuition: Out-of-state    | $26,430    | $26,430       |
# | Tuition: International (non-resident) | $25,294 | $25,294 |
# | **FOR ALL INSTITUTIONS** |            |               |
# | Required Fees            | $150       | $150          |
# | Food and Housing (on-campus) | $12,293 | $12,293 |
# | Housing Only (on-campus) | $7,707     | $7,707        |
# | Food Only (on-campus meal plan) | $4,586 | $4,586 |
#
# *Source: http://www.mississippi.edu/finance/downloads/tuition.pdf
# *Source: http://www.mississippi.edu/finance/downloads/housing.pdf
# *Source: http://www.mississippi.edu/finance/downloads/meal.pdf
# Node 104:
# G2. Credits Per Term
# Please enter the number of credits per term a student can take for the stated full-time tuition:
#
# - Minimum number of credits: **12.0**
# - Maximum number of credits: **12.0**
# Node 105:
# G3. Tuition and Fee Variance by Year of Study
# Do tuition and fees vary by year of study (e.g. sophomore, junior, senior)?
#
# - [ ] Yes
# - [x] No
# Node 106:
# G4. Tuition and Fee Variance by Undergraduate Instructional Program
# Do tuition and fees vary by undergraduate instructional program?
#
# - [ ] Yes
# - [x] No
#
# *Updated: 2/13/2024*
# ---
# Node 107:
# Mississippi State University
# Node 108:
# Office of Institutional Research and Effectiveness
# Node 109:
# G5. Estimated Expenses for Typical Full-Time Undergraduates
# Please provide estimated expenses for a typical full-time undergraduate student:
#
# |                      | Residents | Commuters (living at home) | Commuters (not living at home) |
# |----------------------|-----------|----------------------------|-------------------------------|
# | Books and supplies:  | $1,200    | $1,200                     | $1,200                        |
# | Housing only:        |           |                            | $7,930                        |
# | Food only:           |           | $4,586                     | $4,586                        |
# | Transportation:      | $2,808    | $2,808                     | $2,808                        |
# | Other expenses:      | $3,338    | $3,338                     | $3,338                        |
# Node 110:
# G6. Undergraduate Per-Credit-Hour Charges* (tuition only)
# Please enter the undergraduate per-credit-hour charges (tuition only) in the applicable institution type and segment of students:
# Node 111:
# Public Institutions
#
# |                                      | Charge (tuition only) |
# |--------------------------------------|-----------------------|
# | In-state students, per-credit-hour charge (tuition only): | $402.75               |
# | Out-of-state students, per-credit-hour charge (tuition only): | $1,107.75             |
# | International (non-resident) students, per-credit-hour charge (tuition only): | $1,107.75             |
#
# *Source: https://www.controller.msstate.edu/accountservices/tuition
#
# ---
#
# *Updated: 2/13/2024*
# *G. Annual Expenses*
# *Common Data Set 2023-24*
# ---
# Node 112:
# H. FINANCIAL AID
# Node 113:
# H1. Aid Awarded to Enrolled Undergraduates
#
# Enter total dollar amounts awarded to enrolled full-time and less than full-time degree-seeking undergraduates (using the same cohort reported in CDS Question B1, "total degree-seeking" undergraduates) in the following categories.
#
# Indicate the academic year for which data are reported for items H1, H2, H2A, and H6 below:
#
# **2022-2023 Final**
#
# Which needs-analysis methodology does your institution use in awarding institutional aid? (formerly CDS - H3)
#
# **Federal methodology (FM)**
#
# | Scholarships / Grants | Need-Based (Include non-need based aid use to meet need) | Non-Need-Based (Exclude non-need-based aid use to meet need) |
# |-----------------------|----------------------------------------------------------|-------------------------------------------------------------|
# | Federal               | $31,001,530.00                                           | $2,305,519.00                                                |
# | State - all states, not only the state in which your institution is located | $10,799,403.00 |                                                             |
# | Institutional - Endowed scholarships, annual gifts and tuition funded grants, awarded by the college, excluding athletic aid and tuition waivers (which are reported below) | $40,655,467.00 | $30,340,312.00 |
# | Scholarships/grants from external sources (e.g. Kiwanis, National Merit) not awarded by the college | $7,452,458.00 | $2,589,272.00 |
# | **Total Scholarships/Grants** | **$89,908,858.00** | **$35,235,103.00** |
#
# | Self Help | Need-Based (Include non-need based aid use to meet need) | Non-Need-Based (Exclude non-need-based aid use to meet need) |
# |-----------|----------------------------------------------------------|-------------------------------------------------------------|
# | Student loans from all sources (excluding parent loans) | $80,370,909.00 | $19,472,378.00 |
# | Federal Work-Study | $1,539,187.73 | |
# | State and other (e.g., institutional) work-study/employment (Note: excludes Federal Work/Study captured above) | | |
# | **Total Self-Help** | **$81,910,096.73** | **$19,472,378.00** |
#
# | MISC. | Need-Based (Include non-need based aid use to meet need) | Non-Need-Based (Exclude non-need-based aid use to meet need) |
# |-------|----------------------------------------------------------|-------------------------------------------------------------|
# | Parent Loans | $13,201,396.00 | $8,870,269.00 |
# | Tuition Waivers | | $63,221,154.81 |
# | Athletic Awards | | $10,446,762.56 |
#
# Updated: 2/13/2024
# ---
# Node 114:
# Mississippi State University
# Node 115:
# Office of Institutional Research and Effectiveness
# Node 116:
# H2. Number of Enrolled Students Awarded Aid
# List the number of degree-seeking full-time and less-than-full-time undergraduates who applied for and were awarded financial aid from any source.
#
# |                                      | Full-Time, First-Time, First-Year | Full-Time Undergrad. (Include Freshman) | Less Than Full-Time Undergrad. |
# |--------------------------------------|-----------------------------------|----------------------------------------|--------------------------------|
# | A. Number of degree-seeking undergraduate students (CDS Item B1 if reporting on Fall 2023 cohort) | 3367                              | 16621                                  | 1684                           |
# | B. Number of students in line (A) who applied for need-based financial aid | 2998                              | 12665                                  | 881                            |
# | C. Number of students in line (B) who were determined to have financial need | 2416                              | 10555                                  | 747                            |
# | D. Number of students in line (C) who were awarded any financial aid | 2383                              | 10227                                  | 616                            |
# | E. Number of students in line (D) who were awarded any need-based scholarship or grant aid | 2330                              | 9487                                   | 432                            |
# | F. Number of students in line (D) who were awarded any need-based self-help aid | 1218                              | 5934                                   | 456                            |
# | G. Number of students in line (D) who were awarded any non-need-based scholarship or grant aid | 487                               | 1196                                   | 18                             |
# | H. Number of students in line (D) who need was fully met (exclude PLUS loans, unsubsidized loans, and private alternative loans) | 488                               | 1861                                   | 51                             |
# | I. On average, the percentage of need that was met of students who were awarded any need-based aid. Exclude any aid that was awarded in excess of need as well as any resources that were awarded to replace EFC (PLUS loans, unsubsidized loans, and private alternative loans). | 57.8%                             | 55.3%                                  | 41.4%                          |
# | J. The average financial aid package of those in line (D). Exclude any resources that were awarded to replace EFC (PLUS loans, unsubsidized loans, and private alternative loans). | $15,977.87                        | $14,760.42                             | $8,992.72                      |
# ...
# Node 123:
# Office of Institutional Research and Effectiveness
# Node 124:
# H6. Aid to Undergraduate Degree-Seeking Nonresidents
#
# Report numbers and dollar amounts for the same academic year as checked in item H1.
#
# **H1 Response:** 2022-2023 Final
#
# Indicate your institution's policy regarding institutional scholarship and grant aid for undergraduate degree-seeking nonresidents:
#
# - [ ] Institutional need-based scholarship or grant aid is available
# - [x] Institutional non-need-based scholarship or grant aid is available
# - [ ] Institutional scholarship and grant aid is not available
#
# If institutional financial aid is available for undergraduate degree-seeking nonresidents, provide the number of undergraduate degree-seeking nonresidents who were awarded need-based or non-need-based aid:
#
# Number of undergraduate degree-seeking nonresidents awarded aid: `210`
#
# Average dollar amount of institutional financial aid awarded to undergraduate degree-seeking nonresidents: `$4,232.80`
#
# Total dollar amount of institutional financial aid awarded to undergraduate degree-seeking nonresidents: `$914,284.00`
# Node 125:
# H7. Process for Nonresident First-Year Students
#
# Select all financial aid forms that nonresident first-year financial aid applicants must submit:
#
# - [ ] Institution's own financial aid form
# - [ ] CSS Profile
# - [x] Other; please specify: `General Scholarship Application`
# Node 126:
# H8. Process for First-Year Students
#
# Select all financial aid forms domestic first-year financial aid applicants must submit:
#
# - [x] FAFSA
# - [x] State aid form
# - [ ] Institution's own financial aid form
# - [ ] Business/Farm Supplement
# - [ ] CSS Profile
# - [x] Other; please enter below: `General Scholarship Application`
# Node 127:
# H9. Filing Dates for First-Year Students
#
# Does institution have a deadline for filing required financial aid forms for first-year students?
# Select "no" if there is no deadline and applications are processed on a rolling basis.
#
# - [x] No
#
# Priority date for filing required financial aid forms: `3/1`
#
# Deadline for filing required financial aid forms:
#
# ---
#
# *Updated: 2/13/2024*
#
# *H. Financial Aid*
#
# *Common Data Set 2023-24*
# ---
# Node 128:
# Mississippi State University
# Node 129:
# Office of Institutional Research and Effectiveness
# Node 130:
# H10. Notification Dates for First-Year Students
# Please enter the date for only one response below based on whether students are notified on a certain date or notified on a rolling basis.
#
# Students are notified on or about (date): (MM/DD)
# **12/1**
#
# Students are notified on a rolling basis starting (date): (MM/DD)
# ____________________
# Node 131:
# H11. Reply Dates for First-Year Students
# Students must reply by (date): (MM/DD)
# **5/1**
#
# or within (number) of weeks of notification:
# ____________________
# Node 132:
# H12. Types of Aid Available - Loans
# Please select all types of aid available to undergraduates at your institution:
#
# - [x] Direct Subsidized Stafford Loans
# - [ ] Federal Nursing Loans
# - [x] Direct Unsubsidized Stafford Loans
# - [ ] State Loans
# - [x] Direct PLUS Loans
# - [x] College/University loans from institutional funds
# - [ ] Federal Perkins Loans
# - [ ] Other: ____________________
# Node 133:
# H13. Types of Aid Available - Need-Based Scholarships and Grants
# Please select all types of aid available to undergraduates at your institution:
#
# - [x] Federal Pell
# - [x] College/University scholarship or grant aid from institutional funds
# - [x] SEOG
# - [ ] United Negro College Fund
# - [x] State scholarship/grants
# - [ ] Federal Nursing Scholarship
# - [x] Private scholarships
# - [ ] Other: ____________________
# Node 134:
# H14. Criteria Used in Awarding Institutional Aid
# Please select all criteria used in awarding non-need based institutional aid:
#
# - [x] Academics
# - [ ] Job skills
# - [ ] Music/drama
# - [ ] Alumni affiliation
# - [ ] ROTC
# - [ ] Religious affiliation
# - [ ] Art
# - [x] Leadership
# - [ ] State/district residency
# - [x] Athletics
# - [ ] Minority status
# Node 135:
# H14. Criteria Used in Awarding Institutional Aid
# Please select all criteria used in awarding need-based institutional aid:
#
# - [x] Academics
# - [ ] Job skills
# - [ ] Music/drama
# - [ ] Alumni affiliation
# - [ ] ROTC
# - [ ] Religious affiliation
# - [ ] Art
# - [x] Leadership
# - [ ] State/district residency
# - [x] Athletics
# - [ ] Minority status
#
# *Updated: 2/13/2024*
# *H. Financial Aid*
# *Common Data Set 2023-24*
# ---
# Node 136:
# H15. Affordable Policies
#
# If your institution has recently implemented any major financial aid policy, program, or initiative to make your institution more affordable to incoming students such as replacing loans with grants, or waiving costs for families below a certain income level, please provide the details below:
#
# - There was not an increase to the tuition rate for the year 2020-2021, from the prior year.
# - The winter session tuition for 2020-2021 was discounted in order to help students be able to take advantage of that opportunity.
# - A special circumstance initiative that included contacting our students to inform them of assistance for those who may have had a change in financial standing.
# - Offered an Educational Savings Grant Program for current and future students from low-income families, who can deposit up to $625 into a trustee savings account that will be transferred to their student account at the end of the program. After six months of participation the the Educational Savings Grant Program, the student’s savings would be matched four to one in grant funds, up to $2,500.
#
# ---
#
# Mississippi State University
# Office of Institutional Research and Effectiveness
#
# Updated: 2/13/2024
# H. Financial Aid
# Common Data Set 2023-24
# ---
# Node 137:
# Mississippi State University
# Node 138:
# Office of Institutional Research and Effectiveness
# Node 139:
# I. INSTRUCTIONAL FACULTY AND CLASS SIZE
# Node 140:
# I1. Instructional Faculty by Category
# Please report the number of instructional faculty members in each category for Fall 2023. Include faculty who are on your institution’s payroll on the census date your institution uses for IPEDS/AAUP.
#
# | Category                                                                 | Full-Time | Part-Time | Total |
# |--------------------------------------------------------------------------|-----------|-----------|-------|
# | A. Total number of instructional faculty                                 | 1081      | 377       | 1458  |
# | B. Total number who are members of minority groups                       | 227       | 88        | 315   |
# | C. Total number who are women                                            | 489       | 211       | 700   |
# | D. Total number who are men                                              | 592       | 166       | 758   |
# | E. Total number who are international (non-residents)                    | 66        | 9         | 75    |
# | F. Total number with doctorate, or other terminal degrees                | 892       | 149       | 1041  |
# | G. Total number whose highest degree is a master’s but not a terminal master’s | 176       | 150       | 326   |
# | H. Total number whose highest degree is a bachelor’s                     | 8         | 61        | 69    |
# | I. Total number whose highest degree is unknown or other                 | 5         | 17        | 22    |
# | J. Total number in stand-alone graduate/professional programs in which faculty teach virtually only graduate-level students | 0         | 0         | 0     |
#
# **NOTE:** Rows F, G, H and I should equal row A.
# Node 141:
# I2. Student to Faculty Ratio
# Report the Fall 2023 ratio of full-time equivalent students (full-time plus 1/3 part time) to full-time equivalent instructional faculty (full time plus 1/3 part time). In the ratio calculation, exclude both faculty and students in stand-alone graduate or professional programs such as medicine, law, veterinary, dentistry, social work, business, or public health in which faculty teach virtually only graduate level students.
#
# Do not count undergraduate or graduate student teaching assistants as faculty.
#
# | Fall 2023 Student to Faculty Ratio: | 16 | to | 1 |
# |-------------------------------------|----|----|---|
# | Ratio is based on number of students: | 19,652 |
# | Ratio is based on number of faculty:  | 1,207  |
#
# ---
#
# *Updated: 2/13/2024*
#
# *Common Data Set 2023-24*
# ---
# Node 142:
# Mississippi State University
# Node 143:
# Office of Institutional Research and Effectiveness
# Node 144:
# I3. Undergraduate Class Size
#
# In the table below, please report information about the size of classes and class sections offered in the Fall 2023 term.
#
# **Class Sections:** A class section is an organized course offered for credit, identified by discipline and number, meeting at a stated time or times in a classroom or similar setting, and not a subsection such as a laboratory or discussion session. Undergraduate class sections are defined as any sections in which at least one degree-seeking undergraduate student is enrolled for credit. Exclude distance learning classes and noncredit classes and individual instruction such as dissertation or thesis research, music instruction, or one-to-one readings. Exclude students in independent study, co-operative programs, internships, foreign language taped tutor sessions, practicums, and all students in one-on-one classes. Each class section should be counted only once and should not be duplicated because of course catalog cross-listings.
#
# **Class Subsections:** A class subsection includes any subsection of a course, such as laboratory, recitation, and discussion subsections that are supplementary in nature and are scheduled to meet separately from the lecture portion of the course. Undergraduate subsections are defined as any subsections of courses in which degree-seeking undergraduate students enrolled for credit. As above, exclude noncredit classes and individual instruction such as dissertation or thesis research, music instruction, or one-to-one readings. Each class subsection should be counted only once and should not be duplicated because of cross-listings.
#
# Using the above definitions, please report for each of the following class-size intervals the number of class sections and class subsections offered in Fall 2023. For example, a lecture class with 800 students who meet at another time in 40 separate labs with 20 students should be counted once in the "100+" column in the class section column and 40 times under the "20-29" column of the class subsections table.
#
# | Number of class sections with undergraduates enrolled -- Undergraduate Class Size (provide numbers) | Class Sections | Class Sub-Sections |
# |----------------------------------------------------------------------------------------------------|----------------|-------------------|
# | 2 - 9                                                                                              | 519            | 253               |
# | 10 - 19                                                                                            | 891            | 229               |
# | 20 - 29                                                                                            | 776            | 114               |
# | 30 - 39                                                                                            | 303            | 32                |
# | 40 - 49                                                                                            | 218            | 37                |
# | 50 - 99                                                                                            | 339            | 11                |
# | 100+                                                                                               | 106            | 0                 |
# | **Total**                                                                                          | **3,152**      | **676**           |
#
# *Updated: 2/13/2024*
# ---
# Node 145:
# Mississippi State University
# Node 146:
# Office of Institutional Research and Effectiveness
# Node 147:
# J. DISCIPLINARY AREAS OF DEGREES CONFERRED
#
# Degrees conferred between July 1, 2022 and June 30, 2023.
#
# For each of the following discipline areas, provide the percentage of diplomas/certificates, and bachelor's degrees awarded. To determine the percentage, use majors, not headcount (e.g., students with one degree but a double major will be represented twice). Calculate the percentage from your institution's IPEDS Completions by using the sum of 1st and 2nd majors for each CIP code as the numerator and the sum of the Grand Total by 1st Majors and the Grand Total by 2nd major as the denominator. If you prefer, you can compute the percentages using 1st majors only.
#
# | Category                                      | Diploma/Certificates | Bachelor's | CIP 2020 Categories to Include |
# |-----------------------------------------------|----------------------|------------|-------------------------------|
# | Agriculture                                   |                      | 6.1        | 1                             |
# | Natural resources and conservation            |                      | 2.6        | 3                             |
# | Architecture                                  |                      | 1.6        | 4                             |
# | Communication/journalism                      |                      | 3.2        | 9                             |
# | Computer and information sciences             |                      | 2.2        | 11                            |
# | Education                                     |                      | 8.3        | 13                            |
# | Engineering                                   |                      | 17.0       | 14                            |
# | Engineering technologies                      |                      | 1.7        | 15                            |
# | Foreign languages, literatures, and linguistics |                    | 0.7        | 16                            |
# | Family and consumer sciences                  |                      | 1.9        | 19                            |
# | English                                       |                      | 0.4        | 23                            |
# | Liberal arts/general studies                  |                      | 1.3        | 24                            |
# | Biological/life sciences                      |                      | 6.1        | 26                            |
# | Mathematics and statistics                    |                      | 0.7        | 27                            |
# | Interdisciplinary studies                     |                      | 6.5        | 30                            |
# | Parks and recreation                          |                      | 5.9        | 31                            |
# | Philosophy and religious studies              |                      | 0.2        | 38                            |
# | Physical sciences                             |                      | 1.9        | 40                            |
# | Psychology                                    |                      | 6.9        | 42                            |
# | Public administration and social services     |                      | 0.8        | 44                            |
# | Social sciences                               |                      | 3.1        | 45                            |
# | Visual and performing arts                    |                      | 1.2        | 50                            |
# | Health professions and related programs       |                      | 0.2        | 51                            |
# | Business/marketing                            |                      | 19.0       | 52                            |
# | History                                       |                      | 0.7        | 54                            |
# | Other                                         |                      |            |                               |
#
# *Updated: 2/13/2024*
#
# *Common Data Set 2023-24*

# %%
import time

from llama_index.embeddings.cohere import CohereEmbedding
from llama_index.embeddings.openai import OpenAIEmbedding, OpenAIEmbeddingModelType
from pinecone import Pinecone, ServerlessSpec

embed_model = OpenAIEmbedding(
    api_key=openai_api_key,
    model=OpenAIEmbeddingModelType.TEXT_EMBED_3_LARGE,
    input_type="search_query",
)

# embed_model = CohereEmbedding(
#     cohere_api_key=cohere_api_key,
#     model_name="embed-english-v3.0",
#     input_type="search_query",
# )


index = VectorStoreIndex(nodes=nodes, embed_model=embed_model)
# batch_size = 40
# index = VectorStoreIndex(nodes=[], embed_model=embed_model)

# NOTE: to load vector store
# for i in range(0, len(nodes), batch_size):
#     batch = nodes[i:i+batch_size]
#     index.insert_nodes(batch)
#     time.sleep(5)

# %%
from llama_index.postprocessor.cohere_rerank import CohereRerank
from llama_index.llms.cohere import Cohere
from llama_index.llms.openai import OpenAI

# llm = Cohere(model="command-r-plus", api_key=cohere_api_key)
llm = OpenAI(api_key=openai_api_key)

chat_engine = index.as_chat_engine(
    llm=llm,
    verbose=True,
    # similarity_top_k=10,
    # node_postprocessors=[CohereRerank(api_key=cohere_api_key, top_n=4)],
)

chat_engine.chat("What is the breakdown of application fees for applying to this school?")
# Out:
# Added user message to memory: Does this school have a waitlist?
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"Does this school have a waitlist?"}
# Got output: This school does not have a waitlist.
# ========================
# AgentChatResponse(response='This school does not have a waitlist.', sources=[ToolOutput(content='This school does not have a waitlist.', tool_name='query_engine_tool', raw_input={'input': 'Does this school have a waitlist?'}, raw_output=Response(response='This school does not have a waitlist.', source_nodes=[NodeWithScore(node=TextNode(id_='2e281eb8-ffd8-4cfc-a59d-899d02d18add', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='083481a6-6e3a-431d-a965-d4bd9ae668d6', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, hash='6311d8889d733dabc3424b2f2a102ad45d7403a06d55cb0967a6b4ba38444263')}, text='C2. Applications: First-time, First-year Wait-Listed Students\nStudents who met admission requirements but whose final admission was contingent on space availability.\n\nDo you have a policy of placing students on a waiting list? **No**', start_char_idx=2, end_char_idx=235, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.6066718627243619), NodeWithScore(node=TextNode(id_='efdc8be2-faa9-4d64-ab42-7985ab5867da', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='64b031a5-91ec-49d0-8e2d-d42e3c7245a1', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, hash='aac9c78852c002dcdbcfe6bbc9f329d6a8d4a7b295cbff28004045a1985d0bb0')}, text='C18. Deferred Admission\n\n**Does your institution allow students to postpone enrollment after admission?**  \nNo', start_char_idx=2, end_char_idx=112, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.4408091764087742)], metadata={'2e281eb8-ffd8-4cfc-a59d-899d02d18add': {'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, 'efdc8be2-faa9-4d64-ab42-7985ab5867da': {'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}}), is_error=False)], source_nodes=[NodeWithScore(node=TextNode(id_='2e281eb8-ffd8-4cfc-a59d-899d02d18add', embedding=None, metadata={'file_path': 'datasets/cds/md/mississippi-state.md', 'file_name': 'mississippi-state.md', 'file_size': 67952, 'creation_date': '2024-06-12', 'last_modified_date': '2024-06-12'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_ ...

# %%
from enum import Enum

from pydantic import BaseModel, Field
from llama_index.core.program import LLMTextCompletionProgram

def convert_response_to_class(response_str, output_cls):
    prompt_template_str = """\
    Generate an {cls_name}, from this string: \
    {cls_str}\
    """
    program = LLMTextCompletionProgram.from_defaults(
        llm=llm,
        output_cls=output_cls,
        prompt_template_str=prompt_template_str,
        verbose=True,
    )

    return program(cls_name=output_cls.__name__, cls_str=response_str)

# total first year full time applied male
# total first year full time applied female
# total first year part time applied male
# total first year part time applied female
# total first year full time accepted male
# total first year full time accepted female
# total first year part time accepted male
# total first year part time accepted female
# total first year full time enrolled male
# total first year full time enrolled female
# total first year part time enrolled male
# total first year part time enrolled female
class AcceptedApplicantInfo(BaseModel):
    """Represents male and female applicant information"""

    first_year_applied_male: int = Field(description="Total first year full time male applicants")
    first_year_applied_female: int = Field(description="Total first year full time female applicants")
    first_year_accepted_male: int = Field(description="Total first year full time male applicants who were accepted")
    first_year_accepted_female: int = Field(description="Total first year full time female applicants who were accepted")
    first_year_enrolled_male: int = Field(description="Total first year full time male applicants who enrolled")
    first_year_enrolled_female: int = Field(description="Total first year full time female applicants who enrolled")

applicant_query_engine = index.as_query_engine(
    llm=llm,
    verbose=True,
    response_mode="compact_accumulate",
    output_cls=AcceptedApplicantInfo,
)

response = applicant_query_engine.query("What is the breakdown of male and female first time, first year applicants, how many were accepted, and how many enrolled?")
print(response)

# first year applied in state
# first year applied out of state
# first year applied international
# first year accepted in state
# first year accepted out of state
# first year accepted international
# first year enrolled in state
# first year enrolled out of state
# first year enrolled international

# wait list size
# wait list size admitted
# wait list size ranked

# high school diploma or ged required
# ged accepted

# high school english credits recommended
# high school math credits recommended
# high school science credits recommended
# high school social studies credits recommended
# high school history credits recommended
# high school elective credits recommended
# high school performing arts credits recommended
# high school computer science credits recommended
# high school foreign language credits recommended

# has open admissions policy
# has open admissions policy for out of state

# class rank weight
# gpa weight
# standardized test score weight
# essay weight
# class rank weight
# interview weight
# extracurricular, work or volunteer weight
# first gen weight
# residence weight
# religion weight
class AdmissionFactorWeightClass(str, Enum):
    very_important = "very important"
    important = "important"
    considered = "considered"
    not_considered = "not considered"

class AdmissionsFactorWeights(BaseModel):
    """Represents male and female applicant information"""

    class_rank: AdmissionFactorWeightClass = Field(description="Importance weighted on class rank")
    gpa: AdmissionFactorWeightClass = Field(description="Importance weighted on gpa")
    standardized_test_score: AdmissionFactorWeightClass = Field(description="Importance weighted on standardized test scores")
    essay: AdmissionFactorWeightClass = Field(description="Importance weighted on quality of essay")
    interview: AdmissionFactorWeightClass = Field(description="Importance weighted on quality of essay")
    extracurriculars: AdmissionFactorWeightClass = Field(description="Importance weighted on extracurriculars, volunteer, or work experience")
    first_gen: AdmissionFactorWeightClass = Field(description="Importance weighted on being a first generation student")
    alumni: AdmissionFactorWeightClass = Field(description="Importance weighted on if the student's parents are alumni")
    residence: AdmissionFactorWeightClass = Field(description="Importance weighted on if the student lives out of state")
    religion: AdmissionFactorWeightClass = Field(description="Importance weighted on what the student's religion is")

admission_factor_weight_query_engine = index.as_query_engine(
    llm=llm,
    verbose=True,
    response_mode="compact_accumulate",
    output_cls=AdmissionsFactorWeights,
)

response = admission_factor_weight_query_engine.query("What is the breakdown of relative importance of academic and nonacademic factors for admitted students?")
print(response)

convert_response_to_class(str(response), AdmissionsFactorWeights)

# sat or act required
# sat accepted
# act accepted

# sat composite 25%
# sat composite 50%
# sat composite 75%
# sat math 25%
# sat math 50%
# sat math 75%
# sat reading 25%
# sat reading 50%
# sat reading 75%
# act composite 25%
# act composite 50%
# act composite 75%
# act math 25%
# act math 50%
# act math 75%
# act english 25%
# act english 50%
# act english 75%
# act reading 25%
# act reading 50%
# act reading 75%
# act science 25%
# act science 50%
# act science 75%
# act writing 25%
# act writing 50%
# act writing 75%

# average GPA
# top tenth percent
# top quarter percent
# top half percent
# bottom half percent
# bottom quarter percent

# application fee
# application fee waivable
# application due
# application priority date
# early action
# early action due date
# early decision
# early decision due date

# private or public
# in state tutition
# reciprocity tuition
# religious affiliation tuition
# states with reciprocity
# out of state tuition
# campus housing fees
# campus food fees
# books and supplies fees

# percent of first time freshmen awarded financial aid
# average aid package total
# average scholarship total
# average self help award total
# average need based loan award total

# aid types
# aid deadlines
# Out:
# Response 1: first_year_applied_male=8895 first_year_applied_female=11937 first_year_accepted_male=6857 first_year_accepted_female=9049 first_year_enrolled_male=1682 first_year_enrolled_female=2069
# Response 1: class_rank=<AdmissionFactorWeightClass.important: 'important'> gpa=<AdmissionFactorWeightClass.very_important: 'very important'> standardized_test_score=<AdmissionFactorWeightClass.considered: 'considered'> essay=<AdmissionFactorWeightClass.not_considered: 'not considered'> interview=<AdmissionFactorWeightClass.not_considered: 'not considered'> extracurriculars=<AdmissionFactorWeightClass.not_considered: 'not considered'> first_gen=<AdmissionFactorWeightClass.not_considered: 'not considered'> alumni=<AdmissionFactorWeightClass.not_considered: 'not considered'> residence=<AdmissionFactorWeightClass.not_considered: 'not considered'> religion=<AdmissionFactorWeightClass.not_considered: 'not considered'>
# AdmissionsFactorWeights(class_rank=<AdmissionFactorWeightClass.important: 'important'>, gpa=<AdmissionFactorWeightClass.very_important: 'very important'>, standardized_test_score=<AdmissionFactorWeightClass.considered: 'considered'>, essay=<AdmissionFactorWeightClass.not_considered: 'not considered'>, interview=<AdmissionFactorWeightClass.not_considered: 'not considered'>, extracurriculars=<AdmissionFactorWeightClass.not_considered: 'not considered'>, first_gen=<AdmissionFactorWeightClass.not_considered: 'not considered'>, alumni=<AdmissionFactorWeightClass.not_considered: 'not considered'>, residence=<AdmissionFactorWeightClass.not_considered: 'not considered'>, religion=<AdmissionFactorWeightClass.not_considered: 'not considered'>)
